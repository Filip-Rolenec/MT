# %% [markdown]
# # ADP simulation
# - In this notebook we will test the ADP algorithm.
#
# - The result of this notebook is a csv that describes dfs parameters in all time intervals, like the example below

# %%
import sys
import os

sys.path.append("/Users/filiprolenec/Desktop/MT/MTpython/src")

# %%
import pandas as pd
from datetime import datetime
from gas_example.enum_types import MothballedState, PowerplantState
from gas_example.simulation.state import State, update_balance

# %%
from gas_example.enum_types import Action

# %%
df = pd.DataFrame()
df["0"] = [0.3,0.7,13,93,12,-10]
df["1"] = [0.4,0.6,12,10,9,-4]
df.index = ["\u03C6_0",
            "\u03C6_1", 
            "\u03C6_2", 
            "\u03C6_3", 
            "\u03C6_4", 
            "\u03C6_5"]

# %%
df
# Out:
#         0     1
# φ_0   0.3   0.4
# φ_1   0.7   0.6
# φ_2  13.0  12.0
# φ_3  93.0  10.0
# φ_4  12.0   9.0
# φ_5 -10.0  -4.0

# %%
import sys
import os

sys.path.append("/Users/filiprolenec/Desktop/MT/MTpython/src")

# %%
from gas_example.optimization.adp_algorithm import adp_algorithm_complete

# %%
vfs = adp_algorithm_complete(1)
# Out:
# N/A% (0 of 1) |                          | Elapsed Time: 0:00:00 ETA:  --:--:--
# 298
# [  31.54030068 -498.06898806  207.05633557  184.15948042  141.67084265]
# 297
# {'gas_price': 52.40959736520782, 'co2_price': 8.01443159943288, 'power_price': 55.388625979138475, 'gov_state': 5, 'plant_state': <PowerplantState.NOT_BUILT: 0>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -23105536.485311255}
# Action.DO_NOTHING
# 796.8147889999095
# 744.6867186874151
# 0.7899123186770846
#
#
# {'gas_price': 13.862032479514061, 'co2_price': 13.031588874287372, 'power_price': 17.056811622275596, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': 34141185.85686952}
# Action.MOTHBALL_CHANGE
# -227.8150391217548
# -2128223.3480775654
# -593.4001742268431
#
#
# {'gas_price': 52.40959736520782, 'co2_price': 15.253441736137281, 'power_price': 55.388625979138475, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -23996386.93264997}
# Action.DO_NOTHING
# -354.2107401597284
# -1728331.038074918
# -498.9102666926268
#
#
# {'gas_price': 13.862032479514061, 'co2_price': 8.01443159943288, 'power_price': 41.598329988560224, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': 34141185.85686952}
# Action.RUN
# 1259.9158199046528
# 1977183.902572453
# 433.3488543617589
#
#
# {'gas_price': 13.862032479514061, 'co2_price': 15.253441736137281, 'power_price': 55.388625979138475, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -23996386.93264997}
# Action.RUN
# 746.8591137581908
# 5839365.707056027
# 1030.6056998524962
#
#
# {'gas_price': 49.835082762498196, 'co2_price': 13.031588874287372, 'power_price': 17.056811622275596, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': 110698082.15001848}
# Action.MOTHBALL_CHANGE
# -748.9363980483884
# -1064734.2513706386
# -333.19695274034683
#
#
# {'gas_price': 52.40959736520782, 'co2_price': 6.977755376905639, 'power_price': 41.598329988560224, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -94157742.46144135}
# Action.MOTHBALL_CHANGE
# -27.02901778064188
# -1064025.260764286
# -333.0120500902674
#
#
# {'gas_price': 7.978382540952319, 'co2_price': 13.031588874287372, 'power_price': 23.159023299712903, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -23996386.93264997}
# Action.RUN
# -36.78223960035098
# -1109107.4331965782
# -344.729153766628
#
#
# {'gas_price': 13.862032479514061, 'co2_price': 15.253441736137281, 'power_price': 64.19770744993978, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -23105536.485311255}
# Action.RUN
# 1483.268964894481
# 4189227.8184150048
# 790.1457036916557
#
#
# {'gas_price': 7.978382540952319, 'co2_price': 13.031588874287372, 'power_price': 17.056811622275596, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -23105536.485311255}
# Action.DO_NOTHING
# -198.11645491598324
# -1728185.1555653438
# -498.87517368858954
#
#
# {'gas_price': 7.978382540952319, 'co2_price': 6.977755376905639, 'power_price': 17.056811622275596, 'gov_state': 5, 'plant_state': <PowerplantState.NOT_BUILT: 0>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -23105536.485311255}
# Action.DO_NOTHING
# 987.0372532257986
# 922.4647226370871
# 0.9374752552611872
#
#
# {'gas_price': 41.97372255878556, 'co2_price': 13.031588874287372, 'power_price': 17.056811622275596, 'gov_state': 5, 'plant_state': <PowerplantState.NOT_BUILT: 0>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': 34141185.85686952}
# Action.DO_NOTHING
# -18.675508840196244
# -18.309322394430637
# -0.03566374067675645
#
#
# {'gas_price': 52.40959736520782, 'co2_price': 15.253441736137281, 'power_price': 64.19770744993978, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': 110698082.15001848}
# Action.MOTHBALL_CHANGE
# 101.37686803924339
# -2127900.610913694
# -593.3251841693053
#
#
# {'gas_price': 52.40959736520782, 'co2_price': 13.031588874287372, 'power_price': 64.19770744993978, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': 110698082.15001848}
# Action.MOTHBALL_CHANGE
# 598.1127374762444
# -1063413.6149632633
# -332.85251817793426
#
#
# {'gas_price': 13.862032479514061, 'co2_price': 13.031588874287372, 'power_price': 55.388625979138475, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': 34141185.85686952}
# Action.RUN
# 1058.3772839965488
# 6479598.956885301
# 1120.0528139044927
#
#
# {'gas_price': 41.97372255878556, 'co2_price': 13.031588874287372, 'power_price': 41.598329988560224, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -23996386.93264997}
# Action.MOTHBALL_CHANGE
# -261.8653012637012
# -2128244.7339264154
# -593.4051432995277
#
#
# {'gas_price': 13.862032479514061, 'co2_price': 8.01443159943288, 'power_price': 23.159023299712903, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -23105536.485311255}
# Action.RUN
# -8.8377105547587
# -1358631.2039619796
# -408.2422861910668
#
#
# {'gas_price': 41.97372255878556, 'co2_price': 8.01443159943288, 'power_price': 41.598329988560224, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': 34141185.85686952}
# Action.MOTHBALL_CHANGE
# -9.082245892788706
# -2128008.904162638
# -593.3503470141032
#
#
# {'gas_price': 52.40959736520782, 'co2_price': 8.01443159943288, 'power_price': 55.388625979138475, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': 110698082.15001848}
# Action.MOTHBALL_CHANGE
# -28.821220549013333
# -2128028.2560985684
# -593.3548435762714
#
#
# {'gas_price': 52.40959736520782, 'co2_price': 8.390936430228562, 'power_price': 41.598329988560224, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -23996386.93264997}
# Action.MOTHBALL_CHANGE
# -540.2594947634163
# -2128504.9154156707
# -593.4655966622718
#
#
# [  21.73191477 -275.35945211  107.67563059   55.66050829    0.        ]
# 296
# {'gas_price': 48.819232908585384, 'co2_price': 6.706047736990486, 'power_price': 54.14386197606369, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -28226233.254528284}
# Action.DO_NOTHING
# 78.90337601193463
# -863926.2585270926
# -279.9393148112154
#
#
# {'gas_price': 9.762144582212757, 'co2_price': 12.459588578560826, 'power_price': 79.4321569984643, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': 31838412.52294004}
# Action.RUN
# 1362.5668730043221
# 7375636.882502966
# 1242.337578060732
#
#
# {'gas_price': 48.819232908585384, 'co2_price': 9.562040859368652, 'power_price': 79.4321569984643, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': 31838412.52294004}
# Action.RUN
# 274.5366220338693
# 4334923.523937963
# 812.0544528048799
#
#
# {'gas_price': 18.51556389238081, 'co2_price': 12.459588578560826, 'power_price': 54.14386197606369, 'gov_state': 5, 'plant_state': <PowerplantState.NOT_BUILT: 0>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -28226233.254528284}
# Action.DO_NOTHING
# 809.4133278708703
# 756.4610540792346
# 0.7998881424411869
#
#
# {'gas_price': 39.5316057629472, 'co2_price': 10.678034379739264, 'power_price': 155.23391460593808, 'gov_state': 5, 'plant_state': <PowerplantState.NOT_BUILT: 0>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -45161578.79825634}
# Action.DO_NOTHING
# 2447.1494954654745
# 2287.05560323596
# 1.938301709073201
#
#
# {'gas_price': 48.819232908585384, 'co2_price': 10.678034379739264, 'power_price': 79.4321569984643, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -28226233.254528284}
# Action.RUN
# 490.05490324637407
# 2007082.1134967878
# 438.58332177338
#
#
# {'gas_price': 48.819232908585384, 'co2_price': 6.706047736990486, 'power_price': 54.14386197606369, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': 31838412.52294004}
# Action.DO_NOTHING
# -129.96250535453834
# -1728127.4142209329
# -498.861283489318
#
#
# {'gas_price': 18.51556389238081, 'co2_price': 10.678034379739264, 'power_price': 54.14386197606369, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': 31838412.52294004}
# Action.RUN
# 735.6919581828851
# 2729559.23999355
# 560.8852502962839
#
#
# {'gas_price': 48.819232908585384, 'co2_price': 10.582865425585348, 'power_price': 54.14386197606369, 'gov_state': 5, 'plant_state': <PowerplantState.NOT_BUILT: 0>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -45161578.79825634}
# Action.DO_NOTHING
# 106.91726551493056
# 99.92267804592848
# 0.158391274032396
#
#
# {'gas_price': 18.51556389238081, 'co2_price': 9.562040859368652, 'power_price': 42.58286054687247, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -45161578.79825634}
# Action.RUN
# 52.64243631512073
# 2449562.867534034
# 514.364363623378
#
#
# {'gas_price': 48.819232908585384, 'co2_price': 10.678034379739264, 'power_price': 155.23391460593808, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -45161578.79825634}
# Action.RUN
# 2184.267712311448
# 12924118.585430074
# 1945.9010275059502
#
#
# {'gas_price': 18.51556389238081, 'co2_price': 10.582865425585348, 'power_price': 54.14386197606369, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': 31838412.52294004}
# Action.RUN
# 820.1983802753341
# 2743346.418825142
# 563.1505617079891
#
#
# {'gas_price': 49.133222109990335, 'co2_price': 6.706047736990486, 'power_price': 54.14386197606369, 'gov_state': 5, 'plant_state': <PowerplantState.NOT_BUILT: 0>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -28226233.254528284}
# Action.DO_NOTHING
# 273.25146635869305
# 255.37520220130682
# 0.3355389790840877
#
#
# {'gas_price': 48.819232908585384, 'co2_price': 10.678034379739264, 'power_price': 42.58286054687247, 'gov_state': 5, 'plant_state': <PowerplantState.NOT_BUILT: 0>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': 119065996.44479463}
# Action.DO_NOTHING
# 69.55154218074074
# 68.18778644502163
# 0.11667163228341473
#
#
# {'gas_price': 39.5316057629472, 'co2_price': 10.678034379739264, 'power_price': 155.23391460593808, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -114582821.5721611}
# Action.RUN
# 2041.5146623726323
# 14261403.480336607
# 2105.3767062101683
#
#
# {'gas_price': 49.133222109990335, 'co2_price': 6.706047736990486, 'power_price': 155.23391460593808, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': 119065996.44479463}
# Action.RUN
# 2014.043714030328
# 26899632.243240505
# 3497.816918822889
#
#
# {'gas_price': 48.819232908585384, 'co2_price': 10.678034379739264, 'power_price': 54.14386197606369, 'gov_state': 5, 'plant_state': <PowerplantState.NOT_BUILT: 0>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': 31838412.52294004}
# Action.DO_NOTHING
# 268.8693326648811
# 263.5973849706352
# 0.34415404470142436
#
#
# {'gas_price': 9.762144582212757, 'co2_price': 10.582865425585348, 'power_price': 155.23391460593808, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -114582821.5721611}
# Action.RUN
# 2650.3106696822815
# 37122481.45012382
# 4525.948408726454
#
#
# {'gas_price': 49.133222109990335, 'co2_price': 12.459588578560826, 'power_price': 155.23391460593808, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -114582821.5721611}
# Action.RUN
# 1410.367415464808
# 25241956.0285957
# 3324.2861843985365
#
#
# {'gas_price': 18.51556389238081, 'co2_price': 6.706047736990486, 'power_price': 79.4321569984643, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -114582821.5721611}
# Action.RUN
# 1191.7507619258504
# 6943432.3189082
# 1183.7482916735596
#
#
# [ 21.6841869  529.28934626 114.73055317 -98.18076967   0.        ]
# 295
# {'gas_price': 21.215281077105647, 'co2_price': 10.14241015418757, 'power_price': 212.84156207176736, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -72370714.19304243}
# Action.RUN
# 3976.594182745374
# 25273393.84418971
# 3327.5979811968828
#
#
# {'gas_price': 11.44549214905914, 'co2_price': 5.784173815777147, 'power_price': 45.499166641250895, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': 59792315.84955734}
# Action.RUN
# 775.6766907129895
# 3207568.564747542
# 638.1764280531302
#
#
# {'gas_price': 27.38545674609262, 'co2_price': 12.662870797451857, 'power_price': 27.438105258046804, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -127365466.03037259}
# Action.DO_NOTHING
# -145.03363028075432
# -864135.5454488993
# -279.9958266317945
#
#
# {'gas_price': 20.676381920244186, 'co2_price': 11.623158595560119, 'power_price': 27.438105258046804, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -127365466.03037259}
# Action.DO_NOTHING
# 574.8239739895117
# -1727462.781332761
# -498.7013945053852
#
#
# {'gas_price': 27.38545674609262, 'co2_price': 10.14241015418757, 'power_price': 45.440551708990164, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -127365466.03037259}
# Action.RUN
# 812.9907925569926
# 551613.0293874443
# 156.06575320911523
#
#
# {'gas_price': 27.38545674609262, 'co2_price': 11.623158595560119, 'power_price': 45.499166641250895, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': 73177600.58786702}
# Action.RUN
# 768.2305813419782
# 142031.94152086973
# 52.71191800462502
#
#
# {'gas_price': 11.44549214905914, 'co2_price': 5.784173815777147, 'power_price': 43.170393702660625, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': 59792315.84955734}
# Action.RUN
# 695.407777426844
# 2872146.5665775165
# 584.2050121559689
#
#
# {'gas_price': 11.44549214905914, 'co2_price': 11.623158595560119, 'power_price': 212.84156207176736, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -34023922.802368134}
# Action.RUN
# 5004.113072767627
# 52931504.45542726
# 6011.341358229847
#
#
# {'gas_price': 21.215281077105647, 'co2_price': 8.372019656993798, 'power_price': 27.438105258046804, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -34023922.802368134}
# Action.DO_NOTHING
# 519.4791238684959
# -1727514.5054917186
# -498.713838017974
#
#
# {'gas_price': 27.38545674609262, 'co2_price': 11.623158595560119, 'power_price': 45.499166641250895, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -34023922.802368134}
# Action.RUN
# 228.03227003616115
# 70852.50141319633
# 30.219282591013304
#
#
# {'gas_price': 21.215281077105647, 'co2_price': 12.662870797451857, 'power_price': 45.440551708990164, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -34023922.802368134}
# Action.RUN
# 253.7129943942304
# 801222.691106338
# 210.3790996853501
#
#
# {'gas_price': 11.44549214905914, 'co2_price': 12.662870797451857, 'power_price': 27.438105258046804, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': 59792315.84955734}
# Action.RUN
# 208.35772120956557
# -384312.8348631412
# -142.5292743345018
#
#
# {'gas_price': 11.44549214905914, 'co2_price': 8.372019656993798, 'power_price': 212.84156207176736, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -127365466.03037259}
# Action.RUN
# 4893.894315313873
# 53867500.209530726
# 6096.231597584195
#
#
# {'gas_price': 36.0818182925297, 'co2_price': 11.623158595560119, 'power_price': 212.84156207176736, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -127365466.03037259}
# Action.RUN
# 3543.6638571168255
# 22918980.10183005
# 3077.2035872361116
#
#
# {'gas_price': 21.215281077105647, 'co2_price': 10.14241015418757, 'power_price': 27.438105258046804, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': 59792315.84955734}
# Action.DO_NOTHING
# 27.769787683392735
# -863972.7747179568
# -279.9518753471444
#
#
# {'gas_price': 11.44549214905914, 'co2_price': 5.784173815777147, 'power_price': 45.499166641250895, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -34023922.802368134}
# Action.RUN
# 1156.2094650358365
# 6414696.764400896
# 1111.0686789068682
#
#
# {'gas_price': 20.676381920244186, 'co2_price': 11.623158595560119, 'power_price': 45.499166641250895, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -34023922.802368134}
# Action.RUN
# 806.4766480068256
# 2074246.0406220816
# 450.28576303027296
#
#
# {'gas_price': 27.38545674609262, 'co2_price': 8.372019656993798, 'power_price': 27.438105258046804, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -72370714.19304243}
# Action.DO_NOTHING
# -141.31203797027752
# -864132.0673252195
# -279.99488748472186
#
#
# {'gas_price': 21.215281077105647, 'co2_price': 11.623158595560119, 'power_price': 45.499166641250895, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': 73177600.58786702}
# Action.RUN
# 948.8494417347313
# 1919219.6115032583
# 423.1552546790246
#
#
# {'gas_price': 11.44549214905914, 'co2_price': 5.784173815777147, 'power_price': 45.499166641250895, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -127365466.03037259}
# Action.RUN
# 1178.2584364252477
# 6414717.370916218
# 1111.0715342557326
#
#
# [  26.31891401  574.65502295   98.58807283 -194.27574329    0.        ]
# 294
# {'gas_price': 23.743975566432102, 'co2_price': 7.75801428491247, 'power_price': 39.762738852361, 'gov_state': 5, 'plant_state': <PowerplantState.NOT_BUILT: 0>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': 80675743.15641093}
# Action.DO_NOTHING
# -669.3693491284098
# -656.2444599270821
# -0.7039709020878704
#
#
# {'gas_price': 23.743975566432102, 'co2_price': 9.993315236285166, 'power_price': 39.762738852361, 'gov_state': 5, 'plant_state': <PowerplantState.NOT_BUILT: 0>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': 80675743.15641093}
# Action.DO_NOTHING
# -803.408146872584
# -787.6550459563732
# -0.8196215770965563
#
#
# {'gas_price': 12.348772294379561, 'co2_price': 13.402789184160966, 'power_price': 31.67654284582465, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': 80675743.15641093}
# Action.RUN
# -135.87884309544836
# -10935.897663131356
# -7.340269936088101
#
#
# {'gas_price': 23.743975566432102, 'co2_price': 10.227917398871499, 'power_price': 39.762738852361, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': 110499177.24314937}
# Action.RUN
# 449.0602591108202
# -59796.129371494055
# -30.23854526567781
#
#
# {'gas_price': 12.348772294379561, 'co2_price': 12.548911785887066, 'power_price': 39.762738852361, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': 110499177.24314937}
# Action.RUN
# 794.6176636178907
# 2553914.811288297
# 531.8205629800499
#
#
# {'gas_price': 12.518150886435675, 'co2_price': 13.402789184160966, 'power_price': 44.23071456804577, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': 24235075.529032826}
# Action.RUN
# 147.60511249624665
# 1772752.238527283
# 397.11695883675696
#
#
# {'gas_price': 58.34099385934162, 'co2_price': 12.548911785887066, 'power_price': 110.19131711827586, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': 24235075.529032826}
# Action.RUN
# 1464.5443319885112
# 9592242.332014047
# 1532.978675222918
#
#
# {'gas_price': 12.518150886435675, 'co2_price': 7.75801428491247, 'power_price': 39.762738852361, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': 110499177.24314937}
# Action.RUN
# 929.551279457364
# 3885044.5449154675
# 743.9038427664801
#
#
# {'gas_price': 16.10088719941992, 'co2_price': 13.402789184160966, 'power_price': 39.762738852361, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': 80675743.15641093}
# Action.RUN
# -77.59053876005908
# 613228.9263487011
# 169.86273248848929
#
#
# {'gas_price': 12.348772294379561, 'co2_price': 12.548911785887066, 'power_price': 23.010538970375112, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': 24235075.529032826}
# Action.DO_NOTHING
# 249.72341385975074
# -1727755.1731236689
# -498.7717356915221
#
#
# {'gas_price': 23.743975566432102, 'co2_price': 7.75801428491247, 'power_price': 31.67654284582465, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': 43772620.526366234}
# Action.DO_NOTHING
# -331.6110913721586
# -864325.1089131087
# -280.0470107399488
#
#
# {'gas_price': 16.10088719941992, 'co2_price': 7.75801428491247, 'power_price': 31.67654284582465, 'gov_state': 5, 'plant_state': <PowerplantState.NOT_BUILT: 0>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -25416773.01418698}
# Action.DO_NOTHING
# -604.7054560652371
# -565.1452860496938
# -0.6215366717555791
# {'gas_price': 16.10088719941992, 'co2_price': 10.227917398871499, 'power_price': 39.762738852361, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': 80675743.15641093}
# Action.RUN
# 657.9740818801595
# 2141618.1378013343
# 461.94857213333364
#
#
# {'gas_price': 58.34099385934162, 'co2_price': 10.227917398871499, 'power_price': 110.19131711827586, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': 110499177.24314937}
# Action.RUN
# 635.7034421371493
# 5130249.682517827
# 929.2034246035425
#
#
# {'gas_price': 12.518150886435675, 'co2_price': 13.402789184160966, 'power_price': 110.19131711827586, 'gov_state': 5, 'plant_state': <PowerplantState.NOT_BUILT: 0>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': 110499177.24314937}
# Action.DO_NOTHING
# 1634.3502342840738
# 1602.3041512519121
# 1.4581290630354566
#
#
# {'gas_price': 58.34099385934162, 'co2_price': 12.548911785887066, 'power_price': 31.67654284582465, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': 24235075.529032826}
# Action.DO_NOTHING
# -706.5830180010057
# -1728692.7284490205
# -498.99727157881784
#
#
# {'gas_price': 23.743975566432102, 'co2_price': 7.75801428491247, 'power_price': 23.010538970375112, 'gov_state': 5, 'plant_state': <PowerplantState.NOT_BUILT: 0>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': 110499177.24314937}
# Action.DO_NOTHING
# -1107.963725182526
# -1086.2389462590218
# -1.0713658729999478
#
#
# {'gas_price': 16.10088719941992, 'co2_price': 12.548911785887066, 'power_price': 31.67654284582465, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': 80675743.15641093}
# Action.RUN
# -176.08388704345975
# -428321.51534727216
# -156.00609828297877
#
#
# {'gas_price': 16.10088719941992, 'co2_price': 13.402789184160966, 'power_price': 39.762738852361, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': 24235075.529032826}
# Action.RUN
# 520.786492754185
# 1227120.566001568
# 295.8760334081866
#
#
# {'gas_price': 16.10088719941992, 'co2_price': 13.402789184160966, 'power_price': 44.23071456804577, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': 24235075.529032826}
# Action.RUN
# -24.002242476317974
# 1256669.966952674
# 301.56225961284304
#
#
# [  12.63386707  244.59323376 -155.54224475  -19.87771569    0.        ]
# 293
# {'gas_price': 18.332973535044836, 'co2_price': 6.938555496257657, 'power_price': 64.43421100786027, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': 69375498.67103517}
# Action.RUN
# 373.03728381094635
# 4775791.927451596
# 877.4781636276164
#
#
# {'gas_price': 10.228410593276697, 'co2_price': 7.589705576108925, 'power_price': 54.782868609930176, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -44060074.16475606}
# Action.RUN
# 850.8618625765357
# 8918643.900879234
# 1446.2356380361632
#
#
# {'gas_price': 26.245242159922196, 'co2_price': 9.731810560335976, 'power_price': 64.43421100786027, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -13986405.998526692}
# Action.RUN
# 873.497001768942
# 6468477.939167507
# 1118.51466111434
#
#
# {'gas_price': 18.332973535044836, 'co2_price': 9.731810560335976, 'power_price': 53.26832126161624, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -44060074.16475606}
# Action.RUN
# 470.80941540772466
# 2765749.3607373536
# 566.8266443112591
#
#
# {'gas_price': 26.245242159922196, 'co2_price': 9.2518092467464, 'power_price': 64.43421100786027, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -13986405.998526692}
# Action.RUN
# 529.9434719815156
# 3303446.2568444796
# 653.3919756850186
#
#
# {'gas_price': 18.332973535044836, 'co2_price': 9.731810560335976, 'power_price': 64.43421100786027, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': 69375498.67103517}
# Action.RUN
# 706.7539616201193
# 8747087.846834898
# 1423.9370508924094
#
#
# {'gas_price': 26.245242159922196, 'co2_price': 9.731810560335976, 'power_price': 54.782868609930176, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -5753788.4194562435}
# Action.RUN
# 625.1257897511243
# 3688659.2059355862
# 713.6657030898557
#
#
# {'gas_price': 10.228410593276697, 'co2_price': 6.938555496257657, 'power_price': 64.43421100786027, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -13986405.998526692}
# Action.RUN
# 1065.973384906665
# 11885962.773286186
# 1819.8160565862495
#
#
# {'gas_price': 10.228410593276697, 'co2_price': 8.398673036920036, 'power_price': 54.782868609930176, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -5753788.4194562435}
# Action.RUN
# 562.5622161891977
# 4342958.796162166
# 813.2584177563639
#
#
# {'gas_price': 20.47907959641482, 'co2_price': 7.589705576108925, 'power_price': 64.43421100786027, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -30759321.69485207}
# Action.RUN
# 626.6813425540508
# 4373207.003786173
# 817.7866713884448
#
#
# {'gas_price': 20.47907959641482, 'co2_price': 8.398673036920036, 'power_price': 64.43421100786027, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -30759321.69485207}
# Action.RUN
# 526.1555880388203
# 4256621.740126085
# 800.2985813521612
#
#
# {'gas_price': 18.332973535044836, 'co2_price': 9.2518092467464, 'power_price': 24.601683222426907, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -5753788.4194562435}
# Action.DO_NOTHING
# 339.1810546742572
# -1727683.0083601177
# -498.7543750770978
#
#
# {'gas_price': 18.332973535044836, 'co2_price': 8.398673036920036, 'power_price': 54.782868609930176, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': 69375498.67103517}
# Action.RUN
# 574.5343599650434
# 6351315.215914369
# 1102.277477899867
#
#
# {'gas_price': 20.47907959641482, 'co2_price': 8.398673036920036, 'power_price': 53.26832126161624, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -44060074.16475606}
# Action.RUN
# 681.5476568853405
# 5297120.725372031
# 953.3050568376449
#
#
# {'gas_price': 26.245242159922196, 'co2_price': 8.398673036920036, 'power_price': 64.43421100786027, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -13986405.998526692}
# Action.RUN
# 502.07562991323215
# 3426271.82634726
# 672.7558023156987
#
#
# {'gas_price': 18.332973535044836, 'co2_price': 8.398673036920036, 'power_price': 64.43421100786027, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -5753788.4194562435}
# Action.RUN
# 588.5975953633458
# 4565719.369979557
# 846.4618152007494
#
#
# {'gas_price': 18.332973535044836, 'co2_price': 7.589705576108925, 'power_price': 24.601683222426907, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -44060074.16475606}
# Action.DO_NOTHING
# 107.67083771683122
# -863899.3730488643
# -279.93205500769454
#
#
# {'gas_price': 10.228410593276697, 'co2_price': 9.2518092467464, 'power_price': 53.26832126161624, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -44060074.16475606}
# Action.RUN
# 795.4489327401782
# 8003716.619636327
# 1326.27432664392
#
#
# {'gas_price': 8.276734132179174, 'co2_price': 6.938555496257657, 'power_price': 24.601683222426907, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -30759321.69485207}
# Action.RUN
# 276.50665093478693
# 487899.0949653499
# 141.469888099787
#
#
# {'gas_price': 8.276734132179174, 'co2_price': 6.938555496257657, 'power_price': 64.43421100786027, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -30759321.69485207}
# Action.RUN
# 1025.9819810660006
# 12448008.218938496
# 1888.3386972457904
#
#
# [  37.28024027  452.61628174  -14.3633142  -178.52734925    0.        ]
# 292
# {'gas_price': 61.12971335444625, 'co2_price': 8.12549947129547, 'power_price': 27.90408656598458, 'gov_state': 5, 'plant_state': <PowerplantState.NOT_BUILT: 0>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -54294479.15349667}
# Action.DO_NOTHING
# -2275.6193371916324
# -2126.747044108808
# -1.8754113133936867
#
#
# {'gas_price': 18.806567133127018, 'co2_price': 9.167688430239775, 'power_price': 27.58101653571574, 'gov_state': 5, 'plant_state': <PowerplantState.NOT_BUILT: 0>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -71056068.61490817}
# Action.DO_NOTHING
# -865.5649650661553
# -808.9392196834087
# -0.8380370957798785
#
#
# {'gas_price': 13.280480452637697, 'co2_price': 6.949882776804181, 'power_price': 15.246563929964351, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -71056068.61490817}
# Action.DO_NOTHING
# -610.4368200011548
# -864570.5017009377
# -280.1132665680035
#
#
# {'gas_price': 18.806567133127018, 'co2_price': 6.507340331956727, 'power_price': 27.90408656598458, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -71056068.61490817}
# Action.RUN
# 175.8442799943973
# -981864.0784919709
# -311.44125662943054
#
#
# {'gas_price': 13.280480452637697, 'co2_price': 6.507340331956727, 'power_price': 15.246563929964351, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -54294479.15349667}
# Action.DO_NOTHING
# -631.7615952968373
# -864590.4313974679
# -280.11864743019845
#
#
# {'gas_price': 27.73793105244752, 'co2_price': 6.507340331956727, 'power_price': 15.246563929964351, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -71056068.61490817}
# Action.DO_NOTHING
# -673.119768887989
# -1728629.0838961601
# -498.9819620546789
#
#
# {'gas_price': 11.116137247598672, 'co2_price': 6.507340331956727, 'power_price': 23.104683297841646, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -43033247.07432853}
# Action.RUN
# 263.19668686865
# -149166.77492153645
# -64.77291120400982
#
#
# {'gas_price': 13.280480452637697, 'co2_price': 9.167688430239775, 'power_price': 23.104683297841646, 'gov_state': 5, 'plant_state': <PowerplantState.NOT_BUILT: 0>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -2452492.0766441524}
# Action.DO_NOTHING
# -912.2277936979078
# -852.5493399044499
# -0.8755203978766358
#
#
# {'gas_price': 11.116137247598672, 'co2_price': 8.211823923910178, 'power_price': 23.104683297841646, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -48769286.30499166}
# Action.RUN
# 183.49813122865498
# -640132.5340355709
# -218.05108411072544
#
#
# {'gas_price': 18.806567133127018, 'co2_price': 8.12549947129547, 'power_price': 27.90408656598458, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -43033247.07432853}
# Action.RUN
# 135.3360015489991
# -1447931.76882568
# -430.4837353777274
#
#
# {'gas_price': 18.806567133127018, 'co2_price': 8.12549947129547, 'power_price': 23.104683297841646, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -2452492.0766441524}
# Action.DO_NOTHING
# -220.53173090414066
# -1728206.104421406
# -498.8802131050433
#
#
# {'gas_price': 61.12971335444625, 'co2_price': 8.12549947129547, 'power_price': 23.104683297841646, 'gov_state': 5, 'plant_state': <PowerplantState.NOT_BUILT: 0>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -48769286.30499166}
# Action.DO_NOTHING
# -2590.483100087942
# -2421.012243077159
# -2.0892840465160023
#
#
# {'gas_price': 11.116137247598672, 'co2_price': 9.167688430239775, 'power_price': 15.246563929964351, 'gov_state': 5, 'plant_state': <PowerplantState.NOT_BUILT: 0>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -2452492.0766441524}
# Action.DO_NOTHING
# -1079.5225876073316
# -1008.8996145860292
# -1.0074108642151072
#
#
# {'gas_price': 18.806567133127018, 'co2_price': 9.167688430239775, 'power_price': 31.715327561607232, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -2452492.0766441524}
# Action.RUN
# 204.41901722225248
# -650380.218696266
# -220.95615461489018
#
#
# {'gas_price': 11.116137247598672, 'co2_price': 8.12549947129547, 'power_price': 23.104683297841646, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -48769286.30499166}
# Action.RUN
# 142.0833812380415
# -615309.797056362
# -210.98173449502022
#
#
# {'gas_price': 61.12971335444625, 'co2_price': 8.12549947129547, 'power_price': 27.58101653571574, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -71056068.61490817}
# Action.DO_NOTHING
# -1594.4144235495096
# -1729490.1069379002
# -499.18907084631866
#
#
# {'gas_price': 13.280480452637697, 'co2_price': 6.949882776804181, 'power_price': 27.90408656598458, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -43033247.07432853}
# Action.RUN
# 379.30720788503686
# 482386.81364194304
# 140.18977607851102
#
#
# {'gas_price': 27.73793105244752, 'co2_price': 8.211823923910178, 'power_price': 23.104683297841646, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -54294479.15349667}
# Action.DO_NOTHING
# -522.4298303473466
# -1728488.2521779016
# -498.94808503383683
#
#
# {'gas_price': 13.280480452637697, 'co2_price': 6.507340331956727, 'power_price': 23.104683297841646, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -71056068.61490817}
# Action.RUN
# -292.53234870456095
# -386645.19281081855
# -143.24974111671153
#
#
# {'gas_price': 27.73793105244752, 'co2_price': 6.507340331956727, 'power_price': 23.104683297841646, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -54294479.15349667}
# Action.DO_NOTHING
# -427.2926187896172
# -1728399.338896066
# -498.9266967379163
#
#
# [   4.49323284 -179.74613923    0.           10.45403363    0.        ]
# 291
# {'gas_price': 13.023442351266834, 'co2_price': 4.24575774627935, 'power_price': 26.948012800142834, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -76057081.5497855}
# Action.RUN
# -84.0129743415819
# 529670.5123754591
# 151.07918612307427
#
#
# {'gas_price': 45.51757946933083, 'co2_price': 4.24575774627935, 'power_price': 32.495901080720806, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -66074363.95947535}
# Action.DO_NOTHING
# -382.4907711004437
# -1728357.4680103958
# -498.91662453585997
#
#
# {'gas_price': 45.51757946933083, 'co2_price': 12.3747059839348, 'power_price': 30.1688273802461, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -39394848.24759509}
# Action.DO_NOTHING
# -427.5712914036594
# -1728399.599337764
# -498.9267593880379
#
#
# {'gas_price': 10.397486799075878, 'co2_price': 6.866223920525888, 'power_price': 64.32790147876824, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -39394848.24759509}
# Action.RUN
# -85.80484765026918
# 11826406.747193534
# 1812.517670794362
#
#
# {'gas_price': 40.89346556045993, 'co2_price': 4.24575774627935, 'power_price': 30.1688273802461, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -91088506.43222316}
# Action.DO_NOTHING
# -186.9325030655621
# -864174.7032738924
# -280.0063998054073
#
#
# {'gas_price': 79.80861604473549, 'co2_price': 4.166575144222471, 'power_price': 32.495901080720806, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -39394848.24759509}
# Action.DO_NOTHING
# -355.425326342979
# -864332.1732021868
# -280.0489181353562
#
#
# {'gas_price': 40.89346556045993, 'co2_price': 6.866223920525888, 'power_price': 30.1688273802461, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -39394848.24759509}
# Action.DO_NOTHING
# -385.3399965030377
# -1728360.1308378577
# -498.9172650904246
#
#
# {'gas_price': 45.51757946933083, 'co2_price': 6.866223920525888, 'power_price': 26.948012800142834, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -39394848.24759509}
# Action.DO_NOTHING
# -417.3595123415897
# -1728390.0556190163
# -498.9244636135441
#
#
# {'gas_price': 79.80861604473549, 'co2_price': 6.572185701975655, 'power_price': 64.32790147876824, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -76057081.5497855}
# Action.DO_NOTHING
# -414.822520000321
# -1728387.684598133
# -498.9238932559571
#
#
# {'gas_price': 45.51757946933083, 'co2_price': 12.3747059839348, 'power_price': 64.32790147876824, 'gov_state': 5, 'plant_state': <PowerplantState.NOT_BUILT: 0>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -66074363.95947535}
# Action.DO_NOTHING
# 95.99039583509796
# 89.71065029501915
# 0.1453032083672689
#
#
# {'gas_price': 10.397486799075878, 'co2_price': 12.3747059839348, 'power_price': 26.948012800142834, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -76057081.5497855}
# Action.RUN
# -291.39306957185636
# -525636.1650374979
# -185.02810392094483
#
#
# {'gas_price': 13.023442351266834, 'co2_price': 4.24575774627935, 'power_price': 32.495901080720806, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -91088506.43222316}
# Action.RUN
# -77.50725384349587
# 1328572.504891321
# 315.288556590962
#
#
# {'gas_price': 40.89346556045993, 'co2_price': 6.572185701975655, 'power_price': 26.948012800142834, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -76057081.5497855}
# Action.DO_NOTHING
# -200.69980305688182
# -864187.5699094087
# -280.0098739638585
#
#
# {'gas_price': 79.80861604473549, 'co2_price': 12.3747059839348, 'power_price': 64.32790147876824, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -66074363.95947535}
# Action.DO_NOTHING
# -243.91344029399036
# -864227.9564862624
# -280.0207788073671
#
#
# {'gas_price': 13.023442351266834, 'co2_price': 4.166575144222471, 'power_price': 26.948012800142834, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -66074363.95947535}
# Action.RUN
# -257.4043280840797
# 1082062.0829476118
# 267.5480211580773
#
#
# {'gas_price': 79.80861604473549, 'co2_price': 12.3747059839348, 'power_price': 30.1688273802461, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -66074363.95947535}
# Action.DO_NOTHING
# -388.68965209508053
# -864363.2613571063
# -280.05731207070403
#
#
# {'gas_price': 13.023442351266834, 'co2_price': 4.24575774627935, 'power_price': 32.495901080720806, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -108267791.01598856}
# Action.RUN
# -249.3641447940103
# 2657056.832551673
# 548.9346875496764
#
#
# {'gas_price': 79.80861604473549, 'co2_price': 12.3747059839348, 'power_price': 64.32790147876824, 'gov_state': 5, 'plant_state': <PowerplantState.NOT_BUILT: 0>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -108267791.01598856}
# Action.DO_NOTHING
# -82.81251180708608
# -77.39487084746361
# -0.11855689497583044
#
#
# {'gas_price': 45.51757946933083, 'co2_price': 12.3747059839348, 'power_price': 32.495901080720806, 'gov_state': 5, 'plant_state': <PowerplantState.NOT_BUILT: 0>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -76057081.5497855}
# Action.DO_NOTHING
# -68.02305292760656
# -63.572946682572365
# -0.10062987926821913
#
#
# {'gas_price': 45.51757946933083, 'co2_price': 4.166575144222471, 'power_price': 64.32790147876824, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.MOTHBALLED: 1>, 'balance': -39394848.24759509}
# Action.RUN
# -224.39247128743747
# 3929189.3845919073
# 750.6584360337977
#
#
# [ 1.71560101e+01 -1.20958091e+02 -3.30402372e-13  6.34720548e+01
#   4.23986076e+02]
# 290
# {'gas_price': 13.455764283903568, 'co2_price': 6.057272276124208, 'power_price': 131.53285143733723, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': 13936183.90596202}
# Action.RUN
# 2341.0423439798583
# 15269148.481885485
# 2223.5753692098547
#
#
# {'gas_price': 27.097743958539844, 'co2_price': 7.180326966905382, 'power_price': 62.23427659701714, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': 77925761.44735366}
# Action.RUN
# 708.4368188253391
# 3162388.162607163
# 630.9749829267039
#
#
# {'gas_price': 10.195893022758339, 'co2_price': 5.351219991711305, 'power_price': 6.5369443656257715, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.MOTHBALLED: 1>, 'balance': 77925761.44735366}
# Action.DO_NOTHING
# 345.6701832295801
# -287661.10766351223
# -111.96122038850278
#
#
# {'gas_price': 33.51860172196017, 'co2_price': 5.351219991711305, 'power_price': 62.23427659701714, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -37116940.3250774}
# Action.RUN
# 484.19347586108506
# 5001415.523670711
# 910.4882598149715
#
#
# {'gas_price': 10.195893022758339, 'co2_price': 8.580595955771555, 'power_price': 6.5369443656257715, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': 13936183.90596202}
# Action.MOTHBALL_CHANGE
# 293.8590271114816
# -2127711.902914595
# -593.281335772744
#
#
# {'gas_price': 17.694315668917152, 'co2_price': 7.180326966905382, 'power_price': 6.5369443656257715, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -37116940.3250774}
# Action.MOTHBALL_CHANGE
# 302.6063370174201
# -1063717.1903392375
# -332.93169983671186
#
#
# {'gas_price': 33.51860172196017, 'co2_price': 8.140331455823613, 'power_price': 62.23427659701714, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': 3725133.2367016375}
# Action.RUN
# 346.8591069796613
# 4198038.962687228
# 791.4749462150737
#
#
# {'gas_price': 10.195893022758339, 'co2_price': 5.351219991711305, 'power_price': 22.679495828824777, 'gov_state': 5, 'plant_state': <PowerplantState.NOT_BUILT: 0>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -37116940.3250774}
# Action.DO_NOTHING
# 471.6958684898269
# 440.8372602686286
# 0.519305157376341
#
#
# {'gas_price': 33.51860172196017, 'co2_price': 6.057272276124208, 'power_price': 131.53285143733723, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': 3725133.2367016375}
# Action.RUN
# 1847.6102034855621
# 12379616.133804848
# 1880.0341697097062
#
#
# {'gas_price': 13.455764283903568, 'co2_price': 8.580595955771555, 'power_price': 22.679495828824777, 'gov_state': 5, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -101071720.81264108}
# Action.MOTHBALL_CHANGE
# 640.7622992494709
# -1063401.1567296684
# -332.8492686125613
#
#
# ...
# Action.DO_NOTHING
# -9.871420552764079
# -9.677863284945488
# -0.02096442243872941
#
#
# {'gas_price': 28.246522813989095, 'co2_price': 8.733043955368462, 'power_price': 36.287438192336595, 'gov_state': 3, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': 78535566.46662545}
# Action.DO_NOTHING
# -345.5392690508148
# -864338.7639892399
# -280.0506976803701
#
#
# {'gas_price': 23.454550231263685, 'co2_price': 9.000180216361032, 'power_price': 33.766213440780206, 'gov_state': 2, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': 120266629.45559034}
# Action.RUN
# -213.84451913267912
# -675356.1004749537
# -228.00481717361498
#
#
# {'gas_price': 23.454550231263685, 'co2_price': 8.481470071413204, 'power_price': 36.287438192336595, 'gov_state': 3, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.MOTHBALLED: 1>, 'balance': 100911639.489299}
# Action.RUN
# -213.52282558282263
# 482394.84000748396
# 140.19164215359245
#
#
# {'gas_price': 28.246522813989095, 'co2_price': 8.733043955368462, 'power_price': 31.76485445919043, 'gov_state': 2, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.MOTHBALLED: 1>, 'balance': -1054049.8061688542}
# Action.DO_NOTHING
# -394.18960213309
# -144368.40149732074
# -63.031860047310325
#
#
# {'gas_price': 28.246522813989095, 'co2_price': 8.733043955368462, 'power_price': 33.766213440780206, 'gov_state': 1, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.MOTHBALLED: 1>, 'balance': -2880833.242528498}
# Action.DO_NOTHING
# -322.58862598992425
# -144301.48469718685
# -63.00751230634879
#
#
# {'gas_price': 30.10145474605831, 'co2_price': 8.733043955368462, 'power_price': 31.76485445919043, 'gov_state': 1, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.MOTHBALLED: 1>, 'balance': 78535566.46662545}
# Action.DO_NOTHING
# -563.8397156047395
# -288552.7840348929
# -112.25035522744761
#
#
# {'gas_price': 28.246522813989095, 'co2_price': 8.481470071413204, 'power_price': 33.766213440780206, 'gov_state': 1, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': 78535566.46662545}
# Action.DO_NOTHING
# -197.35075866631573
# -864193.4811359495
# -280.0114700687945
#
#
# {'gas_price': 28.246522813989095, 'co2_price': 8.884986856876514, 'power_price': 36.287438192336595, 'gov_state': 3, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -1054049.8061688542}
# Action.DO_NOTHING
# -360.01395524269424
# -864336.4616404136
# -280.0500760350875
#
#
# {'gas_price': 23.454550231263685, 'co2_price': 9.653631742200341, 'power_price': 33.766213440780206, 'gov_state': 3, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.MOTHBALLED: 1>, 'balance': 120266629.45559034}
# Action.RUN
# -233.4654603608463
# -49472.35641270876
# -25.820748678294667
#
#
# {'gas_price': 30.10145474605831, 'co2_price': 9.653631742200341, 'power_price': 36.7729205394648, 'gov_state': 1, 'plant_state': <PowerplantState.NOT_BUILT: 0>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': 100911639.489299}
# Action.DO_NOTHING
# -32.10308100240427
# -31.473608821630478
# -0.05601299380574736
#
#
# {'gas_price': 28.246522813989095, 'co2_price': 8.733043955368462, 'power_price': 44.81600427744746, 'gov_state': 1, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -1054049.8061688542}
# Action.RUN
# -84.29187908866754
# 264368.2237078545
# 86.64976763308239
#
#
# [ 35.19769173 -14.95989586  16.86087909 -81.49263689 243.73953611]
# 22
# {'gas_price': 17.324601128990693, 'co2_price': 9.426101220303114, 'power_price': 39.72155361379061, 'gov_state': 2, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': 88530245.62832525}
# Action.RUN
# 78.61934906034784
# 1003879.6598807573
# 251.96796235390397
#
#
# {'gas_price': 26.292973145732113, 'co2_price': 8.432865425378795, 'power_price': 31.507764968612182, 'gov_state': 3, 'plant_state': <PowerplantState.NOT_BUILT: 0>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -38861706.21516615}
# Action.DO_NOTHING
# -399.24696522123975
# -373.12800488620996
# -0.439759136951455
#
#
# {'gas_price': 24.58114794896053, 'co2_price': 9.536297503072173, 'power_price': 37.29145593463605, 'gov_state': 2, 'plant_state': <PowerplantState.NOT_BUILT: 0>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -59227704.638344035}
# Action.DO_NOTHING
# -68.56064123788609
# -64.07536564022303
# -0.10129217833519231
#
#
# {'gas_price': 26.292973145732113, 'co2_price': 8.687419780995109, 'power_price': 39.72155361379061, 'gov_state': 2, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': 88530245.62832525}
# Action.RUN
# 101.18722537515413
# -181173.65790075064
# -76.16332183129396
#
#
# {'gas_price': 23.068204107255163, 'co2_price': 8.687419780995109, 'power_price': 31.507764968612182, 'gov_state': 3, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -59227704.638344035}
# Action.MOTHBALL_CHANGE
# -110.26468436225133
# -2128103.051106885
# -593.3722226729176
#
#
# {'gas_price': 24.09323702870999, 'co2_price': 9.918426045972982, 'power_price': 37.29145593463605, 'gov_state': 3, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -71456622.25661576}
# Action.RUN
# -321.80859599297116
# -392010.5838639587
# -144.90437361735636
#
#
# {'gas_price': 24.58114794896053, 'co2_price': 9.918426045972982, 'power_price': 43.50328178829038, 'gov_state': 3, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -59227704.638344035}
# Action.RUN
# -5.236621502213666
# 865062.9504479915
# 223.68567359194662
#
#
# {'gas_price': 26.292973145732113, 'co2_price': 9.536297503072173, 'power_price': 37.29145593463605, 'gov_state': 3, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -38861706.21516615}
# Action.RUN
# -51.56291234566763
# -1306938.8273181617
# -395.2568304181472
#
#
# {'gas_price': 26.292973145732113, 'co2_price': 9.426101220303114, 'power_price': 39.72155361379061, 'gov_state': 4, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -71456622.25661576}
# Action.RUN
# -179.3424134020214
# -287810.5980553776
# -112.00970452946899
#
#
# {'gas_price': 17.324601128990693, 'co2_price': 8.432865425378795, 'power_price': 44.18492729882442, 'gov_state': 2, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': 88530245.62832525}
# Action.RUN
# 492.6755878005294
# 1790037.3624836802
# 400.2116039915076
#
#
# {'gas_price': 24.58114794896053, 'co2_price': 8.687419780995109, 'power_price': 31.507764968612182, 'gov_state': 4, 'plant_state': <PowerplantState.NOT_BUILT: 0>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -38861706.21516615}
# Action.DO_NOTHING
# -324.9303158826097
# -303.67319241911173
# -0.37040091077932114
#
#
# {'gas_price': 24.58114794896053, 'co2_price': 9.918426045972982, 'power_price': 37.29145593463605, 'gov_state': 3, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': 88530245.62832525}
# Action.MOTHBALL_CHANGE
# 167.23927499152737
# -1063836.0399264544
# -332.96269838520806
#
#
# {'gas_price': 24.09323702870999, 'co2_price': 8.687419780995109, 'power_price': 44.18492729882442, 'gov_state': 2, 'plant_state': <PowerplantState.NOT_BUILT: 0>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': 88530245.62832525}
# Action.DO_NOTHING
# 417.1452210032517
# 408.96590296924114
# 0.4890459656746169
#
#
# {'gas_price': 23.068204107255163, 'co2_price': 8.432865425378795, 'power_price': 39.72155361379061, 'gov_state': 4, 'plant_state': <PowerplantState.NOT_BUILT: 0>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -59227704.638344035}
# Action.DO_NOTHING
# 50.332314003853924
# 47.03954579681158
# 0.08669029797197493
#
#
# {'gas_price': 24.09323702870999, 'co2_price': 9.536297503072173, 'power_price': 43.50328178829038, 'gov_state': 2, 'plant_state': <PowerplantState.NOT_BUILT: 0>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -59227704.638344035}
# Action.DO_NOTHING
# 130.96767845918487
# 122.39969948679209
# 0.18630490163805605
#
#
# {'gas_price': 17.324601128990693, 'co2_price': 9.918426045972982, 'power_price': 37.29145593463605, 'gov_state': 2, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -71456622.25661576}
# Action.RUN
# 177.77984238542183
# 583139.8907782286
# 163.16169222367105
#
#
# {'gas_price': 24.09323702870999, 'co2_price': 8.687419780995109, 'power_price': 31.507764968612182, 'gov_state': 4, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -38861706.21516615}
# Action.MOTHBALL_CHANGE
# -204.78974490928073
# -2128191.3922849596
# -593.3927491772728
#
#
# {'gas_price': 23.068204107255163, 'co2_price': 8.432865425378795, 'power_price': 39.72155361379061, 'gov_state': 2, 'plant_state': <PowerplantState.NOT_BUILT: 0>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': 108205276.66710937}
# Action.DO_NOTHING
# 140.825446508325
# 138.06416322290897
# 0.20514681185049094
#
#
# {'gas_price': 23.068204107255163, 'co2_price': 9.426101220303114, 'power_price': 37.29145593463605, 'gov_state': 2, 'plant_state': <PowerplantState.NOT_BUILT: 0>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -38861706.21516615}
# Action.DO_NOTHING
# -80.60582251844356
# -75.33254440873861
# -0.11591835165641415
#
#
# {'gas_price': 24.58114794896053, 'co2_price': 9.426101220303114, 'power_price': 31.507764968612182, 'gov_state': 4, 'plant_state': <PowerplantState.STAGE_2: 2>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -71456622.25661576}
# Action.MOTHBALL_CHANGE
# -162.73525986680545
# -2128152.0890279114
# -593.3836168910004
#
#
# [  33.41023251 -126.20942797 -108.71185436  -42.73204975    0.        ]
# 21
# {'gas_price': 20.39865913451923, 'co2_price': 7.096202395741691, 'power_price': 36.12831193581473, 'gov_state': 1, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -129928784.2710872}
# Action.RUN
# 38.11030526439404
# 379252.4755074382
# 115.64922836141989
#
#
# {'gas_price': 20.614322871560887, 'co2_price': 9.63834407744207, 'power_price': 33.66665180668882, 'gov_state': 1, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -94146593.60622458}
# Action.RUN
# -51.07984751443172
# -372433.9186684936
# -138.84844558658583
#
#
# {'gas_price': 20.39865913451923, 'co2_price': 9.095314465081952, 'power_price': 42.76498162214822, 'gov_state': 1, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -82584818.01744014}
# Action.RUN
# 149.79372726460127
# 1047165.1493844092
# 260.62264261415794
#
#
# {'gas_price': 18.015489897718886, 'co2_price': 7.096202395741691, 'power_price': 30.344826587039588, 'gov_state': 1, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -94146593.60622458}
# Action.RUN
# -67.63107373155678
# -110491.86833560467
# -50.44002165603421
#
#
# {'gas_price': 23.674683721045138, 'co2_price': 7.096202395741691, 'power_price': 51.69818016562584, 'gov_state': 1, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -94146593.60622458}
# Action.RUN
# 452.76289218801696
# 2149953.485922694
# 463.38636565106685
#
#
# {'gas_price': 20.614322871560887, 'co2_price': 9.095314465081952, 'power_price': 33.66665180668882, 'gov_state': 1, 'plant_state': <PowerplantState.NOT_BUILT: 0>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -94146593.60622458}
# Action.DO_NOTHING
# 131.82389484473964
# 123.199901714921
# 0.1872786581957183
#
#
# {'gas_price': 25.013016084729152, 'co2_price': 9.292754449067665, 'power_price': 36.12831193581473, 'gov_state': 1, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -82584818.01744014}
# Action.RUN
# -145.84411922057072
# -601690.3410245925
# -207.08288168452333
#
#
# {'gas_price': 23.674683721045138, 'co2_price': 9.63834407744207, 'power_price': 36.12831193581473, 'gov_state': 1, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': 5495536.631847799}
# Action.RUN
# -145.04160717227202
# -458741.2818789277
# -165.18598087007473
# {'gas_price': 20.614322871560887, 'co2_price': 9.292754449067665, 'power_price': 36.12831193581473, 'gov_state': 1, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -129928784.2710872}
# Action.RUN
# 83.3644266718168
# 31935.69526593387
# 15.974272933340636
#
#
# {'gas_price': 20.39865913451923, 'co2_price': 7.096202395741691, 'power_price': 30.344826587039588, 'gov_state': 3, 'plant_state': <PowerplantState.STAGE_1: 1>, 'mothballed_state': <MothballedState.NORMAL: 0>, 'balance': -94146593.60622458}
# Action.RUN
# -131.54012774603217
# -453727.96652270854
# -163.68025413091559
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-be5f8d63e4c6> in <module>
# ----> 1 vfs = adp_algorithm_complete(1)
#
# ~/Desktop/MT/MTpython/src/gas_example/optimization/adp_algorithm.py in adp_algorithm_complete(loops_of_update)
#      19             if time_epoch != len(problem_setup.time_epochs) - 1:
#      20                 # print(f"{datetime.now()} time epoch: {time_epoch}")
# ---> 21                 update_vf_coef(vfs[time_epoch], vfs[time_epoch + 1], basis_functions, time_epoch)
#      22
#      23     return vfs
#
# ~/Desktop/MT/MTpython/src/gas_example/optimization/vf.py in update_vf_coef(current_vf, next_vf, basis_functions, time_epoch)
#      51     # print(f"{datetime.now()} Got sample_states, time epoch {time_epoch}")
#      52
# ---> 53     state_reward_pairs_raw = get_state_utility_pairs(sampled_states, time_epoch, next_vf)
#      54
#      55     # print(f"{datetime.now()} Got state_reward_pairs, size {len(state_reward_pairs_raw)}")
#
# ~/Desktop/MT/MTpython/src/gas_example/optimization/optimization.py in get_state_utility_pairs(sampled_states, epoch, future_vf)
#      25     for i, state in enumerate(sampled_states):
#      26         # When creating a random path, we need to also consider the various actions.
# ---> 27         action = get_best_action(state, INTEGRAL_SAMPLE_SIZE, epoch, future_vf)
#      28
#      29         new_state, fcf = state.get_new_state_and_fcf(action, epoch)
#
# ~/Desktop/MT/MTpython/src/gas_example/optimization/optimization.py in get_best_action(state, integral_sample_size, epoch, future_vf)
#      59         sample_integral_values = []
#      60         for i in range(integral_sample_size):
# ---> 61             new_state, fcf = state.get_new_state_and_fcf(action, epoch)
#      62
#      63             # This is utility, we need to make a money equivalent first.
#
# ~/Desktop/MT/MTpython/src/gas_example/simulation/state.py in get_new_state_and_fcf(self, action, epoch)
#      32         co2_price = get_next_price(self.co2_price, CO2_VOL)
#      33         power_price = get_next_price(self.power_price, get_pow_vol(self.gov_state))
# ---> 34         gov_state = get_next_gov_policy(self.gov_state, GOV_PROB_DOWN, GOV_PROB_UP)
#      35         plant_state = get_next_plant_state(self, action, epoch)
#      36         mothballed_state = get_next_mothballed_state(self, action)
#
# ~/Desktop/MT/MTpython/src/gas_example/simulation/evolution_models.py in get_next_gov_policy(gov_policy, negative_prob, positive_prob)
#       9     zero_prob = 1 - positive_prob - negative_prob
#      10
# ---> 11     movement = np.random.choice(np.arange(1, 4), p=[negative_prob, zero_prob, positive_prob, ]) - 2
#      12
#      13     if gov_policy + movement in range(1, 6):
#
# KeyboardInterrupt:

# %%
param_list = []
for vf in vfs: 
    param_list.append(vf.params)

# %%
df = pd.DataFrame.from_records(param_list).transpose()

# %%
df.index = ["\u03C6_1", 
            "\u03C6_2", 
            "\u03C6_3", 
            "\u03C6_4", 
            "\u03C6_5"]

# %%
pd.set_option('display.max_columns', 300)

# %%
df

# %%
df.to_csv(f"vfs_1.csv")

# %%
initial_state = State(24,9,39,1,PowerplantState.NOT_BUILT, MothballedState.NORMAL,0)

# %%
df_path = pd.read_csv("vfs_1.csv", index_col = [0])

# %%
df_path

# %%
list(df_path["0"])

# %%
Vf()

# %%
get_best_action(state, INTEGRAL_SAMPLE_SIZE, epoch, future_vf)

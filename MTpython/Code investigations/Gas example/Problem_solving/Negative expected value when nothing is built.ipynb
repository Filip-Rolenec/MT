# %% [markdown]
# # Negative values, when nothing is built.
# - We have always the option to do nothing.
# - Why is it then, that the model turns into negative values after some time periods?

# %%
import sys
import os

sys.path.append("/Users/filiprolenec/Desktop/MT/MTpython/src")

# %%
last_epochs = 30

# %%
from progressbar import progressbar

from gas_example.optimization.vf import create_vfs_time_list, update_vf_models
from gas_example.setup import TIME_EPOCHS
from gas_example.simulation.state import State
from gas_example.enum_types import PowerplantState




def adp_algorithm_complete():
    vfs = create_vfs_time_list()

    for time_epoch_left in progressbar(range(last_epochs)):
        time_epoch = TIME_EPOCHS - time_epoch_left-1
        # Last Vf value is zero, no money to be gained.
        if time_epoch != TIME_EPOCHS - 1:
            update_vf_models(vfs[time_epoch], vfs[time_epoch + 1])
    return vfs

# %%
vfs = adp_algorithm_complete()
# Out:
# N/A% (0 of 30) |                         | Elapsed Time: 0:00:00 ETA:  --:--:--
#   6% (2 of 30) |#                        | Elapsed Time: 0:00:10 ETA:   0:02:23
#   6% (2 of 30) |#                        | Elapsed Time: 0:00:10 ETA:   0:02:23
# Parameters([('x0', <Parameter 'x0', value=0.0, bounds=[-inf:inf]>), ('y0', <Parameter 'y0', value=0.0, bounds=[-inf:inf]>), ('k1', <Parameter 'k1', value=0, bounds=[-inf:inf]>), ('k2', <Parameter 'k2', value=0.0, bounds=[-inf:inf]>)])
# Parameters([('x0', <Parameter 'x0', value=0.0, bounds=[-inf:inf]>), ('y0', <Parameter 'y0', value=0.0, bounds=[-inf:inf]>), ('k1', <Parameter 'k1', value=0, bounds=[-inf:inf]>), ('k2', <Parameter 'k2', value=0.0, bounds=[-inf:inf]>)])
#  10% (3 of 30) |##                       | Elapsed Time: 0:00:26 ETA:   0:07:22
# Parameters([('x0', <Parameter 'x0', value=0.0, bounds=[-inf:inf]>), ('y0', <Parameter 'y0', value=0.0, bounds=[-inf:inf]>), ('k1', <Parameter 'k1', value=0, bounds=[-inf:inf]>), ('k2', <Parameter 'k2', value=0.0, bounds=[-inf:inf]>)])
# Parameters([('x0', <Parameter 'x0', value=0.0, bounds=[-inf:inf]>), ('y0', <Parameter 'y0', value=0.0, bounds=[-inf:inf]>), ('k1', <Parameter 'k1', value=0, bounds=[-inf:inf]>), ('k2', <Parameter 'k2', value=0.0, bounds=[-inf:inf]>)])
#  13% (4 of 30) |###                      | Elapsed Time: 0:00:45 ETA:   0:08:01
#  13% (4 of 30) |###                      | Elapsed Time: 0:00:45 ETA:   0:08:01
# Parameters([('x0', <Parameter 'x0', value=0.0, bounds=[-inf:inf]>), ('y0', <Parameter 'y0', value=0.0, bounds=[-inf:inf]>), ('k1', <Parameter 'k1', value=0, bounds=[-inf:inf]>), ('k2', <Parameter 'k2', value=0.0, bounds=[-inf:inf]>)])
# Parameters([('x0', <Parameter 'x0', value=0.0, bounds=[-inf:inf]>), ('y0', <Parameter 'y0', value=0.0, bounds=[-inf:inf]>), ('k1', <Parameter 'k1', value=0, bounds=[-inf:inf]>), ('k2', <Parameter 'k2', value=0.0, bounds=[-inf:inf]>)])
#  16% (5 of 30) |####                     | Elapsed Time: 0:01:02 ETA:   0:07:00
#  16% (5 of 30) |####                     | Elapsed Time: 0:01:02 ETA:   0:07:00
# Parameters([('x0', <Parameter 'x0', value=143.263878054297 +/- 0.591, bounds=[-inf:inf]>), ('y0', <Parameter 'y0', value=4.501167258742326e-11 +/- 15.6, bounds=[-inf:inf]>), ('k1', <Parameter 'k1', value=0 +/- 0.0562, bounds=[-inf:inf]>), ('k2', <Parameter 'k2', value=60.02604961309059 +/- 0.46, bounds=[-inf:inf]>)])
# Parameters([('x0', <Parameter 'x0', value=143.263878054297 +/- 0.591, bounds=[-inf:inf]>), ('y0', <Parameter 'y0', value=4.501167258742326e-11 +/- 15.6, bounds=[-inf:inf]>), ('k1', <Parameter 'k1', value=0 +/- 0.0562, bounds=[-inf:inf]>), ('k2', <Parameter 'k2', value=60.02604961309059 +/- 0.46, bounds=[-inf:inf]>)])
#  20% (6 of 30) |#####                    | Elapsed Time: 0:01:17 ETA:   0:06:20
#  20% (6 of 30) |#####                    | Elapsed Time: 0:01:17 ETA:   0:06:20
# Parameters([('x0', <Parameter 'x0', value=101.2221438518608 +/- 0.804, bounds=[-inf:inf]>), ('y0', <Parameter 'y0', value=-6.943741395531913e-08 +/- 18.5, bounds=[-inf:inf]>), ('k1', <Parameter 'k1', value=0 +/- 0.0649, bounds=[-inf:inf]>), ('k2', <Parameter 'k2', value=79.76096140497789 +/- 0.585, bounds=[-inf:inf]>)])
# Parameters([('x0', <Parameter 'x0', value=101.2221438518608 +/- 0.804, bounds=[-inf:inf]>), ('y0', <Parameter 'y0', value=-6.943741395531913e-08 +/- 18.5, bounds=[-inf:inf]>), ('k1', <Parameter 'k1', value=0 +/- 0.0649, bounds=[-inf:inf]>), ('k2', <Parameter 'k2', value=79.76096140497789 +/- 0.585, bounds=[-inf:inf]>)])
#  23% (7 of 30) |#####                    | Elapsed Time: 0:01:37 ETA:   0:07:26
# Parameters([('x0', <Parameter 'x0', value=84.93580413773626 +/- 0.997, bounds=[-inf:inf]>), ('y0', <Parameter 'y0', value=10.372102153626274 +/- 30.9, bounds=[-inf:inf]>), ('k1', <Parameter 'k1', value=0 +/- 0.13, bounds=[-inf:inf]>), ('k2', <Parameter 'k2', value=103.92864330485561 +/- 0.671, bounds=[-inf:inf]>)])
# Parameters([('x0', <Parameter 'x0', value=84.93580413773626 +/- 0.997, bounds=[-inf:inf]>), ('y0', <Parameter 'y0', value=10.372102153626274 +/- 30.9, bounds=[-inf:inf]>), ('k1', <Parameter 'k1', value=0 +/- 0.13, bounds=[-inf:inf]>), ('k2', <Parameter 'k2', value=103.92864330485561 +/- 0.671, bounds=[-inf:inf]>)])
#  26% (8 of 30) |######                   | Elapsed Time: 0:01:54 ETA:   0:06:12
# Parameters([('x0', <Parameter 'x0', value=68.82234216481645 +/- 0.558, bounds=[-inf:inf]>), ('y0', <Parameter 'y0', value=10.794015992188784 +/- 31.6, bounds=[-inf:inf]>), ('k1', <Parameter 'k1', value=0 +/- 0.133, bounds=[-inf:inf]>), ('k2', <Parameter 'k2', value=120.6345703661442 +/- 0.494, bounds=[-inf:inf]>)])
# Parameters([('x0', <Parameter 'x0', value=68.82234216481645 +/- 0.558, bounds=[-inf:inf]>), ('y0', <Parameter 'y0', value=10.794015992188784 +/- 31.6, bounds=[-inf:inf]>), ('k1', <Parameter 'k1', value=0 +/- 0.133, bounds=[-inf:inf]>), ('k2', <Parameter 'k2', value=120.6345703661442 +/- 0.494, bounds=[-inf:inf]>)])
#  30% (9 of 30) |#######                  | Elapsed Time: 0:02:10 ETA:   0:05:46
#  30% (9 of 30) |#######                  | Elapsed Time: 0:02:10 ETA:   0:05:46
# Parameters([('x0', <Parameter 'x0', value=62.64861318161838, bounds=[-inf:inf]>), ('y0', <Parameter 'y0', value=24.744052649506923, bounds=[-inf:inf]>), ('k1', <Parameter 'k1', value=0, bounds=[-inf:inf]>), ('k2', <Parameter 'k2', value=145.45773055736788, bounds=[-inf:inf]>)])
# Parameters([('x0', <Parameter 'x0', value=62.64861318161838, bounds=[-inf:inf]>), ('y0', <Parameter 'y0', value=24.744052649506923, bounds=[-inf:inf]>), ('k1', <Parameter 'k1', value=0, bounds=[-inf:inf]>), ('k2', <Parameter 'k2', value=145.45773055736788, bounds=[-inf:inf]>)])
#  33% (10 of 30) |########                | Elapsed Time: 0:02:27 ETA:   0:05:27
#  33% (10 of 30) |########                | Elapsed Time: 0:02:27 ETA:   0:05:27
# Parameters([('x0', <Parameter 'x0', value=54.277470369712354 +/- 0.743, bounds=[-inf:inf]>), ('y0', <Parameter 'y0', value=24.709156487026966 +/- 59.7, bounds=[-inf:inf]>), ('k1', <Parameter 'k1', value=0 +/- 0.249, bounds=[-inf:inf]>), ('k2', <Parameter 'k2', value=158.3164860425804 +/- 0.769, bounds=[-inf:inf]>)])
# Parameters([('x0', <Parameter 'x0', value=54.277470369712354 +/- 0.743, bounds=[-inf:inf]>), ('y0', <Parameter 'y0', value=24.709156487026966 +/- 59.7, bounds=[-inf:inf]>), ('k1', <Parameter 'k1', value=0 +/- 0.249, bounds=[-inf:inf]>), ('k2', <Parameter 'k2', value=158.3164860425804 +/- 0.769, bounds=[-inf:inf]>)])
#  36% (11 of 30) |########                | Elapsed Time: 0:02:41 ETA:   0:04:40
#  36% (11 of 30) |########                | Elapsed Time: 0:02:41 ETA:   0:04:40
# Parameters([('x0', <Parameter 'x0', value=49.67049213995541 +/- 0.445, bounds=[-inf:inf]>), ('y0', <Parameter 'y0', value=42.36843078272008 +/- 39.9, bounds=[-inf:inf]>), ('k1', <Parameter 'k1', value=0 +/- 0.166, bounds=[-inf:inf]>), ('k2', <Parameter 'k2', value=177.55162241960056 +/- 0.502, bounds=[-inf:inf]>)])
# Parameters([('x0', <Parameter 'x0', value=49.67049213995541 +/- 0.445, bounds=[-inf:inf]>), ('y0', <Parameter 'y0', value=42.36843078272008 +/- 39.9, bounds=[-inf:inf]>), ('k1', <Parameter 'k1', value=0 +/- 0.166, bounds=[-inf:inf]>), ('k2', <Parameter 'k2', value=177.55162241960056 +/- 0.502, bounds=[-inf:inf]>)])
#  40% (12 of 30) |#########               | Elapsed Time: 0:02:58 ETA:   0:04:54
# Parameters([('x0', <Parameter 'x0', value=45.265524391047634 +/- 0.616, bounds=[-inf:inf]>), ('y0', <Parameter 'y0', value=47.17397468900012 +/- 54.2, bounds=[-inf:inf]>), ('k1', <Parameter 'k1', value=0 +/- 0.198, bounds=[-inf:inf]>), ('k2', <Parameter 'k2', value=195.8301664783422 +/- 1.03, bounds=[-inf:inf]>)])
# Parameters([('x0', <Parameter 'x0', value=45.265524391047634 +/- 0.616, bounds=[-inf:inf]>), ('y0', <Parameter 'y0', value=47.17397468900012 +/- 54.2, bounds=[-inf:inf]>), ('k1', <Parameter 'k1', value=0 +/- 0.198, bounds=[-inf:inf]>), ('k2', <Parameter 'k2', value=195.8301664783422 +/- 1.03, bounds=[-inf:inf]>)])
#  43% (13 of 30) |##########              | Elapsed Time: 0:03:13 ETA:   0:04:20
# Parameters([('x0', <Parameter 'x0', value=43.58942187179101 +/- 0.54, bounds=[-inf:inf]>), ('y0', <Parameter 'y0', value=140.39831213683544 +/- 43, bounds=[-inf:inf]>), ('k1', <Parameter 'k1', value=0 +/- 0.172, bounds=[-inf:inf]>), ('k2', <Parameter 'k2', value=219.70612892978934 +/- 1.13, bounds=[-inf:inf]>)])
# Parameters([('x0', <Parameter 'x0', value=43.58942187179101 +/- 0.54, bounds=[-inf:inf]>), ('y0', <Parameter 'y0', value=140.39831213683544 +/- 43, bounds=[-inf:inf]>), ('k1', <Parameter 'k1', value=0 +/- 0.172, bounds=[-inf:inf]>), ('k2', <Parameter 'k2', value=219.70612892978934 +/- 1.13, bounds=[-inf:inf]>)])
#  46% (14 of 30) |###########             | Elapsed Time: 0:03:28 ETA:   0:03:57
#  46% (14 of 30) |###########             | Elapsed Time: 0:03:28 ETA:   0:03:57
# Parameters([('x0', <Parameter 'x0', value=35.908265898262755 +/- 0.276, bounds=[-inf:inf]>), ('y0', <Parameter 'y0', value=191.59847742247428 +/- 34.3, bounds=[-inf:inf]>), ('k1', <Parameter 'k1', value=0 +/- 0.155, bounds=[-inf:inf]>), ('k2', <Parameter 'k2', value=223.00042192246255 +/- 0.436, bounds=[-inf:inf]>)])
# Parameters([('x0', <Parameter 'x0', value=35.908265898262755 +/- 0.276, bounds=[-inf:inf]>), ('y0', <Parameter 'y0', value=191.59847742247428 +/- 34.3, bounds=[-inf:inf]>), ('k1', <Parameter 'k1', value=0 +/- 0.155, bounds=[-inf:inf]>), ('k2', <Parameter 'k2', value=223.00042192246255 +/- 0.436, bounds=[-inf:inf]>)])
#  50% (15 of 30) |############            | Elapsed Time: 0:03:43 ETA:   0:03:44
# Parameters([('x0', <Parameter 'x0', value=34.72122436262886 +/- 0.454, bounds=[-inf:inf]>), ('y0', <Parameter 'y0', value=243.9054064594355 +/- 51.5, bounds=[-inf:inf]>), ('k1', <Parameter 'k1', value=0 +/- 0.242, bounds=[-inf:inf]>), ('k2', <Parameter 'k2', value=241.94916099754488 +/- 0.934, bounds=[-inf:inf]>)])
# Parameters([('x0', <Parameter 'x0', value=34.72122436262886 +/- 0.454, bounds=[-inf:inf]>), ('y0', <Parameter 'y0', value=243.9054064594355 +/- 51.5, bounds=[-inf:inf]>), ('k1', <Parameter 'k1', value=0 +/- 0.242, bounds=[-inf:inf]>), ('k2', <Parameter 'k2', value=241.94916099754488 +/- 0.934, bounds=[-inf:inf]>)])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-bfaa56ea61d9> in <module>
# ----> 1 vfs = adp_algorithm_complete()
#
# <ipython-input-3-4abbb4ed017e> in adp_algorithm_complete()
#      16         # Last Vf value is zero, no money to be gained.
#      17         if time_epoch != TIME_EPOCHS - 1:
# ---> 18             update_vf_models(vfs[time_epoch], vfs[time_epoch + 1])
#      19     return vfs
#
# ~/Desktop/MT/MTpython/src/gas_example/optimization/vf.py in update_vf_models(current_vf, next_vf)
#      36 def update_vf_models(current_vf: Vf, next_vf: Vf):
#      37     sampled_states = get_state_sample()
# ---> 38     state_utility_pairs = get_state_utility_pairs(sampled_states, next_vf)
#      39
#      40     new_models = get_new_models(state_utility_pairs)
#
# ~/Desktop/MT/MTpython/src/gas_example/optimization/optimization.py in get_state_utility_pairs(sampled_states, future_vf)
#      27         if PRINT_DETAILS_GLOBAL:
#      28             print("Getting best action")
# ---> 29         action, exp_utility = get_best_action(state, future_vf)
#      30
#      31         state_utility_pairs[state] = exp_utility
#
# ~/Desktop/MT/MTpython/src/gas_example/optimization/optimization.py in get_best_action(state, future_vf, print_details)
#      42         sample_integral_dict = {}
#      43         for i in range(INTEGRAL_SAMPLE_SIZE):
# ---> 44             utility_realization = get_utility_realization(state, action, future_vf)
#      45             sample_integral_dict[i] = utility_realization
#      46
#
# ~/Desktop/MT/MTpython/src/gas_example/optimization/optimization.py in get_utility_realization(state, action, future_vf, print_details)
#      61
#      62 def get_utility_realization(state: State, action: Action, future_vf, print_details=False):
# ---> 63     new_state, fcf = state.get_new_state_and_fcf(action)
#      64     future_vf_utility = future_vf.compute_value(new_state)
#      65     future_vf_money_equivalent = INVERSE_UTILITY_FUNCTION(future_vf_utility)
#
# ~/Desktop/MT/MTpython/src/gas_example/simulation/state.py in get_new_state_and_fcf(self, action)
#      23
#      24     def get_new_state_and_fcf(self, action):
# ---> 25         gas_price = get_next_price(self.gas_price, GAS_VOL)
#      26         co2_price = get_next_price(self.co2_price, CO2_VOL)
#      27         power_price = get_next_price(self.power_price, POWER_VOL)
#
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-bfaa56ea61d9> in <module>
# ----> 1 vfs = adp_algorithm_complete()
#
# <ipython-input-3-4abbb4ed017e> in adp_algorithm_complete()
#      16         # Last Vf value is zero, no money to be gained.
#      17         if time_epoch != TIME_EPOCHS - 1:
# ---> 18             update_vf_models(vfs[time_epoch], vfs[time_epoch + 1])
#      19     return vfs
#
# ~/Desktop/MT/MTpython/src/gas_example/optimization/vf.py in update_vf_models(current_vf, next_vf)
#      36 def update_vf_models(current_vf: Vf, next_vf: Vf):
#      37     sampled_states = get_state_sample()
# ---> 38     state_utility_pairs = get_state_utility_pairs(sampled_states, next_vf)
#      39
#      40     new_models = get_new_models(state_utility_pairs)
#
# ~/Desktop/MT/MTpython/src/gas_example/optimization/optimization.py in get_state_utility_pairs(sampled_states, future_vf)
#      27         if PRINT_DETAILS_GLOBAL:
#      28             print("Getting best action")
# ---> 29         action, exp_utility = get_best_action(state, future_vf)
#      30
#      31         state_utility_pairs[state] = exp_utility
#
# ~/Desktop/MT/MTpython/src/gas_example/optimization/optimization.py in get_best_action(state, future_vf, print_details)
#      42         sample_integral_dict = {}
#      43         for i in range(INTEGRAL_SAMPLE_SIZE):
# ---> 44             utility_realization = get_utility_realization(state, action, future_vf)
#      45             sample_integral_dict[i] = utility_realization
#      46
#
# ~/Desktop/MT/MTpython/src/gas_example/optimization/optimization.py in get_utility_realization(state, action, future_vf, print_details)
#      61
#      62 def get_utility_realization(state: State, action: Action, future_vf, print_details=False):
# ---> 63     new_state, fcf = state.get_new_state_and_fcf(action)
#      64     future_vf_utility = future_vf.compute_value(new_state)
#      65     future_vf_money_equivalent = INVERSE_UTILITY_FUNCTION(future_vf_utility)
#
# ~/Desktop/MT/MTpython/src/gas_example/simulation/state.py in get_new_state_and_fcf(self, action)
#      23
#      24     def get_new_state_and_fcf(self, action):
# ---> 25         gas_price = get_next_price(self.gas_price, GAS_VOL)
#      26         co2_price = get_next_price(self.co2_price, CO2_VOL)
#      27         power_price = get_next_price(self.power_price, POWER_VOL)
#
# KeyboardInterrupt:

# %%
state = State(300, 200, 200, PowerplantState.NOT_BUILT, 0)

# %%
vfs[290].compute_value(state)

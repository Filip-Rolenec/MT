# %% [markdown]
# # ADP simulation
# - In the previous notebook we have found a better model for the value functions.
# - Now we want to implement the decision making that is based on such vfs approximations and fix potential bugs.
#
# - When approved, this strategy will be run together with the baselines in the next notebook.

# %%
import sys
import os

sys.path.append("/Users/filiprolenec/Desktop/MT/MTpython/src")

import pandas as pd
from gas_example.optimization_2.vf import Vf
from gas_example.enum_types import PowerplantState
from gas_example.simulation.state import State
from gas_example.optimization_2.optimization import get_best_action

import numpy as np
import matplotlib.pyplot as plt
from gas_example.optimization_2.adp_model import piecewise_linear

# %% [markdown]
# # 1. Decision making based on vf parameters.

# %%
def get_vfs_from_path(path): 
    df_vfs = pd.read_pickle(path)
    
    vfs = []
    for column in df_vfs: 
        vf = Vf()
        vf.set_params(df_vfs[column])
        vfs.append(vf)
        
    return vfs

# %%
vfs = get_vfs_from_path("saved_vfs/vfs_12_20_2020.pkl")

# %%
init_state=State(10, 25, 44, PowerplantState.NOT_BUILT, 110000000)
time_epoch = 0
get_best_action(init_state, time_epoch,vfs[time_epoch+1])
# Out:
# <Action.DO_NOTHING: 0>

# %% [markdown]
# ### 20.12.
# - There is a problem with consistency, but it is caused by weird range of sampled values for spark prices.

# %% [markdown]
# # 2. Run and individual decisions making sense

# %%
vfs = get_vfs_from_path("vfs.csv")

# %%
state = init_state

for i in range(299): 
    action = get_best_action(state, i, vfs[i + 1], True)
    print(action)
    state, fcf = state.get_new_state_and_fcf(action, i)
    print(fcf)
# Out:
# {'gas_price': 10, 'co2_price': 25, 'power_price': 60, 'plant_state': <PowerplantState.NOT_BUILT: 0>, 'balance': 110000000}
# Spark: 19
# {<Action.DO_NOTHING: 0>: 1288.8348, <Action.IDLE_AND_BUILD: 3>: -31563.077100000006}
#
#
# Action.DO_NOTHING
# 0
# {'gas_price': 9.967859893622034, 'co2_price': 25.375677431750212, 'power_price': 64.4584762271659, 'plant_state': <PowerplantState.NOT_BUILT: 0>, 'balance': 110181674}
# Spark: 23.114938901793657
# {<Action.DO_NOTHING: 0>: 1483.4550000000004, <Action.IDLE_AND_BUILD: 3>: -9296.6351}
#
#
# Action.DO_NOTHING
# 0
# {'gas_price': 10.073537618862147, 'co2_price': 25.261886487915152, 'power_price': 61.81047551478889, 'plant_state': <PowerplantState.NOT_BUILT: 0>, 'balance': 110363648}
# Spark: 20.475051408011595
# {<Action.DO_NOTHING: 0>: 1404.2714999999998, <Action.IDLE_AND_BUILD: 3>: -2727.3545}
#
#
# Action.DO_NOTHING
# 0
# {'gas_price': 10.58625398681705, 'co2_price': 25.526207840081113, 'power_price': 58.28725702767517, 'plant_state': <PowerplantState.NOT_BUILT: 0>, 'balance': 110545923}
# Spark: 16.174795200777005
# {<Action.DO_NOTHING: 0>: 1203.8647, <Action.IDLE_AND_BUILD: 3>: -5169.1804}
#
#
# Action.DO_NOTHING
# 0
# {'gas_price': 10.59938151364265, 'co2_price': 26.246394496465516, 'power_price': 59.9432914285749, 'plant_state': <PowerplantState.NOT_BUILT: 0>, 'balance': 110728499}
# Spark: 17.097515418466735
# {<Action.DO_NOTHING: 0>: 1264.6483, <Action.IDLE_AND_BUILD: 3>: -4505.5294}
#
#
# Action.DO_NOTHING
# 0
# {'gas_price': 10.700099663264027, 'co2_price': 25.78182266877461, 'power_price': 64.1384044368081, 'plant_state': <PowerplantState.NOT_BUILT: 0>, 'balance': 110911376}
# Spark: 21.656482104769466
# {<Action.DO_NOTHING: 0>: 1627.5439999999999, <Action.IDLE_AND_BUILD: 3>: -9289.033000000001}
#
#
# Action.DO_NOTHING
# 0
# {'gas_price': 10.632854030634839, 'co2_price': 25.839592605297145, 'power_price': 65.92003821462988, 'plant_state': <PowerplantState.NOT_BUILT: 0>, 'balance': 111094555}
# Spark: 23.447591578697903
# {<Action.DO_NOTHING: 0>: 1844.1937, <Action.IDLE_AND_BUILD: 3>: -3053.8845999999994}
#
#
# Action.DO_NOTHING
# 0
# {'gas_price': 10.853855271145038, 'co2_price': 25.882379810745913, 'power_price': 67.16743030719914, 'plant_state': <PowerplantState.NOT_BUILT: 0>, 'balance': 111278037}
# Spark: 24.431195225308187
# {<Action.DO_NOTHING: 0>: 1960.9762000000003, <Action.IDLE_AND_BUILD: 3>: -473.5036}
#
#
# Action.DO_NOTHING
# 0
# {'gas_price': 10.985223019913828, 'co2_price': 25.06731722122964, 'power_price': 64.55063105296172, 'plant_state': <PowerplantState.NOT_BUILT: 0>, 'balance': 111461822}
# Spark: 22.498090811818248
# {<Action.DO_NOTHING: 0>: 1856.2861000000005, <Action.IDLE_AND_BUILD: 3>: -6159.9998}
#
#
# Action.DO_NOTHING
# 0
# {'gas_price': 11.191804176326695, 'co2_price': 25.434271853551138, 'power_price': 68.48888631721026, 'plant_state': <PowerplantState.NOT_BUILT: 0>, 'balance': 111645910}
# Spark: 25.862810287332426
# {<Action.DO_NOTHING: 0>: 2163.3216, <Action.IDLE_AND_BUILD: 3>: -63.55319999999999}
#
#
# Action.DO_NOTHING
# 0
# {'gas_price': 11.414900029522824, 'co2_price': 24.811158752861633, 'power_price': 65.79481164084737, 'plant_state': <PowerplantState.NOT_BUILT: 0>, 'balance': 111830302}
# Spark: 23.568752858462915
# {<Action.DO_NOTHING: 0>: 2033.0022999999994, <Action.IDLE_AND_BUILD: 3>: -324.95949999999993}
#
#
# Action.DO_NOTHING
# 0
# {'gas_price': 11.238379104656014, 'co2_price': 24.173078497324656, 'power_price': 68.94510478260489, 'plant_state': <PowerplantState.NOT_BUILT: 0>, 'balance': 112014999}
# Spark: 27.53364718062422
# {<Action.DO_NOTHING: 0>: 5007.751499999999, <Action.IDLE_AND_BUILD: 3>: 1763.0858999999996}
#
#
# Action.DO_NOTHING
# 0
# {'gas_price': 11.456492116813358, 'co2_price': 24.61924092636532, 'power_price': 68.0730953328307, 'plant_state': <PowerplantState.NOT_BUILT: 0>, 'balance': 112200001}
# Spark: 25.997362289652024
# {<Action.DO_NOTHING: 0>: 4945.4233, <Action.IDLE_AND_BUILD: 3>: -1316.4584}
#
#
# Action.DO_NOTHING
# 0
# {'gas_price': 11.55711334820823, 'co2_price': 25.75468053010405, 'power_price': 69.89511524357728, 'plant_state': <PowerplantState.NOT_BUILT: 0>, 'balance': 112385308}
# Spark: 26.583321365264993
# {<Action.DO_NOTHING: 0>: 5597.261400000001, <Action.IDLE_AND_BUILD: 3>: 171.2119}
#
#
# Action.DO_NOTHING
# 0
# {'gas_price': 11.106422668320745, 'co2_price': 25.282541357159065, 'power_price': 74.34914306464643, 'plant_state': <PowerplantState.NOT_BUILT: 0>, 'balance': 112570921}
# Spark: 31.96017903916662
# {<Action.DO_NOTHING: 0>: 9613.709599999998, <Action.IDLE_AND_BUILD: 3>: 4531.1786}
#
#
# Action.DO_NOTHING
# 0
# {'gas_price': 11.706207010300334, 'co2_price': 24.865063347429697, 'power_price': 72.11686816424118, 'plant_state': <PowerplantState.NOT_BUILT: 0>, 'balance': 112756841}
# Spark: 29.545597806511154
# {<Action.DO_NOTHING: 0>: 7757.7345000000005, <Action.IDLE_AND_BUILD: 3>: 7901.139500000001}
#
#
# Action.IDLE_AND_BUILD
# -65000000
# {'gas_price': 11.92551486500053, 'co2_price': 24.666724917808903, 'power_price': 74.92564226739559, 'plant_state': <PowerplantState.STAGE_1: 1>, 'balance': 47835715}
# Spark: 32.33340248458615
# {<Action.DO_NOTHING: 0>: 15023.107200000002, <Action.RUN: 1>: 15281.134399999999, <Action.RUN_AND_BUILD: 2>: 16520.390799999997, <Action.IDLE_AND_BUILD: 3>: 16405.6892, <Action.MOTHBALL_CHANGE: 4>: 14645.6599}
#
#
# Action.RUN_AND_BUILD
# -61207990.042219594
# {'gas_price': 11.888420444932178, 'co2_price': 25.03968353802929, 'power_price': 73.57152438403695, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': -13447884}
# Spark: 30.643420401075474
# {<Action.DO_NOTHING: 0>: 20032.610299999997, <Action.RUN: 1>: 20632.4404, <Action.MOTHBALL_CHANGE: 4>: 19386.0598}
#
#
# Action.RUN
# 7097305.075509736
# {'gas_price': 12.335035223468296, 'co2_price': 24.188770661196195, 'power_price': 80.11690992223089, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': -6386486}
# Spark: 37.5931040375664
# {<Action.DO_NOTHING: 0>: 26248.761900000005, <Action.RUN: 1>: 26577.107499999995, <Action.MOTHBALL_CHANGE: 4>: 26319.294600000005}
#
#
# Action.RUN
# 9098813.962819124
# {'gas_price': 12.37041845836797, 'co2_price': 23.564427893348476, 'power_price': 76.80655564359887, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 2716808}
# Spark: 34.87170929188242
# {<Action.DO_NOTHING: 0>: 23316.8275, <Action.RUN: 1>: 24281.396099999994, <Action.MOTHBALL_CHANGE: 4>: 23409.076700000005}
#
#
# Action.RUN
# 8315052.2760621365
# {'gas_price': 12.364995263496457, 'co2_price': 23.229764226537576, 'power_price': 77.12064499371229, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 11050080}
# Spark: 35.52588550367825
# {<Action.DO_NOTHING: 0>: 23899.7276, <Action.RUN: 1>: 24652.762399999996, <Action.MOTHBALL_CHANGE: 4>: 24099.441999999992}
#
#
# Action.RUN
# 8503455.025059337
# {'gas_price': 12.86154493938859, 'co2_price': 23.113673343129236, 'power_price': 78.49171107804258, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 19585829}
# Spark: 36.516492795524755
# {<Action.DO_NOTHING: 0>: 24252.085499999997, <Action.RUN: 1>: 25264.1631, <Action.MOTHBALL_CHANGE: 4>: 24076.592200000003}
#
#
# Action.RUN
# 8788749.92511113
# {'gas_price': 12.358928045868701, 'co2_price': 23.326229428437582, 'power_price': 80.99279489883314, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 28421442}
# Spark: 39.30763742452685
# {<Action.DO_NOTHING: 0>: 26977.353400000004, <Action.RUN: 1>: 26948.7603, <Action.MOTHBALL_CHANGE: 4>: 26997.3068}
#
#
# Action.MOTHBALL_CHANGE
# -2128000
# {'gas_price': 12.61722496599995, 'co2_price': 23.586734437871712, 'power_price': 76.55807858495749, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 26336868}
# Spark: 34.35411918108582
# {<Action.DO_NOTHING: 0>: 22692.7906, <Action.RUN: 1>: 23448.551899999995, <Action.MOTHBALL_CHANGE: 4>: 22815.363299999997}
#
#
# Action.RUN
# 8165986.3241527155
# {'gas_price': 12.504115162185252, 'co2_price': 23.411979566574058, 'power_price': 74.43754809318848, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 34559839}
# Spark: 32.52145336442917
# {<Action.DO_NOTHING: 0>: 21412.139699999996, <Action.RUN: 1>: 22368.42030000001, <Action.MOTHBALL_CHANGE: 4>: 21670.882700000006}
#
#
# Action.RUN
# 7638178.568955602
# {'gas_price': 12.39809488917405, 'co2_price': 23.86631574523883, 'power_price': 83.70095694289058, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 42267711}
# Spark: 41.4365463084777
# {<Action.DO_NOTHING: 0>: 28490.001300000004, <Action.RUN: 1>: 28797.186999999998, <Action.MOTHBALL_CHANGE: 4>: 28595.4973}
#
#
# Action.RUN
# 10205725.336841578
# {'gas_price': 12.238001100352538, 'co2_price': 24.339660880691845, 'power_price': 81.30153545120532, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 52560100}
# Spark: 38.72387347016094
# {<Action.DO_NOTHING: 0>: 26365.7901, <Action.RUN: 1>: 26669.3992, <Action.MOTHBALL_CHANGE: 4>: 25737.691600000002}
#
#
# Action.RUN
# 9424475.55940635
# {'gas_price': 13.099826853259446, 'co2_price': 24.322168394536003, 'power_price': 79.63499849050349, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 62086948}
# Spark: 36.21300324270804
# {<Action.DO_NOTHING: 0>: 24350.830000000005, <Action.RUN: 1>: 25111.4723, <Action.MOTHBALL_CHANGE: 4>: 23875.6263}
#
#
# Action.RUN
# 8701344.933899917
# {'gas_price': 13.403340127222332, 'co2_price': 24.15401426864465, 'power_price': 81.73323546364611, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 70905206}
# Spark: 38.17588106777913
# {<Action.DO_NOTHING: 0>: 25767.6883, <Action.RUN: 1>: 26395.7991, <Action.MOTHBALL_CHANGE: 4>: 26126.3031}
#
#
# Action.RUN
# 9266653.747520389
# {'gas_price': 13.17456043158194, 'co2_price': 24.563922903367732, 'power_price': 83.18236343717454, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 80304270}
# Spark: 39.443880102224874
# {<Action.DO_NOTHING: 0>: 28000.665500000003, <Action.RUN: 1>: 28601.760499999997, <Action.MOTHBALL_CHANGE: 4>: 28003.3882}
#
#
# Action.RUN
# 9631837.469440764
# {'gas_price': 13.289085640653507, 'co2_price': 23.94486123135848, 'power_price': 85.58005692135849, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 90084644}
# Spark: 42.34611004934651
# {<Action.DO_NOTHING: 0>: 29773.2296, <Action.RUN: 1>: 31191.8694, <Action.MOTHBALL_CHANGE: 4>: 29734.927600000003}
#
#
# Action.RUN
# 10467679.694211794
# {'gas_price': 13.725772253810543, 'co2_price': 24.37572258637583, 'power_price': 84.08460430432517, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 100718394}
# Spark: 39.98310946413879
# {<Action.DO_NOTHING: 0>: 27510.363599999997, <Action.RUN: 1>: 27865.3778, <Action.MOTHBALL_CHANGE: 4>: 28124.106299999996}
#
#
# Action.MOTHBALL_CHANGE
# -2128000
# {'gas_price': 13.92667927247526, 'co2_price': 24.016680807306088, 'power_price': 87.41713831275737, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 98753224}
# Spark: 43.473778232976024
# {<Action.DO_NOTHING: 0>: 30052.336, <Action.RUN: 1>: 31132.4366, <Action.MOTHBALL_CHANGE: 4>: 30708.125599999996}
#
#
# Action.RUN
# 10792448.131097093
# {'gas_price': 13.806834547608648, 'co2_price': 24.091001957005147, 'power_price': 86.23006214270286, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 109726596}
# Spark: 42.33222563808907
# {<Action.DO_NOTHING: 0>: 28585.307200000003, <Action.RUN: 1>: 29877.3236, <Action.MOTHBALL_CHANGE: 4>: 28911.910599999996}
#
#
# Action.RUN
# 10463680.983769652
# {'gas_price': 12.819851468074816, 'co2_price': 24.027107675837566, 'power_price': 88.33042016402588, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 120388781}
# Spark: 45.483461020113495
# {<Action.DO_NOTHING: 0>: 32229.0393, <Action.RUN: 1>: 32356.471299999997, <Action.MOTHBALL_CHANGE: 4>: 31455.6933}
#
#
# Action.RUN
# 11371236.773792686
# {'gas_price': 12.378781301681261, 'co2_price': 23.96213249689546, 'power_price': 92.2516198966021, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 131977630}
# Spark: 49.91070609802537
# {<Action.DO_NOTHING: 0>: 35610.263499999994, <Action.RUN: 1>: 36184.943100000004, <Action.MOTHBALL_CHANGE: 4>: 34946.3597}
#
#
# Action.RUN
# 12646283.356231308
# {'gas_price': 12.807351852165121, 'co2_price': 23.687466411050984, 'power_price': 92.3549045544216, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 144862772}
# Spark: 49.8600862912055
# {<Action.DO_NOTHING: 0>: 35462.5342, <Action.RUN: 1>: 35187.0013, <Action.MOTHBALL_CHANGE: 4>: 34549.509300000005}
#
#
# Action.DO_NOTHING
# -1728000
# {'gas_price': 13.074733040988301, 'co2_price': 24.034812534257316, 'power_price': 92.59445994183106, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 143371171}
# Spark: 49.48491436658545
# {<Action.DO_NOTHING: 0>: 34303.715200000006, <Action.RUN: 1>: 34688.349500000004, <Action.MOTHBALL_CHANGE: 4>: 34141.8996}
#
#
# Action.RUN
# 12523655.337576611
# {'gas_price': 13.018545235190253, 'co2_price': 23.590592374135742, 'power_price': 98.2039583852707, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 156152299}
# Spark: 55.594820775944704
# {<Action.DO_NOTHING: 0>: 37771.507600000004, <Action.RUN: 1>: 39140.85660000001, <Action.MOTHBALL_CHANGE: 4>: 37600.124299999996}
#
#
# Action.RUN
# 14283308.383472076
# {'gas_price': 12.916651794713921, 'co2_price': 23.668787951780352, 'power_price': 94.55354425668159, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 170717096}
# Spark: 51.96810451018731
# {<Action.DO_NOTHING: 0>: 35878.13710000001, <Action.RUN: 1>: 36761.417799999996, <Action.MOTHBALL_CHANGE: 4>: 36439.775799999996}
#
#
# Action.RUN
# 13238814.098933946
# {'gas_price': 12.711347557037858, 'co2_price': 23.806628213080664, 'power_price': 95.16280060811424, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 184259728}
# Spark: 52.64482483799573
# {<Action.DO_NOTHING: 0>: 37222.5126, <Action.RUN: 1>: 37913.313200000004, <Action.MOTHBALL_CHANGE: 4>: 37590.3401}
#
#
# Action.RUN
# 13433709.55334277
# {'gas_price': 13.223962613660015, 'co2_price': 23.939328306709452, 'power_price': 94.85610021855146, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 198019944}
# Spark: 51.69280929818199
# {<Action.DO_NOTHING: 0>: 36880.3912, <Action.RUN: 1>: 38148.951, <Action.MOTHBALL_CHANGE: 4>: 37573.9221}
#
#
# Action.RUN
# 13159529.077876413
# {'gas_price': 13.278982363156917, 'co2_price': 24.4976339494832, 'power_price': 90.01602338776584, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 211528253}
# Spark: 46.239407075125726
# {<Action.DO_NOTHING: 0>: 32876.1276, <Action.RUN: 1>: 34150.4084, <Action.MOTHBALL_CHANGE: 4>: 33019.4702}
#
#
# Action.RUN
# 11588949.23763621
# {'gas_price': 12.59205807390109, 'co2_price': 24.410818195935438, 'power_price': 91.58397689782277, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 223485698}
# Spark: 48.581100627986245
# {<Action.DO_NOTHING: 0>: 35333.679, <Action.RUN: 1>: 36892.649000000005, <Action.MOTHBALL_CHANGE: 4>: 35853.1158}
#
#
# Action.RUN
# 12263356.980860038
# {'gas_price': 12.879274173230389, 'co2_price': 23.927240414814236, 'power_price': 86.98842081323463, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 236138414}
# Spark: 44.181906225190005
# {<Action.DO_NOTHING: 0>: 31260.139699999992, <Action.RUN: 1>: 32583.860099999998, <Action.MOTHBALL_CHANGE: 4>: 31440.684899999993}
#
#
# Action.RUN
# 10996388.992854722
# {'gas_price': 12.580549961048279, 'co2_price': 22.89653650141285, 'power_price': 83.50846693095095, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 247542966}
# Spark: 42.031380468489814
# {<Action.DO_NOTHING: 0>: 29853.068699999993, <Action.RUN: 1>: 31085.541100000002, <Action.MOTHBALL_CHANGE: 4>: 29721.995000000006}
#
#
# Action.RUN
# 10377037.574925067
# {'gas_price': 11.974944755552153, 'co2_price': 22.32579823392565, 'power_price': 83.34797089201159, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 258345979}
# Spark: 43.047227902533784
# {<Action.DO_NOTHING: 0>: 31811.1003, <Action.RUN: 1>: 32405.5811, <Action.MOTHBALL_CHANGE: 4>: 31243.245000000006}
#
#
# Action.RUN
# 10669601.63592973
# {'gas_price': 12.730781024152964, 'co2_price': 22.429084992595467, 'power_price': 82.38887415589843, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 269459882}
# Spark: 41.22900813915001
# {<Action.DO_NOTHING: 0>: 30333.9473, <Action.RUN: 1>: 31713.651300000005, <Action.MOTHBALL_CHANGE: 4>: 29980.0531}
#
#
# Action.RUN
# 10145954.344075203
# {'gas_price': 12.21870356314038, 'co2_price': 22.517462854350168, 'power_price': 87.85584672066878, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 280067628}
# Spark: 47.11968030317823
# {<Action.DO_NOTHING: 0>: 35334.467599999996, <Action.RUN: 1>: 36368.736600000004, <Action.MOTHBALL_CHANGE: 4>: 35127.0536}
#
#
# Action.RUN
# 11842467.92731533
# {'gas_price': 12.101760769299123, 'co2_price': 23.009465906584524, 'power_price': 87.54361715283729, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 292392209}
# Spark: 46.43239047695364
# {<Action.DO_NOTHING: 0>: 35616.9176, <Action.RUN: 1>: 36877.0647, <Action.MOTHBALL_CHANGE: 4>: 35265.798899999994}
#
#
# Action.RUN
# 11644528.457362648
# {'gas_price': 12.238494485055867, 'co2_price': 23.062063763184117, 'power_price': 91.81924178038172, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 304538879}
# Spark: 50.518683532141736
# {<Action.DO_NOTHING: 0>: 38917.527700000006, <Action.RUN: 1>: 39650.6661, <Action.MOTHBALL_CHANGE: 4>: 38664.083000000006}
#
#
# Action.RUN
# 12821380.85725682
# {'gas_price': 11.725695348127974, 'co2_price': 23.550265467915256, 'power_price': 89.41202148878239, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 317884406}
# Spark: 48.13606067273916
# {<Action.DO_NOTHING: 0>: 36580.1012, <Action.RUN: 1>: 37206.97319999999, <Action.MOTHBALL_CHANGE: 4>: 36222.8175}
#
#
# Action.RUN
# 12135185.473748878
# {'gas_price': 11.682078380489108, 'co2_price': 24.41642304597877, 'power_price': 87.18704026931198, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 330564646}
# Spark: 45.088538842844095
# {<Action.DO_NOTHING: 0>: 33029.2574, <Action.RUN: 1>: 34267.4736, <Action.MOTHBALL_CHANGE: 4>: 33268.777200000004}
#
#
# Action.RUN
# 11257499.186739098
# {'gas_price': 11.79647829504815, 'co2_price': 25.28692370639021, 'power_price': 93.11973754520923, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 342386692}
# Spark: 50.036335543770875
# {<Action.DO_NOTHING: 0>: 36761.3575, <Action.RUN: 1>: 37760.49340000001, <Action.MOTHBALL_CHANGE: 4>: 37143.556500000006}
#
#
# Action.RUN
# 12682464.636606012
# {'gas_price': 11.964755520844083, 'co2_price': 24.701605607772304, 'power_price': 92.94249180344177, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 355655582}
# Spark: 50.27613067482538
# {<Action.DO_NOTHING: 0>: 36952.74629999999, <Action.RUN: 1>: 37988.2576, <Action.MOTHBALL_CHANGE: 4>: 37271.393}
#
#
# Action.RUN
# 12751525.63434971
# {'gas_price': 11.729240283011192, 'co2_price': 23.408512893472853, 'power_price': 94.46003086132846, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 369015562}
# Spark: 53.32227768484441
# {<Action.DO_NOTHING: 0>: 39678.089, <Action.RUN: 1>: 40569.947, <Action.MOTHBALL_CHANGE: 4>: 39247.9951}
#
#
# Action.RUN
# 13628815.97323519
# {'gas_price': 11.846292464129457, 'co2_price': 23.262824866949156, 'power_price': 93.86498247056075, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 383276346}
# Spark: 52.75586513948213
# {<Action.DO_NOTHING: 0>: 39275.1478, <Action.RUN: 1>: 40286.2679, <Action.MOTHBALL_CHANGE: 4>: 39367.730800000005}
#
#
# Action.RUN
# 13465689.160170853
# {'gas_price': 11.107123920841323, 'co2_price': 23.386263329283, 'power_price': 96.09882575672937, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 397397287}
# Spark: 55.60543850660505
# {<Action.DO_NOTHING: 0>: 42165.4098, <Action.RUN: 1>: 43908.475099999996, <Action.MOTHBALL_CHANGE: 4>: 42072.7031}
#
#
# Action.RUN
# 14286366.289902255
# {'gas_price': 11.127622219715278, 'co2_price': 23.16229117977953, 'power_price': 90.73086782774025, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 412363582}
# Spark: 50.44095442824545
# {<Action.DO_NOTHING: 0>: 38767.864499999996, <Action.RUN: 1>: 39217.1835, <Action.MOTHBALL_CHANGE: 4>: 38824.4461}
#
#
# Action.RUN
# 12798994.87533469
# {'gas_price': 11.312605605955731, 'co2_price': 23.383977409329738, 'power_price': 93.0452682262557, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 425864767}
# Spark: 52.34868521097024
# {<Action.DO_NOTHING: 0>: 40385.4837, <Action.RUN: 1>: 41451.543300000005, <Action.MOTHBALL_CHANGE: 4>: 40771.1691}
#
#
# Action.RUN
# 13348421.340759428
# {'gas_price': 10.372321694716103, 'co2_price': 23.03466326593561, 'power_price': 88.26936627878096, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 439938585}
# Spark: 48.86238131812925
# {<Action.DO_NOTHING: 0>: 37976.015699999996, <Action.RUN: 1>: 38591.8187, <Action.MOTHBALL_CHANGE: 4>: 37727.33119999999}
#
#
# Action.RUN
# 12344365.819621226
# {'gas_price': 10.870424685981138, 'co2_price': 23.039693322589585, 'power_price': 90.98616913022994, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 453029933}
# Spark: 51.07605112165922
# {<Action.DO_NOTHING: 0>: 39257.231199999995, <Action.RUN: 1>: 40276.0434, <Action.MOTHBALL_CHANGE: 4>: 38860.264800000004}
#
#
# Action.RUN
# 12981902.723037856
# {'gas_price': 10.21344896945965, 'co2_price': 22.91073138138575, 'power_price': 92.66846419385597, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 466781492}
# Spark: 53.54428384301056
# {<Action.DO_NOTHING: 0>: 41134.0051, <Action.RUN: 1>: 42084.6291, <Action.MOTHBALL_CHANGE: 4>: 41994.693900000006}
#
#
# Action.RUN
# 13692753.746787041
# {'gas_price': 10.640423431256158, 'co2_price': 21.946530195139882, 'power_price': 90.24438424592074, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 481267788}
# Spark: 51.657430619524696
# {<Action.DO_NOTHING: 0>: 40037.7961, <Action.RUN: 1>: 40759.520699999994, <Action.MOTHBALL_CHANGE: 4>: 39483.7863}
#
#
# Action.RUN
# 13149340.018423112
# {'gas_price': 10.544053458647037, 'co2_price': 22.14473402183203, 'power_price': 88.32688051679875, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 495233698}
# Spark: 49.638093036319695
# {<Action.DO_NOTHING: 0>: 37614.177800000005, <Action.RUN: 1>: 38261.3394, <Action.MOTHBALL_CHANGE: 4>: 37959.5344}
#
#
# Action.RUN
# 12567770.794460073
# {'gas_price': 10.538060972438853, 'co2_price': 21.889013841225974, 'power_price': 84.5928873813071, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 508640144}
# Spark: 46.16581256764226
# {<Action.DO_NOTHING: 0>: 33861.63480000001, <Action.RUN: 1>: 35501.8762, <Action.MOTHBALL_CHANGE: 4>: 34184.7798}
#
#
# Action.RUN
# 11567754.019480972
# {'gas_price': 10.453237984526528, 'co2_price': 22.746556904525924, 'power_price': 86.68766282737326, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 521067064}
# Spark: 47.487867938320804
# {<Action.DO_NOTHING: 0>: 34746.9598, <Action.RUN: 1>: 35700.0338, <Action.MOTHBALL_CHANGE: 4>: 34360.5844}
#
#
# Action.RUN
# 11948505.966236392
# {'gas_price': 10.391390225118217, 'co2_price': 23.068785904738792, 'power_price': 88.78083246134544, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 533895889}
# Spark: 49.320656331488436
# {<Action.DO_NOTHING: 0>: 36641.973600000005, <Action.RUN: 1>: 37045.609000000004, <Action.MOTHBALL_CHANGE: 4>: 36919.703499999996}
#
#
# Action.RUN
# 12476349.02346867
# {'gas_price': 10.127955141893587, 'co2_price': 22.68372187271614, 'power_price': 86.38356560905994, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 547274616}
# Spark: 47.571888594450215
# {<Action.DO_NOTHING: 0>: 35705.3104, <Action.RUN: 1>: 36533.651, <Action.MOTHBALL_CHANGE: 4>: 35569.458399999996}
#
#
# Action.RUN
# 11972703.91520166
# {'gas_price': 10.244851310292333, 'co2_price': 22.479162411672213, 'power_price': 87.57553769634734, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 560170962}
# Spark: 48.8515239743828
# {<Action.DO_NOTHING: 0>: 36254.2372, <Action.RUN: 1>: 36596.8859, <Action.MOTHBALL_CHANGE: 4>: 36268.3707}
#
#
# Action.RUN
# 12341238.904622246
# {'gas_price': 10.742623670801938, 'co2_price': 23.05590183376037, 'power_price': 88.80428588773987, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 573457751}
# Spark: 49.00576038317755
# {<Action.DO_NOTHING: 0>: 35979.324, <Action.RUN: 1>: 37107.7845, <Action.MOTHBALL_CHANGE: 4>: 35768.5299}
#
#
# Action.RUN
# 12385658.990355134
# {'gas_price': 10.841785915977205, 'co2_price': 22.784325136408583, 'power_price': 82.70475575192015, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 586810978}
# Spark: 43.07864469953436
# {<Action.DO_NOTHING: 0>: 30857.064099999996, <Action.RUN: 1>: 30906.1598, <Action.MOTHBALL_CHANGE: 4>: 30774.953200000004}
#
#
# Action.RUN
# 10678649.673465896
# {'gas_price': 11.19805119940287, 'co2_price': 22.745028720167475, 'power_price': 83.0501603460967, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 598476430}
# Spark: 43.10708042652636
# {<Action.DO_NOTHING: 0>: 31067.141100000004, <Action.RUN: 1>: 32364.234799999995, <Action.MOTHBALL_CHANGE: 4>: 31222.455100000003}
#
#
# Action.RUN
# 10686839.162839593
# {'gas_price': 10.72069556095859, 'co2_price': 23.240784787700953, 'power_price': 80.83676119791076, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 610169352}
# Spark: 40.87528084925122
# {<Action.DO_NOTHING: 0>: 29308.319499999998, <Action.RUN: 1>: 29938.471899999993, <Action.MOTHBALL_CHANGE: 4>: 29583.710400000004}
#
#
# Action.RUN
# 10044080.88458435
# {'gas_price': 10.983639597089875, 'co2_price': 22.3101275937386, 'power_price': 85.05889467642426, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 621237766}
# Spark: 45.765127485595784
# {<Action.DO_NOTHING: 0>: 33573.652200000004, <Action.RUN: 1>: 34435.2898, <Action.MOTHBALL_CHANGE: 4>: 33401.463200000006}
#
#
# Action.RUN
# 11452356.715851586
# {'gas_price': 11.814888390332456, 'co2_price': 20.94704624275975, 'power_price': 88.70728215914177, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 633735062}
# Spark: 49.94534752604956
# {<Action.DO_NOTHING: 0>: 37980.7566, <Action.RUN: 1>: 38743.0483, <Action.MOTHBALL_CHANGE: 4>: 37564.073800000006}
#
#
# Action.RUN
# 12656260.087502275
# {'gas_price': 11.875083211975985, 'co2_price': 21.541311680354035, 'power_price': 89.58227227986856, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 647458890}
# Spark: 50.16587738753855
# {<Action.DO_NOTHING: 0>: 37792.01900000001, <Action.RUN: 1>: 38563.801, <Action.MOTHBALL_CHANGE: 4>: 37766.703}
#
#
# Action.RUN
# 12719772.687611101
# {'gas_price': 10.966997093420078, 'co2_price': 21.759499279407912, 'power_price': 87.67452356461568, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 661269001}
# Spark: 48.9480271917877
# {<Action.DO_NOTHING: 0>: 36759.0062, <Action.RUN: 1>: 37744.1729, <Action.MOTHBALL_CHANGE: 4>: 37820.275}
#
#
# Action.MOTHBALL_CHANGE
# -2128000
# {'gas_price': 11.41801537651665, 'co2_price': 21.42961899973807, 'power_price': 89.53993740242768, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 660229626}
# Spark: 50.692303026172965
# {<Action.DO_NOTHING: 0>: 38638.9224, <Action.RUN: 1>: 39350.4809, <Action.MOTHBALL_CHANGE: 4>: 38773.620899999994}
#
#
# Action.RUN
# 12871383.271537814
# {'gas_price': 11.500682130090372, 'co2_price': 22.024809483060075, 'power_price': 88.79395715447407, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 674212690}
# Spark: 49.268465541323636
# {<Action.DO_NOTHING: 0>: 37386.5201, <Action.RUN: 1>: 38037.9909, <Action.MOTHBALL_CHANGE: 4>: 37232.3006}
#
#
# Action.RUN
# 12461318.075901208
# {'gas_price': 11.672477058274028, 'co2_price': 21.883123250793645, 'power_price': 91.3404462543248, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 687808106}
# Spark: 51.78484594525713
# {<Action.DO_NOTHING: 0>: 39282.905199999994, <Action.RUN: 1>: 40256.8277, <Action.MOTHBALL_CHANGE: 4>: 39106.664}
#
#
# Action.RUN
# 13186035.632234054
# {'gas_price': 11.804232924854091, 'co2_price': 21.75527858912399, 'power_price': 87.6239686436412, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 702151890}
# Spark: 48.064457129663126
# {<Action.DO_NOTHING: 0>: 36185.7441, <Action.RUN: 1>: 37003.77710000001, <Action.MOTHBALL_CHANGE: 4>: 36658.4023}
#
#
# Action.RUN
# 12114563.653342979
# {'gas_price': 12.119082984351461, 'co2_price': 21.843646085317562, 'power_price': 90.17288831480941, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 715446123}
# Spark: 50.21015924514039
# {<Action.DO_NOTHING: 0>: 37669.39269999999, <Action.RUN: 1>: 38171.12679999999, <Action.MOTHBALL_CHANGE: 4>: 37365.6767}
#
#
# Action.RUN
# 12732525.86260043
# {'gas_price': 11.909193639017584, 'co2_price': 21.970936976853043, 'power_price': 93.32052783363999, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 729381295}
# Spark: 53.44039721776936
# {<Action.DO_NOTHING: 0>: 39392.2794, <Action.RUN: 1>: 40769.010599999994, <Action.MOTHBALL_CHANGE: 4>: 39526.133299999994}
#
#
# Action.RUN
# 13662834.398717575
# {'gas_price': 11.68989665120377, 'co2_price': 22.196828886361992, 'power_price': 91.75292463267056, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 744271327}
# Spark: 51.86619909510479
# {<Action.DO_NOTHING: 0>: 37976.1318, <Action.RUN: 1>: 38860.3568, <Action.MOTHBALL_CHANGE: 4>: 38484.947199999995}
#
#
# Action.RUN
# 13209465.339390181
# {'gas_price': 12.041422511361127, 'co2_price': 21.86799639579846, 'power_price': 97.55775851522407, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 758731833}
# Spark: 57.64833960806448
# {<Action.DO_NOTHING: 0>: 42072.9037, <Action.RUN: 1>: 43078.3472, <Action.MOTHBALL_CHANGE: 4>: 42015.4877}
#
#
# Action.RUN
# 14874721.80712257
# {'gas_price': 11.941720269246963, 'co2_price': 21.482012337945896, 'power_price': 103.18340877201419, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 774884229}
# Spark: 63.75967616482134
# {<Action.DO_NOTHING: 0>: 46360.49480000001, <Action.RUN: 1>: 47661.10180000002, <Action.MOTHBALL_CHANGE: 4>: 46885.728200000005}
#
#
# Action.RUN
# 16634786.735468544
# {'gas_price': 11.97490763079464, 'co2_price': 20.842128706049213, 'power_price': 100.49931433209323, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 792826274}
# Spark: 61.68227799524939
# {<Action.DO_NOTHING: 0>: 44743.07070000001, <Action.RUN: 1>: 45975.55930000001, <Action.MOTHBALL_CHANGE: 4>: 45091.85290000002}
#
#
# Action.RUN
# 16036496.062631827
# {'gas_price': 12.589670808992768, 'co2_price': 21.806425195282365, 'power_price': 99.78855316494565, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 810198673}
# Spark: 59.39245716067052
# {<Action.DO_NOTHING: 0>: 43019.13970000001, <Action.RUN: 1>: 44391.92489999999, <Action.MOTHBALL_CHANGE: 4>: 43990.6094}
#
#
# Action.RUN
# 15377027.662273109
# {'gas_price': 13.20631214534569, 'co2_price': 21.630188597721453, 'power_price': 94.05524383060148, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 826939206}
# Spark: 53.218743087534335
# {<Action.DO_NOTHING: 0>: 39138.5007, <Action.RUN: 1>: 39777.39139999999, <Action.MOTHBALL_CHANGE: 4>: 38480.977399999996}
#
#
# Action.RUN
# 13598998.009209888
# {'gas_price': 13.855061068063849, 'co2_price': 21.810520834723587, 'power_price': 91.87519266276848, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 841926421}
# Spark: 50.20961075998105
# {<Action.DO_NOTHING: 0>: 36895.79009999999, <Action.RUN: 1>: 37369.7225, <Action.MOTHBALL_CHANGE: 4>: 36530.5305}
#
#
# Action.RUN
# 12732367.89887454
# {'gas_price': 13.888823903125301, 'co2_price': 20.47504917536361, 'power_price': 92.0217957241615, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 856070327}
# Spark: 51.6579226456726
# {<Action.DO_NOTHING: 0>: 38590.2242, <Action.RUN: 1>: 39582.4452, <Action.MOTHBALL_CHANGE: 4>: 38270.8425}
#
#
# Action.RUN
# 13149481.721953709
# {'gas_price': 13.501347435489823, 'co2_price': 20.99472720721461, 'power_price': 91.1105498417091, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 870655396}
# Spark: 50.61447519900467
# {<Action.DO_NOTHING: 0>: 38159.13859999999, <Action.RUN: 1>: 38835.47519999999, <Action.MOTHBALL_CHANGE: 4>: 38555.6561}
#
#
# Action.RUN
# 12848968.857313346
# {'gas_price': 13.77552711539349, 'co2_price': 21.219022543766414, 'power_price': 92.76677989262116, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 884963544}
# Spark: 51.77223023346126
# {<Action.DO_NOTHING: 0>: 39141.8916, <Action.RUN: 1>: 38702.6716, <Action.MOTHBALL_CHANGE: 4>: 38252.4977}
#
#
# Action.DO_NOTHING
# -1728000
# {'gas_price': 12.990134191427108, 'co2_price': 21.104542366093046, 'power_price': 90.3042518758397, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 884694279}
# Spark: 50.209575318319544
# {<Action.DO_NOTHING: 0>: 36788.4816, <Action.RUN: 1>: 38286.64369999999, <Action.MOTHBALL_CHANGE: 4>: 37129.320100000004}
#
#
# Action.RUN
# 12732357.69167603
# {'gas_price': 12.6928881495732, 'co2_price': 21.29800074486934, 'power_price': 90.25764168394323, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 898908810}
# Spark: 50.26675278950069
# {<Action.DO_NOTHING: 0>: 36819.0744, <Action.RUN: 1>: 37939.06229999999, <Action.MOTHBALL_CHANGE: 4>: 36763.875700000004}
#
#
# Action.RUN
# 12748824.803376202
# {'gas_price': 12.88949944113954, 'co2_price': 21.137691222221736, 'power_price': 90.81916883902144, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 913163312}
# Spark: 50.79197817566017
# {<Action.DO_NOTHING: 0>: 37922.513999999996, <Action.RUN: 1>: 38715.7446, <Action.MOTHBALL_CHANGE: 4>: 38022.205799999996}
#
#
# Action.RUN
# 12900089.714590129
# {'gas_price': 12.385623941722667, 'co2_price': 20.55257980369758, 'power_price': 84.66049042689869, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 927592871}
# Spark: 45.72228668147844
# {<Action.DO_NOTHING: 0>: 32860.798500000004, <Action.RUN: 1>: 33709.0785, <Action.MOTHBALL_CHANGE: 4>: 32979.516}
#
#
# Action.RUN
# 11440018.56426579
# {'gas_price': 12.443463869120354, 'co2_price': 20.5716478684342, 'power_price': 87.20119251821534, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 940583779}
# Spark: 48.18608078066079
# {<Action.DO_NOTHING: 0>: 35291.2149, <Action.RUN: 1>: 35933.675299999995, <Action.MOTHBALL_CHANGE: 4>: 36126.848600000005}
#
#
# Action.MOTHBALL_CHANGE
# -2128000
# {'gas_price': 13.402071752091762, 'co2_price': 20.59462312398856, 'power_price': 82.67444433366408, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 940005715}
# Spark: 42.677749457583765
# {<Action.DO_NOTHING: 0>: 31387.215399999997, <Action.RUN: 1>: 32126.8361, <Action.MOTHBALL_CHANGE: 4>: 30987.7453}
#
#
# Action.RUN
# 10563191.843784126
# {'gas_price': 13.641566564667908, 'co2_price': 20.38406261773084, 'power_price': 81.64655436755122, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 952138849}
# Spark: 41.62092518515247
# {<Action.DO_NOTHING: 0>: 29984.1349, <Action.RUN: 1>: 30723.696900000003, <Action.MOTHBALL_CHANGE: 4>: 30630.688700000002}
#
#
# Action.RUN
# 10258826.453323912
# {'gas_price': 13.520383128667804, 'co2_price': 20.26763821162596, 'power_price': 81.92313049194176, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 963987153}
# Spark: 42.135109151647995
# {<Action.DO_NOTHING: 0>: 30491.356199999995, <Action.RUN: 1>: 30749.036499999995, <Action.MOTHBALL_CHANGE: 4>: 30910.3559}
#
#
# Action.MOTHBALL_CHANGE
# -2128000
# {'gas_price': 13.35537832987482, 'co2_price': 19.580343131229185, 'power_price': 76.58299267631034, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 963447742}
# Spark: 37.64727121520633
# {<Action.DO_NOTHING: 0>: 26567.852800000008, <Action.RUN: 1>: 27133.4791, <Action.MOTHBALL_CHANGE: 4>: 26717.212199999998}
#
#
# Action.RUN
# 9114414.109979423
# {'gas_price': 13.474414582713234, 'co2_price': 19.622335833635134, 'power_price': 79.2888532634312, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 974168422}
# Spark: 40.192102847082836
# {<Action.DO_NOTHING: 0>: 29233.7392, <Action.RUN: 1>: 29717.899799999996, <Action.MOTHBALL_CHANGE: 4>: 28651.411099999998}
#
#
# Action.RUN
# 9847325.619959857
# {'gas_price': 13.46921204097014, 'co2_price': 19.7611225602228, 'power_price': 78.90576327985266, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 985640930}
# Spark: 39.67542867865972
# {<Action.DO_NOTHING: 0>: 27969.786799999998, <Action.RUN: 1>: 28776.483400000005, <Action.MOTHBALL_CHANGE: 4>: 27980.547700000006}
#
#
# Action.RUN
# 9698523.459453998
# {'gas_price': 13.737176346235161, 'co2_price': 19.89566251156159, 'power_price': 78.65750251736691, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 996983337}
# Spark: 39.02466365957016
# {<Action.DO_NOTHING: 0>: 27312.4483, <Action.RUN: 1>: 28469.299499999997, <Action.MOTHBALL_CHANGE: 4>: 27786.9129}
#
#
# Action.RUN
# 9511103.133956207
# {'gas_price': 13.706076023759445, 'co2_price': 19.489514814220176, 'power_price': 79.81633125040548, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1008156748}
# Spark: 40.62074041242587
# {<Action.DO_NOTHING: 0>: 29423.002399999998, <Action.RUN: 1>: 29880.954099999995, <Action.MOTHBALL_CHANGE: 4>: 29448.1233}
#
#
# Action.RUN
# 9970773.238778649
# {'gas_price': 13.246040183732136, 'co2_price': 18.93801595387577, 'power_price': 80.40557132859483, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1019809042}
# Spark: 42.22151519098693
# {<Action.DO_NOTHING: 0>: 30953.09969999999, <Action.RUN: 1>: 32031.1406, <Action.MOTHBALL_CHANGE: 4>: 31529.762600000002}
#
#
# Action.RUN
# 10431796.375004236
# {'gas_price': 12.928359204495559, 'co2_price': 19.2102065821727, 'power_price': 82.04526278546531, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1031942365}
# Spark: 43.90669699879705
# {<Action.DO_NOTHING: 0>: 32321.2503, <Action.RUN: 1>: 33583.7383, <Action.MOTHBALL_CHANGE: 4>: 32537.149599999993}
#
#
# Action.RUN
# 10917128.735653551
# {'gas_price': 12.153097648040164, 'co2_price': 19.138309262799893, 'power_price': 82.02818567891569, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1044581861}
# Spark: 44.73677876807563
# {<Action.DO_NOTHING: 0>: 33265.231999999996, <Action.RUN: 1>: 33660.579, <Action.MOTHBALL_CHANGE: 4>: 32658.7547}
#
#
# Action.RUN
# 11156192.285205781
# {'gas_price': 12.06849305697643, 'co2_price': 19.122670392449933, 'power_price': 84.0145477876975, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1057481691}
# Spark: 46.82338433827113
# {<Action.DO_NOTHING: 0>: 34327.36, <Action.RUN: 1>: 34794.5729, <Action.MOTHBALL_CHANGE: 4>: 34408.3355}
#
#
# Action.RUN
# 11757134.689422086
# {'gas_price': 12.239707274989517, 'co2_price': 19.941949979971746, 'power_price': 87.8484125515085, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1071004761}
# Spark: 49.66675529654725
# {<Action.DO_NOTHING: 0>: 35999.299000000006, <Action.RUN: 1>: 37198.731400000004, <Action.MOTHBALL_CHANGE: 4>: 36217.2561}
#
#
# Action.RUN
# 12576025.525405608
# {'gas_price': 12.430034794444211, 'co2_price': 20.370508889803826, 'power_price': 97.07483305993084, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1085370408}
# Spark: 58.2742893756828
# {<Action.DO_NOTHING: 0>: 43130.702600000004, <Action.RUN: 1>: 44030.5937, <Action.MOTHBALL_CHANGE: 4>: 43047.4926}
#
#
# Action.RUN
# 15054995.340196647
# {'gas_price': 12.778149467255242, 'co2_price': 21.016236887772, 'power_price': 106.23869105196029, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1102242845}
# Spark: 66.44430469693305
# {<Action.DO_NOTHING: 0>: 50675.26010000001, <Action.RUN: 1>: 51592.234000000004, <Action.MOTHBALL_CHANGE: 4>: 50152.00659999999}
#
#
# Action.RUN
# 17407959.75271672
# {'gas_price': 12.852275024814782, 'co2_price': 21.88419836711115, 'power_price': 105.85534685772447, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1121499999}
# Spark: 65.11887346579853
# {<Action.DO_NOTHING: 0>: 49658.63000000001, <Action.RUN: 1>: 50180.068, <Action.MOTHBALL_CHANGE: 4>: 49103.72450000001}
#
#
# Action.RUN
# 17026235.55814998
# {'gas_price': 12.346040471384724, 'co2_price': 22.429759771291053, 'power_price': 100.61202018220547, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1140406603}
# Spark: 59.836219939529684
# {<Action.DO_NOTHING: 0>: 45838.2108, <Action.RUN: 1>: 46292.7521, <Action.MOTHBALL_CHANGE: 4>: 45304.60489999999}
#
#
# Action.RUN
# 15504831.34258455
# {'gas_price': 12.41935319748364, 'co2_price': 22.671533769414253, 'power_price': 94.94667817079242, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1157820516}
# Spark: 53.85579120389453
# {<Action.DO_NOTHING: 0>: 40458.4364, <Action.RUN: 1>: 41068.69230000001, <Action.MOTHBALL_CHANGE: 4>: 39837.65119999999}
#
#
# Action.RUN
# 13782467.866721625
# {'gas_price': 12.238652577398124, 'co2_price': 23.309255600707168, 'power_price': 89.96692383572791, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1173537981}
# Spark: 48.41901565762261
# {<Action.DO_NOTHING: 0>: 35488.2115, <Action.RUN: 1>: 36313.384000000005, <Action.MOTHBALL_CHANGE: 4>: 35310.226599999995}
#
#
# Action.RUN
# 12216676.509395313
# {'gas_price': 11.811823407532495, 'co2_price': 23.200683138674123, 'power_price': 85.73512724974266, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1187713028}
# Spark: 44.722620703536045
# {<Action.DO_NOTHING: 0>: 32512.29929999999, <Action.RUN: 1>: 33455.3257, <Action.MOTHBALL_CHANGE: 4>: 32618.569800000005}
#
#
# Action.RUN
# 11152114.76261838
# {'gas_price': 11.231023685135554, 'co2_price': 24.444622875376993, 'power_price': 83.72191352728633, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1200845166}
# Spark: 42.046266966773786
# {<Action.DO_NOTHING: 0>: 30746.7044, <Action.RUN: 1>: 31445.0145, <Action.MOTHBALL_CHANGE: 4>: 30436.9114}
#
#
# Action.RUN
# 10381324.88643085
# {'gas_price': 11.116709256055223, 'co2_price': 24.546691218760962, 'power_price': 75.74617230443444, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1213226930}
# Spark: 34.08277182961825
# {<Action.DO_NOTHING: 0>: 23980.2471, <Action.RUN: 1>: 24324.014099999997, <Action.MOTHBALL_CHANGE: 4>: 24397.589099999994}
#
#
# Action.MOTHBALL_CHANGE
# -2128000
# {'gas_price': 11.029875672398783, 'co2_price': 24.63384030579055, 'power_price': 73.301402470573, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1213099158}
# Spark: 31.637686492383665
# {<Action.DO_NOTHING: 0>: 21391.8294, <Action.RUN: 1>: 22279.7966, <Action.MOTHBALL_CHANGE: 4>: 22218.761899999998}
#
#
# Action.RUN
# 7383653.709806494
# {'gas_price': 11.185424300684694, 'co2_price': 25.185223920402795, 'power_price': 73.30114344489435, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1222498538}
# Spark: 30.930495223806865
# {<Action.DO_NOTHING: 0>: 20810.3296, <Action.RUN: 1>: 21428.7431, <Action.MOTHBALL_CHANGE: 4>: 21363.2911}
#
#
# Action.RUN
# 7179982.624456378
# {'gas_price': 11.168474177142908, 'co2_price': 25.17772255749801, 'power_price': 74.14972135629176, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1231709435}
# Spark: 31.803524621650837
# {<Action.DO_NOTHING: 0>: 21873.804, <Action.RUN: 1>: 22413.711, <Action.MOTHBALL_CHANGE: 4>: 21980.947}
#
#
# Action.RUN
# 7431415.091035441
# {'gas_price': 11.495614779007138, 'co2_price': 24.935731657146604, 'power_price': 73.93968689343542, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1241187392}
# Spark: 31.508340457281676
# {<Action.DO_NOTHING: 0>: 20979.255199999996, <Action.RUN: 1>: 21813.440099999996, <Action.MOTHBALL_CHANGE: 4>: 20917.493899999998}
#
#
# Action.RUN
# 7346402.051697122
# {'gas_price': 11.627052839047849, 'co2_price': 24.853081228585506, 'power_price': 75.20989325709543, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1250595849}
# Spark: 32.72975918946207
# {<Action.DO_NOTHING: 0>: 22109.0973, <Action.RUN: 1>: 22692.555099999998, <Action.MOTHBALL_CHANGE: 4>: 22323.6525}
#
#
# Action.RUN
# 7698170.646565078
# {'gas_price': 11.607379181704049, 'co2_price': 24.598204196295363, 'power_price': 77.89426870357767, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1260372195}
# Spark: 35.688685325578255
# {<Action.DO_NOTHING: 0>: 25028.3982, <Action.RUN: 1>: 24978.185500000007, <Action.MOTHBALL_CHANGE: 4>: 25619.381800000003}
#
#
# Action.MOTHBALL_CHANGE
# -2128000
# {'gas_price': 11.502947218299518, 'co2_price': 23.983033187688108, 'power_price': 81.25459230468354, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1260322288}
# Spark: 39.768611898695916
# {<Action.DO_NOTHING: 0>: 28376.9607, <Action.RUN: 1>: 29590.4, <Action.MOTHBALL_CHANGE: 4>: 28633.348900000005}
#
#
# Action.RUN
# 9725360.226824423
# {'gas_price': 11.583821693065797, 'co2_price': 24.08629960771943, 'power_price': 70.21745654013256, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1272145235}
# Spark: 28.547335239347333
# {<Action.DO_NOTHING: 0>: 19145.366799999996, <Action.RUN: 1>: 20181.6151, <Action.MOTHBALL_CHANGE: 4>: 19405.326699999998}
#
#
# Action.RUN
# 6493632.548932033
# {'gas_price': 11.313695551726353, 'co2_price': 24.479790223020405, 'power_price': 70.53248402094059, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1280750644}
# Spark: 28.73899824619383
# {<Action.DO_NOTHING: 0>: 19116.115200000004, <Action.RUN: 1>: 19787.140900000002, <Action.MOTHBALL_CHANGE: 4>: 19016.7402}
#
#
# Action.RUN
# 6548831.494903823
# {'gas_price': 11.736157976500595, 'co2_price': 24.264735161492915, 'power_price': 70.01542929623213, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1289425555}
# Spark: 28.01453615823862
# {<Action.DO_NOTHING: 0>: 18833.217399999998, <Action.RUN: 1>: 19826.7564, <Action.MOTHBALL_CHANGE: 4>: 19126.475899999998}
#
#
# Action.RUN
# 6340186.413572723
# {'gas_price': 11.848963595727946, 'co2_price': 23.82687043996152, 'power_price': 73.7011065584255, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1297905804}
# Spark: 32.025272522736024
# {<Action.DO_NOTHING: 0>: 22675.61599999999, <Action.RUN: 1>: 22955.8765, <Action.MOTHBALL_CHANGE: 4>: 22631.961}
#
#
# Action.RUN
# 7495278.486547975
# {'gas_price': 11.444715944751087, 'co2_price': 23.183917703339866, 'power_price': 68.50843162713593, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1307557059}
# Spark: 27.87979797904498
# {<Action.DO_NOTHING: 0>: 19054.498900000002, <Action.RUN: 1>: 19398.501800000002, <Action.MOTHBALL_CHANGE: 4>: 18580.228600000002}
#
#
# Action.RUN
# 6301381.817964954
# {'gas_price': 11.898520214591079, 'co2_price': 23.453215018425936, 'power_price': 68.66276133119342, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1316028385}
# Spark: 27.311026098176406
# {<Action.DO_NOTHING: 0>: 18149.9651, <Action.RUN: 1>: 18917.5487, <Action.MOTHBALL_CHANGE: 4>: 18204.7325}
#
#
# Action.RUN
# 6137575.516274805
# {'gas_price': 11.813354418926396, 'co2_price': 23.40122703936416, 'power_price': 64.94327158482119, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1324349625}
# Spark: 23.728690126530637
# {<Action.DO_NOTHING: 0>: 15296.344000000001, <Action.RUN: 1>: 16145.971800000001, <Action.MOTHBALL_CHANGE: 4>: 15163.8721}
#
#
# Action.RUN
# 5105862.756440824
# {'gas_price': 12.164775540992785, 'co2_price': 23.463466007883344, 'power_price': 62.554025211099464, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1331651192}
# Spark: 20.92578366222333
# {<Action.DO_NOTHING: 0>: 12807.2402, <Action.RUN: 1>: 13214.761100000002, <Action.MOTHBALL_CHANGE: 4>: 13088.195}
#
#
# Action.RUN
# 4298625.694720319
# {'gas_price': 11.761330718750395, 'co2_price': 23.422330641202826, 'power_price': 63.874444297837975, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1338156247}
# Spark: 22.690782937884755
# {<Action.DO_NOTHING: 0>: 14468.5423, <Action.RUN: 1>: 14844.3638, <Action.MOTHBALL_CHANGE: 4>: 14508.9971}
#
#
# Action.RUN
# 4806945.486110809
# {'gas_price': 11.682452104084112, 'co2_price': 23.08699306410062, 'power_price': 59.900662587387345, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1345181205}
# Spark: 19.131217419202606
# {<Action.DO_NOTHING: 0>: 11398.0065, <Action.RUN: 1>: 11708.9203, <Action.MOTHBALL_CHANGE: 4>: 11383.473499999998}
#
#
# Action.RUN
# 3781790.61673035
# {'gas_price': 12.170752055125172, 'co2_price': 24.288282678324627, 'power_price': 60.42836401270097, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1351190918}
# Spark: 17.96932927925117
# {<Action.DO_NOTHING: 0>: 10645.0683, <Action.RUN: 1>: 11193.451800000003, <Action.MOTHBALL_CHANGE: 4>: 10692.726800000002}
#
#
# Action.RUN
# 3447166.832424337
# {'gas_price': 11.46291113875844, 'co2_price': 24.740037261092766, 'power_price': 60.75535813146135, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1356875380}
# Spark: 18.552409731610144
# {<Action.DO_NOTHING: 0>: 10686.141899999999, <Action.RUN: 1>: 11479.616500000002, <Action.MOTHBALL_CHANGE: 4>: 10680.072900000001}
#
#
# Action.RUN
# 3615094.0027037216
# {'gas_price': 11.883126669975844, 'co2_price': 24.060080090519033, 'power_price': 63.78227271161931, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1362737435}
# Spark: 21.839065951124432
# {<Action.DO_NOTHING: 0>: 13428.8537, <Action.RUN: 1>: 14367.963199999998, <Action.MOTHBALL_CHANGE: 4>: 13658.441100000004}
#
#
# Action.RUN
# 4561650.993923835
# {'gas_price': 12.315357923771879, 'co2_price': 24.33275544465714, 'power_price': 64.96778487984149, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1369557292}
# Spark: 22.319671511412473
# ...
# Spark: 28.514452528376857
# {<Action.DO_NOTHING: 0>: 12927.031299999999, <Action.RUN: 1>: 13282.0671, <Action.MOTHBALL_CHANGE: 4>: 13008.552400000002}
#
#
# Action.RUN
# 6484162.328172535
# {'gas_price': 13.842811345306338, 'co2_price': 24.56557698531426, 'power_price': 68.11101344092074, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 2011915556}
# Spark: 23.702625110300147
# {<Action.DO_NOTHING: 0>: 10027.9686, <Action.RUN: 1>: 10522.428299999998, <Action.MOTHBALL_CHANGE: 4>: 10007.1217}
#
#
# Action.RUN
# 5098356.031766442
# {'gas_price': 13.880606135857409, 'co2_price': 24.925557220434868, 'power_price': 66.63587385881895, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 2020345174}
# Spark: 21.829710502526677
# {<Action.DO_NOTHING: 0>: 8773.605800000001, <Action.RUN: 1>: 9305.2663, <Action.MOTHBALL_CHANGE: 4>: 8680.769}
#
#
# Action.RUN
# 4558956.624727683
# {'gas_price': 13.276633315500808, 'co2_price': 24.706452260522394, 'power_price': 66.92525582465889, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 2028248424}
# Spark: 22.942170248635684
# {<Action.DO_NOTHING: 0>: 9524.273299999999, <Action.RUN: 1>: 9982.258399999999, <Action.MOTHBALL_CHANGE: 4>: 9313.961400000002}
#
#
# Action.RUN
# 4879345.031607077
# {'gas_price': 13.997238505969579, 'co2_price': 24.6036455837213, 'power_price': 67.96271005737576, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 2036485645}
# Spark: 23.36182596768488
# {<Action.DO_NOTHING: 0>: 9499.851799999999, <Action.RUN: 1>: 10174.6989, <Action.MOTHBALL_CHANGE: 4>: 9650.3287}
#
#
# Action.RUN
# 5000205.878693245
# {'gas_price': 13.617158743946645, 'co2_price': 23.698716638111463, 'power_price': 67.17350213430223, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 2044857531}
# Spark: 23.857626752244116
# {<Action.DO_NOTHING: 0>: 10032.8522, <Action.RUN: 1>: 10155.554799999998, <Action.MOTHBALL_CHANGE: 4>: 9715.944}
#
#
# Action.RUN
# 5142996.504646305
# {'gas_price': 13.631633789322057, 'co2_price': 23.736341591112897, 'power_price': 66.8917390847031, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 2053386270}
# Spark: 23.52376370426815
# {<Action.DO_NOTHING: 0>: 9438.4631, <Action.RUN: 1>: 9918.269699999999, <Action.MOTHBALL_CHANGE: 4>: 9570.335}
#
#
# Action.RUN
# 5046843.946829227
# {'gas_price': 13.76309186601401, 'co2_price': 23.566684110522296, 'power_price': 65.06337283784818, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 2061832784}
# Spark: 21.733596861311874
# {<Action.DO_NOTHING: 0>: 8430.6533, <Action.RUN: 1>: 8838.7953, <Action.MOTHBALL_CHANGE: 4>: 8432.353200000001}
#
#
# Action.RUN
# 4531275.89605782
# {'gas_price': 13.742200243391856, 'co2_price': 24.24620558567346, 'power_price': 60.846316687255936, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 2069776828}
# Spark: 16.857910858190614
# {<Action.DO_NOTHING: 0>: 5629.553100000001, <Action.RUN: 1>: 6365.105699999999, <Action.MOTHBALL_CHANGE: 4>: 5792.6757}
#
#
# Action.RUN
# 3127078.327158897
# {'gas_price': 14.18185677193727, 'co2_price': 24.182741968833888, 'power_price': 65.43512891088201, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 2076327476}
# Spark: 21.070530170110857
# {<Action.DO_NOTHING: 0>: 7918.759900000001, <Action.RUN: 1>: 8435.2042, <Action.MOTHBALL_CHANGE: 4>: 8120.460999999999}
#
#
# Action.RUN
# 4340312.688991927
# {'gas_price': 14.73067236430377, 'co2_price': 23.991281019276606, 'power_price': 64.91960443991117, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 2084104181}
# Spark: 20.19765105633079
# {<Action.DO_NOTHING: 0>: 7583.5645, <Action.RUN: 1>: 8055.1802, <Action.MOTHBALL_CHANGE: 4>: 7255.794599999998}
#
#
# Action.RUN
# 4088923.5042232685
# {'gas_price': 14.602053461613101, 'co2_price': 24.722957456481, 'power_price': 65.57938634394793, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 2091641925}
# Spark: 20.25437542585383
# {<Action.DO_NOTHING: 0>: 7514.311800000001, <Action.RUN: 1>: 7596.8448, <Action.MOTHBALL_CHANGE: 4>: 7301.230200000002}
#
#
# Action.RUN
# 4105260.1226459034
# {'gas_price': 15.576477314321306, 'co2_price': 24.592626255368774, 'power_price': 65.47996103506861, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 2099208482}
# Spark: 19.310857465378536
# {<Action.DO_NOTHING: 0>: 6765.4374, <Action.RUN: 1>: 7035.546600000001, <Action.MOTHBALL_CHANGE: 4>: 6982.575300000001}
#
#
# Action.RUN
# 3833526.9500290183
# {'gas_price': 15.886590833623064, 'co2_price': 24.47361279507654, 'power_price': 65.14077994042752, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 2106515354}
# Spark: 18.780576311727916
# {<Action.DO_NOTHING: 0>: 6251.8295, <Action.RUN: 1>: 6849.1033, <Action.MOTHBALL_CHANGE: 4>: 6533.567400000001}
#
#
# Action.RUN
# 3680805.9777776394
# {'gas_price': 16.417956722496395, 'co2_price': 24.068674165759326, 'power_price': 65.05444510886392, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 2113681320}
# Spark: 18.567814220608195
# {<Action.DO_NOTHING: 0>: 6279.0241000000005, <Action.RUN: 1>: 6921.8090999999995, <Action.MOTHBALL_CHANGE: 4>: 6080.370499999999}
#
#
# Action.RUN
# 3619530.4955351604
# {'gas_price': 16.11076073471017, 'co2_price': 24.11139870296492, 'power_price': 62.407438395163965, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 2120797745}
# Spark: 16.185278957488876
# {<Action.DO_NOTHING: 0>: 5167.7432, <Action.RUN: 1>: 5655.1743000000015, <Action.MOTHBALL_CHANGE: 4>: 5116.3768}
#
#
# Action.RUN
# 2933360.339756796
# {'gas_price': 16.125191243830862, 'co2_price': 23.936548594509546, 'power_price': 69.4652375320137, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 2127238620}
# Spark: 23.403497693673295
# {<Action.DO_NOTHING: 0>: 8172.0152, <Action.RUN: 1>: 8762.6576, <Action.MOTHBALL_CHANGE: 4>: 7957.399299999998}
#
#
# Action.RUN
# 5012207.335777909
# {'gas_price': 16.032577842708434, 'co2_price': 23.55417226367518, 'power_price': 66.7648771610241, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 2135772413}
# Spark: 21.178127054640484
# {<Action.DO_NOTHING: 0>: 7136.156100000001, <Action.RUN: 1>: 7601.6862, <Action.MOTHBALL_CHANGE: 4>: 7227.6701}
#
#
# Action.RUN
# 4371300.59173646
# {'gas_price': 16.13928015619654, 'co2_price': 24.06018848877027, 'power_price': 63.94201675714003, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 2143678335}
# Spark: 17.742548112173218
# {<Action.DO_NOTHING: 0>: 5350.493699999999, <Action.RUN: 1>: 5918.1258, <Action.MOTHBALL_CHANGE: 4>: 5559.947100000002}
#
#
# Action.RUN
# 3381853.856305887
# {'gas_price': 16.41421177268465, 'co2_price': 23.660466778304624, 'power_price': 63.15854708645842, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 2150606233}
# Spark: 17.083868535469147
# {<Action.DO_NOTHING: 0>: 4995.026, <Action.RUN: 1>: 5719.714999999999, <Action.MOTHBALL_CHANGE: 4>: 5161.8537}
#
#
# Action.RUN
# 3192154.1382151144
# {'gas_price': 16.280506385108875, 'co2_price': 23.266489499837032, 'power_price': 62.52688399095795, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 2157355560}
# Spark: 16.979888106012044
# {<Action.DO_NOTHING: 0>: 5017.513, <Action.RUN: 1>: 5399.575499999999, <Action.MOTHBALL_CHANGE: 4>: 4958.1446}
#
#
# Action.RUN
# 3162207.7745314687
# {'gas_price': 15.301224618373702, 'co2_price': 23.191160323472545, 'power_price': 60.637046049651126, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 2164086039}
# Spark: 16.14466110780488
# {<Action.DO_NOTHING: 0>: 4301.9197, <Action.RUN: 1>: 5084.410800000001, <Action.MOTHBALL_CHANGE: 4>: 4387.002}
#
#
# Action.RUN
# 2921662.399047805
# {'gas_price': 15.36773386476312, 'co2_price': 22.833058268981482, 'power_price': 59.2575502805279, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 2170586691}
# Spark: 15.056758146783302
# {<Action.DO_NOTHING: 0>: 4116.7859, <Action.RUN: 1>: 4405.0257, <Action.MOTHBALL_CHANGE: 4>: 3837.9866999999995}
#
#
# Action.RUN
# 2608346.346273591
# {'gas_price': 14.779231653708736, 'co2_price': 22.54147697686527, 'power_price': 58.959902233273546, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 2176784246}
# Spark: 15.639193602699542
# {<Action.DO_NOTHING: 0>: 3953.790900000001, <Action.RUN: 1>: 4558.4355, <Action.MOTHBALL_CHANGE: 4>: 4008.7953}
#
#
# Action.RUN
# 2776087.7575774686
# {'gas_price': 15.372957491236885, 'co2_price': 23.08052343543087, 'power_price': 62.089561535736806, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 2183160055}
# Spark: 17.63608060906905
# {<Action.DO_NOTHING: 0>: 4627.631200000001, <Action.RUN: 1>: 5051.983, <Action.MOTHBALL_CHANGE: 4>: 4466.160500000001}
#
#
# Action.RUN
# 3351191.2154118866
# {'gas_price': 16.44204000039444, 'co2_price': 22.65555620178878, 'power_price': 61.044412652972845, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 2190122447}
# Spark: 15.94681645078963
# {<Action.DO_NOTHING: 0>: 3889.2434999999996, <Action.RUN: 1>: 4336.6857, <Action.MOTHBALL_CHANGE: 4>: 3917.1293000000005}
#
#
# Action.RUN
# 2864683.137827413
# {'gas_price': 16.968388679488516, 'co2_price': 22.159963523112395, 'power_price': 62.396767190092646, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 2196609027}
# Spark: 17.268414987491735
# {<Action.DO_NOTHING: 0>: 4284.624699999999, <Action.RUN: 1>: 4811.717599999999, <Action.MOTHBALL_CHANGE: 4>: 4050.0714000000003}
#
#
# Action.RUN
# 3245303.5163976196
# {'gas_price': 17.22659153574096, 'co2_price': 22.073247258093982, 'power_price': 67.71386800535484, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 2203487569}
# Spark: 22.414029211519896
# {<Action.DO_NOTHING: 0>: 5840.674899999999, <Action.RUN: 1>: 6300.260199999999, <Action.MOTHBALL_CHANGE: 4>: 5587.396900000001}
#
#
# Action.RUN
# 4727240.41291773
# {'gas_price': 17.17925272599074, 'co2_price': 21.43173008245851, 'power_price': 64.55559281682815, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 2211861856}
# Spark: 19.9446100083789
# {<Action.DO_NOTHING: 0>: 4743.5513, <Action.RUN: 1>: 5426.348999999999, <Action.MOTHBALL_CHANGE: 4>: 4750.762099999999}
#
#
# Action.RUN
# 4016047.6824131226
# {'gas_price': 17.109699510319256, 'co2_price': 20.6597349977631, 'power_price': 65.74166087619426, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 2219537606}
# Spark: 21.972226368111908
# {<Action.DO_NOTHING: 0>: 5342.5307999999995, <Action.RUN: 1>: 5759.619099999999, <Action.MOTHBALL_CHANGE: 4>: 5265.0103}
#
#
# Action.RUN
# 4600001.19401623
# {'gas_price': 17.11387625467499, 'co2_price': 20.397719397712713, 'power_price': 63.018509295244726, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 2227810951}
# Spark: 19.506913642857022
# {<Action.DO_NOTHING: 0>: 4243.3032, <Action.RUN: 1>: 4913.6862, <Action.MOTHBALL_CHANGE: 4>: 4131.2476}
#
#
# Action.RUN
# 3889991.1291428218
# {'gas_price': 17.194696344584745, 'co2_price': 20.15565365020935, 'power_price': 68.25735911674286, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 2235386778}
# Spark: 24.90700912194877
# {<Action.DO_NOTHING: 0>: 5466.053099999999, <Action.RUN: 1>: 6231.2521, <Action.MOTHBALL_CHANGE: 4>: 5566.543900000001}
#
#
# Action.RUN
# 5445218.627121246
# {'gas_price': 16.611541718453605, 'co2_price': 20.928475880355176, 'power_price': 71.77458491726674, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 2244532913}
# Spark: 28.234567318457948
# {<Action.DO_NOTHING: 0>: 6213.411799999998, <Action.RUN: 1>: 6698.615500000001, <Action.MOTHBALL_CHANGE: 4>: 6032.9751}
#
#
# Action.RUN
# 6403555.387715889
# {'gas_price': 17.173453735358443, 'co2_price': 20.154215695690525, 'power_price': 75.62579562540878, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 2254654073}
# Spark: 32.29812619435982
# {<Action.DO_NOTHING: 0>: 6769.5831, <Action.RUN: 1>: 7525.9627, <Action.MOTHBALL_CHANGE: 4>: 6699.868300000002}
#
#
# Action.RUN
# 7573860.343975628
# {'gas_price': 16.455932405510282, 'co2_price': 20.14926489963753, 'power_price': 74.70934835294689, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 2265964187}
# Spark: 32.10415104779908
# {<Action.DO_NOTHING: 0>: 6467.525600000001, <Action.RUN: 1>: 7199.3022, <Action.MOTHBALL_CHANGE: 4>: 6415.357800000002}
#
#
# Action.RUN
# 7517995.501766134
# {'gas_price': 17.140208216754694, 'co2_price': 20.18023931403203, 'power_price': 75.1139138520739, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 2277237023}
# Spark: 31.793466321287184
# {<Action.DO_NOTHING: 0>: 6044.610600000002, <Action.RUN: 1>: 6833.050299999999, <Action.MOTHBALL_CHANGE: 4>: 5838.7495}
#
#
# Action.RUN
# 7428518.300530709
# {'gas_price': 16.52158190767351, 'co2_price': 19.950117534867147, 'power_price': 72.05697268391009, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 2288438852}
# Spark: 29.585273241369435
# {<Action.DO_NOTHING: 0>: 5011.6595, <Action.RUN: 1>: 5829.2878, <Action.MOTHBALL_CHANGE: 4>: 5040.559200000001}
#
#
# Action.RUN
# 6792558.693514397
# {'gas_price': 16.819971111915414, 'co2_price': 20.168877991373023, 'power_price': 68.62944524848618, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 2299022172}
# Spark: 25.64059614519774
# {<Action.DO_NOTHING: 0>: 3904.4463, <Action.RUN: 1>: 4675.6243, <Action.MOTHBALL_CHANGE: 4>: 3824.8731}
#
#
# Action.RUN
# 5656491.68981695
# {'gas_price': 17.528877302076616, 'co2_price': 20.70007926141228, 'power_price': 74.12884969852816, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 2308485028}
# Spark: 29.899893135039257
# {<Action.DO_NOTHING: 0>: 4434.613399999999, <Action.RUN: 1>: 5174.2143, <Action.MOTHBALL_CHANGE: 4>: 4348.7903}
#
#
# Action.RUN
# 6883169.2228913065
# {'gas_price': 17.747929383322745, 'co2_price': 21.04377145109146, 'power_price': 78.14748774324599, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 2319192216}
# Spark: 33.35578690883179
# {<Action.DO_NOTHING: 0>: 4498.7806, <Action.RUN: 1>: 5436.5309, <Action.MOTHBALL_CHANGE: 4>: 4499.2475}
#
#
# Action.RUN
# 7878466.629743556
# {'gas_price': 18.488875957198896, 'co2_price': 20.765372998642952, 'power_price': 76.70208927345779, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 2330914029}
# Spark: 31.447840317615942
# {<Action.DO_NOTHING: 0>: 3665.0802000000003, <Action.RUN: 1>: 4684.0311, <Action.MOTHBALL_CHANGE: 4>: 3610.6970000000006}
#
#
# Action.RUN
# 7328978.011473391
# {'gas_price': 17.41352880403793, 'co2_price': 21.593675537334146, 'power_price': 81.40911684491297, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 2342104805}
# Spark: 36.40191250354089
# {<Action.DO_NOTHING: 0>: 3982.5851999999995, <Action.RUN: 1>: 4959.8052, <Action.MOTHBALL_CHANGE: 4>: 3825.8953999999994}
#
#
# Action.RUN
# 8755750.801019777
# {'gas_price': 17.08671731887999, 'co2_price': 21.83805408379751, 'power_price': 77.54562823872489, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 2354743193}
# Spark: 32.62085683604739
# {<Action.DO_NOTHING: 0>: 2858.6959, <Action.RUN: 1>: 3846.1304999999998, <Action.MOTHBALL_CHANGE: 4>: 2838.5265999999997}
#
#
# Action.RUN
# 7666806.768781647
# {'gas_price': 16.6880625566405, 'co2_price': 22.25826970680874, 'power_price': 84.43945528481919, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 2366311712}
# Spark: 39.493123021369954
# {<Action.DO_NOTHING: 0>: 2834.8853, <Action.RUN: 1>: 4028.9979, <Action.MOTHBALL_CHANGE: 4>: 2824.5472000000004}
#
#
# Action.RUN
# 9646019.430154545
# {'gas_price': 16.140012828139074, 'co2_price': 22.071535835189117, 'power_price': 83.76646420866348, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 2379881819}
# Spark: 39.55491554533529
# {<Action.DO_NOTHING: 0>: 2101.1307, <Action.RUN: 1>: 3400.1559, <Action.MOTHBALL_CHANGE: 4>: 2034.6666}
#
#
# Action.RUN
# 9663815.677056564
# {'gas_price': 15.576742556900118, 'co2_price': 21.754615192148115, 'power_price': 84.12071526190373, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 2393492164}
# Spark: 40.78935751285549
# {<Action.DO_NOTHING: 0>: 1225.2925, <Action.RUN: 1>: 2641.828, <Action.MOTHBALL_CHANGE: 4>: 1160.1148}
#
#
# Action.RUN
# 10019334.96370238
# {'gas_price': 15.214446850000492, 'co2_price': 22.157592668193544, 'power_price': 80.64026462112201, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 2407481094}
# Spark: 37.26822510292798
# {<Action.DO_NOTHING: 0>: -498.8300000000001, <Action.RUN: 1>: 1457.4599999999994, <Action.MOTHBALL_CHANGE: 4>: -593.35}
#
#
# Action.RUN
# 9005248.829643257

# %% [markdown]
# # Optimal strategy is dumb
# - The optimal strategy is making stupid decisions which do not make sense.
# - Not running the plant when there is spark 30 and doing nothing, why?

# %%
import sys
import os

sys.path.append("/Users/filiprolenec/Desktop/MT/MTpython/src")

# %%
import pandas as pd
from gas_example.enum_types import PowerplantState
from gas_example.optimization.optimization import get_best_action
from gas_example.simulation.state import State, action_is_invalid

# %%
df_vfs = pd.read_pickle(f'../saved_vfs/vfs_2020-12-25_H09.pkl')
vfs = list(df_vfs[0])

# %%
init_state=State(10, 25, 70, PowerplantState.NOT_BUILT, 0)

# %%
state = init_state
fcfs = []
for epoch in range(300-1):
    print(epoch)
    action, exp_value = get_best_action(state, vfs[epoch+1], print_details = True)
    print(f"Best action is: {action}")
    new_state, fcf = state.get_new_state_and_fcf(action)
    state = new_state
# Out:
# 0
# {'gas_price': 10, 'co2_price': 25, 'power_price': 70, 'plant_state': <PowerplantState.NOT_BUILT: 0>, 'balance': 0}
# Spark: 29
# {<Action.DO_NOTHING: 0>: 167219.61497, <Action.IDLE_AND_BUILD: 3>: 166555.99941999998}
#
#
# Best action is: Action.DO_NOTHING
# 1
# {'gas_price': 10.196959587145919, 'co2_price': 25.04336647552116, 'power_price': 70.60417773707027, 'plant_state': <PowerplantState.NOT_BUILT: 0>, 'balance': 0}
# Spark: 29.363851674403193
# {<Action.DO_NOTHING: 0>: 167093.61826, <Action.IDLE_AND_BUILD: 3>: 166728.47243999998}
#
#
# Best action is: Action.DO_NOTHING
# 2
# {'gas_price': 10.302519173189284, 'co2_price': 23.62843297830677, 'power_price': 71.86308562818256, 'plant_state': <PowerplantState.NOT_BUILT: 0>, 'balance': 0}
# Spark: 31.93213347668651
# {<Action.DO_NOTHING: 0>: 169798.38020999997, <Action.IDLE_AND_BUILD: 3>: 169181.04184}
#
#
# Best action is: Action.DO_NOTHING
# 3
# {'gas_price': 10.308077089022548, 'co2_price': 25.133473527581334, 'power_price': 76.15404533801599, 'plant_state': <PowerplantState.NOT_BUILT: 0>, 'balance': 0}
# Spark: 34.712494721412114
# {<Action.DO_NOTHING: 0>: 171850.88612, <Action.IDLE_AND_BUILD: 3>: 171956.22422}
#
#
# Best action is: Action.IDLE_AND_BUILD
# 4
# {'gas_price': 10.447054018974338, 'co2_price': 24.852060848032842, 'power_price': 72.17958032397992, 'plant_state': <PowerplantState.STAGE_1: 1>, 'balance': -65367519}
# Spark: 30.880465456972743
# {<Action.DO_NOTHING: 0>: 170295.68836, <Action.RUN: 1>: 170646.77935000003, <Action.RUN_AND_BUILD: 2>: 169708.40962, <Action.IDLE_AND_BUILD: 3>: 169481.29549000002}
#
#
# Best action is: Action.RUN
# 5
# {'gas_price': 9.780193104821738, 'co2_price': 24.932897119900474, 'power_price': 68.74746541081483, 'plant_state': <PowerplantState.STAGE_1: 1>, 'balance': -62084030}
# Spark: 28.034375186092618
# {<Action.DO_NOTHING: 0>: 166818.94201, <Action.RUN: 1>: 167080.36307999998, <Action.RUN_AND_BUILD: 2>: 166676.48162, <Action.IDLE_AND_BUILD: 3>: 166625.97606000002}
#
#
# Best action is: Action.RUN
# 6
# {'gas_price': 9.239347261651755, 'co2_price': 25.185847317601947, 'power_price': 73.48638263458146, 'plant_state': <PowerplantState.STAGE_1: 1>, 'balance': -59199854}
# Spark: 33.06118805532776
# {<Action.DO_NOTHING: 0>: 171338.54269, <Action.RUN: 1>: 171456.14475, <Action.RUN_AND_BUILD: 2>: 171596.87324000002, <Action.IDLE_AND_BUILD: 3>: 171175.73599000002}
#
#
# Best action is: Action.RUN_AND_BUILD
# 7
# {'gas_price': 9.3543550806195, 'co2_price': 25.57344638450415, 'power_price': 67.60621004206426, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': -120928825}
# Spark: 26.678408576940612
# {<Action.DO_NOTHING: 0>: 166607.98923999997, <Action.RUN: 1>: 166990.50649}
#
#
# Best action is: Action.RUN
# 8
# {'gas_price': 9.565656104164976, 'co2_price': 25.476126898186184, 'power_price': 62.42886656363804, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': -115540339}
# Spark: 21.387083561286882
# {<Action.DO_NOTHING: 0>: 161067.17079000003, <Action.RUN: 1>: 161202.27767}
#
#
# Best action is: Action.RUN
# 9
# {'gas_price': 9.89690107736374, 'co2_price': 24.84741133755297, 'power_price': 60.82646765608969, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': -111675188}
# Spark: 20.08215524117298
# {<Action.DO_NOTHING: 0>: 159336.18157, <Action.RUN: 1>: 159534.08714999998}
#
#
# Best action is: Action.RUN
# 10
# {'gas_price': 9.754921075330728, 'co2_price': 24.34015756413428, 'power_price': 55.49304706903626, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': -108171377}
# Spark: 15.39796842957125
# {<Action.DO_NOTHING: 0>: 154187.86534, <Action.RUN: 1>: 154701.91796000002}
#
#
# Best action is: Action.RUN
# 11
# {'gas_price': 9.219662263832756, 'co2_price': 24.72481365788907, 'power_price': 53.449256356384666, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': -106023271}
# Spark: 13.504780434662841
# {<Action.DO_NOTHING: 0>: 152124.76301999998, <Action.RUN: 1>: 152254.50818}
#
#
# Best action is: Action.RUN
# 12
# {'gas_price': 9.224418923228008, 'co2_price': 25.254203602810183, 'power_price': 50.17476014835965, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': -104418956}
# Spark: 9.696137622321462
# {<Action.DO_NOTHING: 0>: 147996.95926, <Action.RUN: 1>: 147922.80289}
#
#
# Best action is: Action.DO_NOTHING
# 13
# {'gas_price': 9.675889818067851, 'co2_price': 24.661083647155973, 'power_price': 53.74961408018576, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': -106771262}
# Spark: 13.412640614961933
# {<Action.DO_NOTHING: 0>: 151332.97392, <Action.RUN: 1>: 151648.67221999998}
#
#
# Best action is: Action.RUN
# 14
# {'gas_price': 9.13919558000867, 'co2_price': 25.141907045755534, 'power_price': 53.17338552443747, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': -105198233}
# Spark: 12.892282898673265
# {<Action.DO_NOTHING: 0>: 150333.77324, <Action.RUN: 1>: 150591.08525}
#
#
# Best action is: Action.RUN
# 15
# {'gas_price': 9.127308361285568, 'co2_price': 24.863725137035626, 'power_price': 52.29515631970331, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': -103769113}
# Spark: 12.304122821382116
# {<Action.DO_NOTHING: 0>: 149811.11491, <Action.RUN: 1>: 149905.32011}
#
#
# Best action is: Action.RUN
# 16
# {'gas_price': 9.64646294741408, 'co2_price': 25.30987928414337, 'power_price': 55.49291097933353, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': -102504627}
# Spark: 14.53656874777608
# {<Action.DO_NOTHING: 0>: 151715.91899, <Action.RUN: 1>: 151991.1908}
#
#
# Best action is: Action.RUN
# 17
# {'gas_price': 9.541464326963952, 'co2_price': 25.78873210543731, 'power_price': 57.886235104423164, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': -100577431}
# Spark: 16.5560386720219
# {<Action.DO_NOTHING: 0>: 153369.83975, <Action.RUN: 1>: 153631.74481}
#
#
# Best action is: Action.RUN
# 18
# {'gas_price': 9.472903703901384, 'co2_price': 26.65032576453154, 'power_price': 59.7349029590206, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': -98046319}
# Spark: 17.611673490587673
# {<Action.DO_NOTHING: 0>: 154178.87983, <Action.RUN: 1>: 154223.72816}
#
#
# Best action is: Action.RUN
# 19
# {'gas_price': 9.161409009174859, 'co2_price': 26.71735671729322, 'power_price': 59.59916726569706, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': -95190907}
# Spark: 17.72040153922898
# {<Action.DO_NOTHING: 0>: 153790.50120000003, <Action.RUN: 1>: 153928.67043}
#
#
# Best action is: Action.RUN
# 20
# {'gas_price': 9.394707748689623, 'co2_price': 27.06175393657606, 'power_price': 62.57063991898658, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': -92287422}
# Spark: 20.114178233720896
# {<Action.DO_NOTHING: 0>: 155906.40235000002, <Action.RUN: 1>: 156329.79243}
#
#
# Best action is: Action.RUN
# 21
# {'gas_price': 9.778247339340503, 'co2_price': 27.62217243010584, 'power_price': 62.30906217170272, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': -88664586}
# Spark: 18.908642402256376
# {<Action.DO_NOTHING: 0>: 154146.11225, <Action.RUN: 1>: 154548.65286}
#
#
# Best action is: Action.RUN
# 22
# {'gas_price': 10.710565500219401, 'co2_price': 26.962707068596092, 'power_price': 64.20834177558844, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': -85375273}
# Spark: 20.535069206772945
# {<Action.DO_NOTHING: 0>: 155599.44945999997, <Action.RUN: 1>: 155631.18301999997}
#
#
# Best action is: Action.RUN
# 23
# {'gas_price': 10.843775346705057, 'co2_price': 26.01695914916405, 'power_price': 61.76488614022524, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': -81589759}
# Spark: 18.904151644356126
# {<Action.DO_NOTHING: 0>: 153538.50229000003, <Action.RUN: 1>: 153889.94151}
#
#
# Best action is: Action.RUN
# 24
# {'gas_price': 10.474738215222882, 'co2_price': 24.88422372238504, 'power_price': 66.68241825476024, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': -78261762}
# Spark: 25.32345631715231
# {<Action.DO_NOTHING: 0>: 159767.09511000002, <Action.RUN: 1>: 159984.0012}
#
#
# Best action is: Action.RUN
# 25
# {'gas_price': 10.627935577119974, 'co2_price': 26.64890097079198, 'power_price': 70.76400667626123, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': -73029913}
# Spark: 27.487170128349277
# {<Action.DO_NOTHING: 0>: 161535.02672, <Action.RUN: 1>: 161408.58438}
#
#
# Best action is: Action.DO_NOTHING
# 26
# {'gas_price': 10.794521362380642, 'co2_price': 27.704388057295212, 'power_price': 78.05540686228237, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': -75204741}
# Spark: 33.55649744260651
# {<Action.DO_NOTHING: 0>: 167363.98596000002, <Action.RUN: 1>: 167657.08636000002}
#
#
# Best action is: Action.RUN
# 27
# {'gas_price': 10.554660874218822, 'co2_price': 29.546812864583156, 'power_price': 76.91828308223852, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': -67537966}
# Spark: 30.81680934343653
# {<Action.DO_NOTHING: 0>: 163928.20882, <Action.RUN: 1>: 164196.54437000002}
#
#
# Best action is: Action.RUN
# 28
# {'gas_price': 11.02342601115297, 'co2_price': 28.786572615324552, 'power_price': 86.48776560867597, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': -60632354}
# Spark: 40.67776698219845
# {<Action.DO_NOTHING: 0>: 173458.46785999998, <Action.RUN: 1>: 173605.36521000002}
#
#
# Best action is: Action.RUN
# 29
# {'gas_price': 10.981412020735569, 'co2_price': 29.0733104671239, 'power_price': 86.39282496594684, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': -50792017}
# Spark: 40.33810247808737
# {<Action.DO_NOTHING: 0>: 172716.7995, <Action.RUN: 1>: 173157.61258}
#
#
# Best action is: Action.RUN
# 30
# {'gas_price': 11.25019028450872, 'co2_price': 30.341225669208313, 'power_price': 79.92642727005978, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': -40995784}
# Spark: 32.335011316342744
# {<Action.DO_NOTHING: 0>: 164294.06539, <Action.RUN: 1>: 164702.16728999998}
#
#
# Best action is: Action.RUN
# 31
# {'gas_price': 10.80800955055133, 'co2_price': 30.916019436633327, 'power_price': 78.7948364744575, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': -33494277}
# Spark: 31.070807487272845
# {<Action.DO_NOTHING: 0>: 162592.28661, <Action.RUN: 1>: 162865.13954}
#
#
# Best action is: Action.RUN
# 32
# {'gas_price': 10.819406020816464, 'co2_price': 29.152443363320632, 'power_price': 84.16077457438911, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': -26321591}
# Spark: 38.188925190252014
# {<Action.DO_NOTHING: 0>: 168865.1645, <Action.RUN: 1>: 169630.27077}
#
#
# Best action is: Action.RUN
# 33
# {'gas_price': 11.389339899775402, 'co2_price': 28.79500364253569, 'power_price': 83.97977990412306, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': -17018107}
# Spark: 37.79543636181197
# {<Action.DO_NOTHING: 0>: 168569.89694, <Action.RUN: 1>: 168622.732}
#
#
# Best action is: Action.RUN
# 34
# {'gas_price': 12.151027329354282, 'co2_price': 29.01658759331345, 'power_price': 87.96925803878035, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': -7777568}
# Spark: 40.80164311611263
# {<Action.DO_NOTHING: 0>: 171134.73473999999, <Action.RUN: 1>: 171428.40569999997}
#
#
# Best action is: Action.RUN
# 35
# {'gas_price': 12.454155759525142, 'co2_price': 30.749966661242006, 'power_price': 83.34685866544513, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 2388450}
# Spark: 34.14273624467798
# {<Action.DO_NOTHING: 0>: 164305.72117, <Action.RUN: 1>: 164649.92101}
#
#
# Best action is: Action.RUN
# 36
# {'gas_price': 12.608686624862742, 'co2_price': 31.501211423885383, 'power_price': 82.1138736304741, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 10623646}
# Spark: 32.00397558172598
# {<Action.DO_NOTHING: 0>: 161562.94676, <Action.RUN: 1>: 161861.01231}
#
#
# Best action is: Action.RUN
# 37
# {'gas_price': 13.177485840844318, 'co2_price': 31.64471188515115, 'power_price': 80.77748825531083, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 18246893}
# Spark: 29.955290529315356
# {<Action.DO_NOTHING: 0>: 159271.54199, <Action.RUN: 1>: 159488.96626999998}
#
#
# Best action is: Action.RUN
# 38
# {'gas_price': 13.5400057875909, 'co2_price': 32.55281647859841, 'power_price': 82.25713001787193, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 25283527}
# Spark: 30.16430775168262
# {<Action.DO_NOTHING: 0>: 158845.07211, <Action.RUN: 1>: 159035.15511}
#
#
# Best action is: Action.RUN
# 39
# {'gas_price': 14.278096898834347, 'co2_price': 33.603114903677316, 'power_price': 79.49236838405577, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 32392916}
# Spark: 25.6111565815441
# {<Action.DO_NOTHING: 0>: 153941.80839, <Action.RUN: 1>: 154203.67439}
#
#
# Best action is: Action.RUN
# 40
# {'gas_price': 14.511672571001103, 'co2_price': 33.83705949801011, 'power_price': 77.65024160610085, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 38182331}
# Spark: 23.301509537089633
# {<Action.DO_NOTHING: 0>: 150747.92419, <Action.RUN: 1>: 151124.76831}
#
#
# Best action is: Action.RUN
# 41
# {'gas_price': 14.803988295494596, 'co2_price': 35.69133674953446, 'power_price': 80.30499453359941, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 43305777}
# Spark: 23.809669488570357
# {<Action.DO_NOTHING: 0>: 151228.74205999996, <Action.RUN: 1>: 151641.29554}
#
#
# Best action is: Action.RUN
# 42
# {'gas_price': 15.664297148681204, 'co2_price': 35.363886833169516, 'power_price': 82.04302248479624, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 48586312}
# Spark: 25.01483850294552
# {<Action.DO_NOTHING: 0>: 152111.46256, <Action.RUN: 1>: 152444.37593}
#
#
# Best action is: Action.RUN
# 43
# {'gas_price': 15.599819040708978, 'co2_price': 36.69607732564748, 'power_price': 80.63518059575873, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 54228059}
# Spark: 22.339284229402267
# {<Action.DO_NOTHING: 0>: 148819.93102, <Action.RUN: 1>: 148941.70789999998}
#
#
# Best action is: Action.RUN
# 44
# {'gas_price': 16.087439146536447, 'co2_price': 36.132551958297014, 'power_price': 86.47045807645839, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 59096572}
# Spark: 28.250466971624924
# {<Action.DO_NOTHING: 0>: 154434.94688000003, <Action.RUN: 1>: 154968.88588}
#
#
# Best action is: Action.RUN
# 45
# {'gas_price': 15.590501557381938, 'co2_price': 35.513053165706786, 'power_price': 87.31503391688717, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 65702042}
# Spark: 30.211479193798453
# {<Action.DO_NOTHING: 0>: 156061.68394999998, <Action.RUN: 1>: 156039.39659}
#
#
# Best action is: Action.DO_NOTHING
# 46
# {'gas_price': 15.79237732885854, 'co2_price': 35.60275106972251, 'power_price': 87.37288274553593, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 64055661}
# Spark: 29.97775434695488
# {<Action.DO_NOTHING: 0>: 155034.74076999997, <Action.RUN: 1>: 155264.79545999996}
#
#
# Best action is: Action.RUN
# 47
# {'gas_price': 15.356083823178444, 'co2_price': 35.96625723645922, 'power_price': 84.53244360134606, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 71174522}
# Spark: 27.210102541708395
# {<Action.DO_NOTHING: 0>: 152173.78319999998, <Action.RUN: 1>: 152302.38269}
#
#
# Best action is: Action.RUN
# 48
# {'gas_price': 15.719387312021102, 'co2_price': 35.60609038834303, 'power_price': 81.26308374389167, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 77495651}
# Spark: 23.93760604352754
# {<Action.DO_NOTHING: 0>: 148439.79003, <Action.RUN: 1>: 148846.30105}
#
#
# Best action is: Action.RUN
# 49
# {'gas_price': 15.260437259187343, 'co2_price': 34.79943866525355, 'power_price': 80.39958600538098, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 82870073}
# Spark: 24.339710080940094
# {<Action.DO_NOTHING: 0>: 148030.4776, <Action.RUN: 1>: 148396.23398}
#
#
# Best action is: Action.RUN
# 50
# {'gas_price': 15.117287066455162, 'co2_price': 34.5982205772385, 'power_price': 84.27149423312439, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 88370980}
# Spark: 28.555986589430724
# {<Action.DO_NOTHING: 0>: 152149.20037, <Action.RUN: 1>: 152256.91756}
#
#
# Best action is: Action.RUN
# 51
# {'gas_price': 15.954114346571803, 'co2_price': 32.97194832113084, 'power_price': 89.29123381833995, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 95114158}
# Spark: 34.36517115063731
# {<Action.DO_NOTHING: 0>: 157261.67942, <Action.RUN: 1>: 157661.99852}
#
#
# Best action is: Action.RUN
# 52
# {'gas_price': 14.942592572913497, 'co2_price': 30.592624059712076, 'power_price': 93.75534275937075, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 103567556}
# Spark: 42.22012612674517
# {<Action.DO_NOTHING: 0>: 164207.04942000002, <Action.RUN: 1>: 164757.05122000002}
#
#
# Best action is: Action.RUN
# 53
# {'gas_price': 14.051362839831217, 'co2_price': 31.03581023689949, 'power_price': 93.955070425165, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 114332351}
# Spark: 42.8678973484343
# {<Action.DO_NOTHING: 0>: 164647.05368, <Action.RUN: 1>: 165079.67844}
#
#
# Best action is: Action.RUN
# 54
# {'gas_price': 13.705902358393434, 'co2_price': 31.563377406624703, 'power_price': 92.93265194106668, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 125304386}
# Spark: 41.66337217604854
# {<Action.DO_NOTHING: 0>: 163062.51807, <Action.RUN: 1>: 163712.51411999998}
#
#
# Best action is: Action.RUN
# 55
# {'gas_price': 14.19025059978553, 'co2_price': 33.089535648301144, 'power_price': 97.07187236083509, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 135942240}
# Spark: 43.792086112748414
# {<Action.DO_NOTHING: 0>: 164895.86989, <Action.RUN: 1>: 165144.37469000003}
#
#
# Best action is: Action.RUN
# 56
# {'gas_price': 15.172902816298155, 'co2_price': 32.33592026829305, 'power_price': 104.57117226368216, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 147220274}
# Spark: 51.06234917909095
# {<Action.DO_NOTHING: 0>: 171245.65135000003, <Action.RUN: 1>: 171894.37395}
#
#
# Best action is: Action.RUN
# 57
# {'gas_price': 13.826530111960473, 'co2_price': 31.871644338272617, 'power_price': 110.23605575208153, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 160643358}
# Spark: 58.537881301848444
# {<Action.DO_NOTHING: 0>: 177877.00548, <Action.RUN: 1>: 178417.81386}
#
#
# Best action is: Action.RUN
# 58
# {'gas_price': 13.864844973025363, 'co2_price': 31.668826899349497, 'power_price': 117.92123808101995, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 176275072}
# Spark: 66.3875662086451
# {<Action.DO_NOTHING: 0>: 185471.06772999998, <Action.RUN: 1>: 186115.38122000004}
#
#
# Best action is: Action.RUN
# 59
# {'gas_price': 14.236174549541605, 'co2_price': 32.153582247696036, 'power_price': 121.24236943324274, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 194228497}
# Spark: 68.8526126360051
# {<Action.DO_NOTHING: 0>: 187261.02105, <Action.RUN: 1>: 188010.36748}
#
#
# Best action is: Action.RUN
# 60
# {'gas_price': 13.91384363560339, 'co2_price': 31.955049692746638, 'power_price': 111.32194023252767, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 212932555}
# Spark: 59.45304690417764
# {<Action.DO_NOTHING: 0>: 178065.53356, <Action.RUN: 1>: 178305.55539}
#
#
# Best action is: Action.RUN
# 61
# {'gas_price': 13.848665130379958, 'co2_price': 32.28186301694825, 'power_price': 113.00419287944086, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 228918298}
# Spark: 60.87366473211266
# {<Action.DO_NOTHING: 0>: 178762.54557, <Action.RUN: 1>: 179360.80239}
#
#
# Best action is: Action.RUN
# 62
# {'gas_price': 13.183896250710935, 'co2_price': 32.4923615528901, 'power_price': 115.67889378056451, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 245345949}
# Spark: 64.00263597696348
# {<Action.DO_NOTHING: 0>: 180938.4501, <Action.RUN: 1>: 181530.1695}
#
#
# Best action is: Action.RUN
# 63
# {'gas_price': 12.701413976157504, 'co2_price': 30.79033656839712, 'power_price': 113.44525148921446, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 262715900}
# Spark: 63.95350094465982
# {<Action.DO_NOTHING: 0>: 180291.4496, <Action.RUN: 1>: 181105.97462}
#
#
# Best action is: Action.RUN
# 64
# {'gas_price': 12.01917854238449, 'co2_price': 30.999957758760186, 'power_price': 107.36930199297213, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 280100168}
# Spark: 58.35016569182744
# {<Action.DO_NOTHING: 0>: 174391.54729999998, <Action.RUN: 1>: 174837.47052999996}
#
#
# Best action is: Action.RUN
# 65
# {'gas_price': 11.92358267897943, 'co2_price': 31.911101394577216, 'power_price': 106.61145566365799, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 295874271}
# Spark: 56.77677159010135
# {<Action.DO_NOTHING: 0>: 172057.15219, <Action.RUN: 1>: 172932.89638}
#
#
# Best action is: Action.RUN
# 66
# {'gas_price': 12.016773118470303, 'co2_price': 31.611265150241678, 'power_price': 99.8330267332664, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 311214236}
# Spark: 50.20498846455441
# {<Action.DO_NOTHING: 0>: 165118.58544999998, <Action.RUN: 1>: 165965.35236000002}
#
#
# Best action is: Action.RUN
# 67
# {'gas_price': 11.414895794891704, 'co2_price': 31.375150742652682, 'power_price': 99.1691413345681, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 324657407}
# Spark: 50.37909479702371
# {<Action.DO_NOTHING: 0>: 164791.80879, <Action.RUN: 1>: 165428.43421}
#
#
# Best action is: Action.RUN
# 68
# {'gas_price': 11.524100712995798, 'co2_price': 31.4644574060574, 'power_price': 98.51786910822938, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 338173703}
# Spark: 49.52931098917619
# {<Action.DO_NOTHING: 0>: 163124.24494, <Action.RUN: 1>: 163656.22545}
#
#
# Best action is: Action.RUN
# 69
# {'gas_price': 12.267490101173257, 'co2_price': 31.56069214906104, 'power_price': 102.66411432719462, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 351463776}
# Spark: 52.835932076960326
# {<Action.DO_NOTHING: 0>: 165879.31107000003, <Action.RUN: 1>: 166488.84275}
#
#
# Best action is: Action.RUN
# 70
# {'gas_price': 12.874266642549278, 'co2_price': 30.91642006115464, 'power_price': 99.24875288808676, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 365742926}
# Spark: 49.45806618438284
# {<Action.DO_NOTHING: 0>: 162401.15839, <Action.RUN: 1>: 162719.24461}
#
#
# Best action is: Action.RUN
# 71
# {'gas_price': 12.880824299660267, 'co2_price': 30.665521437068776, 'power_price': 98.8572371304044, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 379057694}
# Spark: 49.310891393675355
# {<Action.DO_NOTHING: 0>: 161731.80122999998, <Action.RUN: 1>: 162366.57888}
#
#
# Best action is: Action.RUN
# 72
# {'gas_price': 12.840306980233986, 'co2_price': 30.687514001180844, 'power_price': 94.28750188924647, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 392351406}
# Spark: 44.75968090783164
# {<Action.DO_NOTHING: 0>: 156898.51518000002, <Action.RUN: 1>: 157343.56808}
#
#
# Best action is: Action.RUN
# 73
# {'gas_price': 12.898361546249468, 'co2_price': 32.16530099520944, 'power_price': 92.33970746878501, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 404335925}
# Spark: 41.2760449273261
# {<Action.DO_NOTHING: 0>: 152602.73132999998, <Action.RUN: 1>: 153395.46633}
#
#
# Best action is: Action.RUN
# 74
# {'gas_price': 13.791666287637792, 'co2_price': 33.1572213215275, 'power_price': 94.77117961843989, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 415321336}
# Spark: 41.82229200927459
# {<Action.DO_NOTHING: 0>: 152628.46399000002, <Action.RUN: 1>: 152867.64956999998}
#
#
# Best action is: Action.RUN
# 75
# {'gas_price': 14.312275779625837, 'co2_price': 34.08928074120238, 'power_price': 100.10790751530247, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 426484658}
# Spark: 45.70635099447425
# {<Action.DO_NOTHING: 0>: 155788.19203, <Action.RUN: 1>: 156260.57978}
#
#
# Best action is: Action.RUN
# 76
# {'gas_price': 13.861534393708727, 'co2_price': 33.563656923952394, 'power_price': 94.96245682860776, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 438802435}
# Spark: 41.53726551094664
# {<Action.DO_NOTHING: 0>: 151537.83220999996, <Action.RUN: 1>: 151969.70210999998}
#
#
# Best action is: Action.RUN
# 77
# {'gas_price': 14.256636356986684, 'co2_price': 33.27051486455357, 'power_price': 93.75600359021492, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 449921173}
# Spark: 40.228852368674666
# {<Action.DO_NOTHING: 0>: 149483.92618, <Action.RUN: 1>: 150196.10438}
#
#
# Best action is: Action.RUN
# 78
# {'gas_price': 14.112635294543583, 'co2_price': 33.36040488903707, 'power_price': 95.09352638951226, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 460675587}
# Spark: 41.62048620593161
# {<Action.DO_NOTHING: 0>: 150713.01718, <Action.RUN: 1>: 151139.82271}
#
#
# Best action is: Action.RUN
# 79
# {'gas_price': 14.277234942407986, 'co2_price': 34.44559587545105, 'power_price': 92.23762321170688, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 471854791}
# Spark: 37.51479239384784
# {<Action.DO_NOTHING: 0>: 145976.03913, <Action.RUN: 1>: 146622.79140000002}
#
#
# Best action is: Action.RUN
# 80
# {'gas_price': 13.347726329279183, 'co2_price': 33.47319720421345, 'power_price': 85.49271199910261, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 481851615}
# Spark: 32.67178846560998
# {<Action.DO_NOTHING: 0>: 141252.40760000004, <Action.RUN: 1>: 141935.90993}
#
#
# Best action is: Action.RUN
# 81
# {'gas_price': 13.418910254087677, 'co2_price': 32.42729441307997, 'power_price': 89.2072333678876, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 490448457}
# Spark: 37.36102870071995
# {<Action.DO_NOTHING: 0>: 144985.83285000004, <Action.RUN: 1>: 145617.97728999998}
#
#
# Best action is: Action.RUN
# 82
# {'gas_price': 12.911600819063112, 'co2_price': 31.362991742476144, 'power_price': 93.52123179904838, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 500431017}
# Spark: 43.24663923750913
# {<Action.DO_NOTHING: 0>: 149888.30537000002, <Action.RUN: 1>: 150457.56202999997}
#
#
# Best action is: Action.RUN
# 83
# {'gas_price': 11.93186569476206, 'co2_price': 31.83916831223655, 'power_price': 89.79128601535771, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 512151501}
# Spark: 40.0202520083591
# {<Action.DO_NOTHING: 0>: 146774.04778, <Action.RUN: 1>: 147236.04833}
#
#
# Best action is: Action.RUN
# 84
# {'gas_price': 11.867942363651306, 'co2_price': 31.950753885377654, 'power_price': 89.32699270038277, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 522947681}
# Spark: 39.508296451353814
# {<Action.DO_NOTHING: 0>: 145907.8052, <Action.RUN: 1>: 146054.26473000002}
#
#
# Best action is: Action.RUN
# 85
# {'gas_price': 11.401459151887103, 'co2_price': 31.050748976738923, 'power_price': 85.93466851926256, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 533611954}
# Spark: 37.48246039063653
# {<Action.DO_NOTHING: 0>: 143165.89379, <Action.RUN: 1>: 143650.66370999996}
#
#
# Best action is: Action.RUN
# 86
# {'gas_price': 10.912117665278283, 'co2_price': 32.52744479222088, 'power_price': 84.87196521618033, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 543701319}
# Spark: 35.43240275868117
# {<Action.DO_NOTHING: 0>: 141093.84199000002, <Action.RUN: 1>: 141514.77199}
#
#
# Best action is: Action.RUN
# 87
# {'gas_price': 11.48171737846526, 'co2_price': 32.58020858594142, 'power_price': 92.06524020910112, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 553207742}
# Spark: 42.00331424469444
# {<Action.DO_NOTHING: 0>: 146716.67165999996, <Action.RUN: 1>: 147279.83608}
#
#
# Best action is: Action.RUN
# 88
# {'gas_price': 11.807759909590178, 'co2_price': 32.5414559363239, 'power_price': 93.85816692160094, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 564651740}
# Spark: 43.508951075686866
# {<Action.DO_NOTHING: 0>: 147768.19358000002, <Action.RUN: 1>: 147951.66127999997}
#
#
# Best action is: Action.RUN
# 89
# {'gas_price': 12.059452292044314, 'co2_price': 33.897934617866994, 'power_price': 93.33418897678693, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 576555011}
# Spark: 41.37680206687563
# {<Action.DO_NOTHING: 0>: 145141.41909000004, <Action.RUN: 1>: 145799.58445}
#
#
# Best action is: Action.RUN
# 90
# {'gas_price': 11.510802500215469, 'co2_price': 34.32917597217209, 'power_price': 94.6367611106127, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 587854326}
# Spark: 42.79678263822514
# {<Action.DO_NOTHING: 0>: 145968.71509, <Action.RUN: 1>: 146533.03475}
#
#
# Best action is: Action.RUN
# 91
# {'gas_price': 12.356204939634916, 'co2_price': 33.87619266654991, 'power_price': 96.05074345811514, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 599587621}
# Spark: 43.81834585193031
# {<Action.DO_NOTHING: 0>: 146796.74053000004, <Action.RUN: 1>: 147477.26275999998}
#
#
# Best action is: Action.RUN
# 92
# {'gas_price': 12.343356158545896, 'co2_price': 34.96731601067772, 'power_price': 94.27548047800451, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 611639084}
# Spark: 40.964808308780896
# {<Action.DO_NOTHING: 0>: 143593.6684, <Action.RUN: 1>: 143984.64979000002}
#
#
# Best action is: Action.RUN
# 93
# {'gas_price': 12.33506659487921, 'co2_price': 34.473083249994396, 'power_price': 96.16785340332743, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 622875842}
# Spark: 43.35970355845382
# {<Action.DO_NOTHING: 0>: 145590.89007, <Action.RUN: 1>: 145829.42068}
#
#
# Best action is: Action.RUN
# 94
# {'gas_price': 11.786796589775165, 'co2_price': 35.510233071469855, 'power_price': 98.19933788108226, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 634831623}
# Spark: 44.90230821983724
# {<Action.DO_NOTHING: 0>: 146279.68433999998, <Action.RUN: 1>: 146975.99955}
#
#
# Best action is: Action.RUN
# 95
# {'gas_price': 12.791070964101648, 'co2_price': 36.069469114206676, 'power_price': 98.19736560776366, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 647258334}
# Spark: 43.33682552945533
# {<Action.DO_NOTHING: 0>: 144310.23396, <Action.RUN: 1>: 144744.17519}
#
#
# Best action is: Action.RUN
# 96
# {'gas_price': 13.134216313180241, 'co2_price': 34.75302826235253, 'power_price': 104.93366788120932, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 659247693}
# Spark: 51.04642330567655
# {<Action.DO_NOTHING: 0>: 150793.4363, <Action.RUN: 1>: 151348.20649}
#
#
# Best action is: Action.RUN
# 97
# {'gas_price': 12.800926429112563, 'co2_price': 35.0873952669284, 'power_price': 105.5378477963744, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 673511774}
# Spark: 51.64952610033343
# {<Action.DO_NOTHING: 0>: 150549.9529, <Action.RUN: 1>: 151317.85687000002}
#
#
# Best action is: Action.RUN
# 98
# {'gas_price': 12.902877737508927, 'co2_price': 34.14899883797074, 'power_price': 104.25372387809237, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 687975810}
# Spark: 51.201847302612705
# {<Action.DO_NOTHING: 0>: 149814.73129, <Action.RUN: 1>: 150356.04021999997}
#
#
# Best action is: Action.RUN
# 99
# {'gas_price': 12.410634748258627, 'co2_price': 34.21966819362961, 'power_price': 99.39956488220245, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 702332797}
# Spark: 46.76926194031422
# {<Action.DO_NOTHING: 0>: 144927.66458, <Action.RUN: 1>: 145753.86439}
#
#
# Best action is: Action.RUN
# 100
# {'gas_price': 12.586380895801463, 'co2_price': 36.14789322919611, 'power_price': 99.87935772681624, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 715417043}
# Spark: 45.14508360181867
# {<Action.DO_NOTHING: 0>: 142763.17338999998, <Action.RUN: 1>: 143422.65576}
#
#
# Best action is: Action.RUN
# 101
# {'gas_price': 12.90976040473462, 'co2_price': 37.50732655207868, 'power_price': 94.72447471913928, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 728047855}
# Spark: 38.30738776232598
# {<Action.DO_NOTHING: 0>: 136416.40617000003, <Action.RUN: 1>: 136516.46611}
#
#
# Best action is: Action.RUN
# 102
# {'gas_price': 12.972578375937196, 'co2_price': 37.360210607866904, 'power_price': 98.1378255066633, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 738699623}
# Spark: 41.805036522859204
# {<Action.DO_NOTHING: 0>: 138931.96716, <Action.RUN: 1>: 139241.22373000003}
#
#
# Best action is: Action.RUN
# 103
# {'gas_price': 13.219735925876655, 'co2_price': 38.50659211296993, 'power_price': 99.28531030283526, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 750391984}
# Spark: 41.55898226398867
# {<Action.DO_NOTHING: 0>: 138432.56938, <Action.RUN: 1>: 138798.50431}
#
#
# Best action is: Action.RUN
# 104
# {'gas_price': 12.699032010344665, 'co2_price': 37.97872357085274, 'power_price': 105.39397573072361, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 762031689}
# Spark: 48.71622014952621
# {<Action.DO_NOTHING: 0>: 144554.92055, <Action.RUN: 1>: 145143.20323}
#
#
# Best action is: Action.RUN
# 105
# {'gas_price': 13.118131130571369, 'co2_price': 39.32548839971347, 'power_price': 106.57632147941804, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 775783983}
# Spark: 48.13270194913319
# {<Action.DO_NOTHING: 0>: 143664.50892000002, <Action.RUN: 1>: 143971.37140000003}
#
#
# Best action is: Action.RUN
# 106
# {'gas_price': 13.03469131031822, 'co2_price': 39.764393031093235, 'power_price': 107.31489951065934, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 789388321}
# Spark: 48.51581516924789
# {<Action.DO_NOTHING: 0>: 143131.537, <Action.RUN: 1>: 143762.17749}
#
#
# Best action is: Action.RUN
# 107
# {'gas_price': 12.637937497393718, 'co2_price': 38.324089989543864, 'power_price': 105.29787900887462, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 803127182}
# Spark: 48.33585152193703
# {<Action.DO_NOTHING: 0>: 142321.69020999997, <Action.RUN: 1>: 142847.61602000002}
#
#
# Best action is: Action.RUN
# 108
# {'gas_price': 13.10920887204523, 'co2_price': 38.85088389282707, 'power_price': 109.62508604108655, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 816836097}
# Spark: 51.66499327621425
# {<Action.DO_NOTHING: 0>: 144972.19285, <Action.RUN: 1>: 145702.01949}
#
#
# Best action is: Action.RUN
# 109
# {'gas_price': 12.535002109766374, 'co2_price': 40.06708996741645, 'power_price': 102.07453137902448, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 831541369}
# Spark: 43.47243930184165
# {<Action.DO_NOTHING: 0>: 137021.04437000002, <Action.RUN: 1>: 137481.08828000003}
#
#
# Best action is: Action.RUN
# 110
# {'gas_price': 12.278855334781733, 'co2_price': 41.75548691029925, 'power_price': 103.17383195259556, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 843874751}
# Spark: 43.139489707514585
# {<Action.DO_NOTHING: 0>: 136164.08122000002, <Action.RUN: 1>: 136732.08563}
#
#
# Best action is: Action.RUN
# 111
# {'gas_price': 12.767032702423986, 'co2_price': 42.24584759657019, 'power_price': 113.21787302254666, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 856131121}
# Spark: 52.20499272355248
# {<Action.DO_NOTHING: 0>: 143810.55239, <Action.RUN: 1>: 144550.38207}
#
#
# Best action is: Action.RUN
# 112
# {'gas_price': 12.862892940846383, 'co2_price': 43.62736543992013, 'power_price': 112.27935398051423, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 871059232}
# Spark: 49.78909559974771
# {<Action.DO_NOTHING: 0>: 141373.18568999998, <Action.RUN: 1>: 142069.41263}
#
#
# Best action is: Action.RUN
# 113
# {'gas_price': 13.03372440339635, 'co2_price': 42.63987800869915, 'power_price': 105.48824904669246, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 885305391}
# Spark: 43.81464663459696
# {<Action.DO_NOTHING: 0>: 135688.53033999997, <Action.RUN: 1>: 136386.1985}
#
#
# Best action is: Action.RUN
# 114
# {'gas_price': 12.389152662682811, 'co2_price': 41.93382743569377, 'power_price': 106.98925289338963, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 897827658}
# Spark: 46.66627279501305
# {<Action.DO_NOTHING: 0>: 137811.39077, <Action.RUN: 1>: 138225.6082}
#
#
# Best action is: Action.RUN
# 115
# {'gas_price': 12.336975893737861, 'co2_price': 39.12693975330548, 'power_price': 101.91147402119951, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 911204657}
# Spark: 44.44755837415617
# {<Action.DO_NOTHING: 0>: 135772.72759, <Action.RUN: 1>: 136071.37565}
#
#
# Best action is: Action.RUN
# 116
# {'gas_price': 13.137222755131015, 'co2_price': 39.09008131949544, 'power_price': 95.87508525580354, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 923954814}
# Spark: 37.64778118117709
# {<Action.DO_NOTHING: 0>: 128471.85641, <Action.RUN: 1>: 128883.76540999999}
#
#
# Best action is: Action.RUN
# 117
# {'gas_price': 12.715747056140133, 'co2_price': 38.753069606546774, 'power_price': 95.60263839309997, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 934737215}
# Spark: 38.13382173041306
# {<Action.DO_NOTHING: 0>: 128385.31239, <Action.RUN: 1>: 128762.42452000002}
#
#
# Best action is: Action.RUN
# 118
# {'gas_price': 12.990389898405175, 'co2_price': 39.88514197989383, 'power_price': 94.37484720530406, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 945679582}
# Spark: 35.49931532700506
# {<Action.DO_NOTHING: 0>: 125103.55659000001, <Action.RUN: 1>: 125560.93333}
#
#
# Best action is: Action.RUN
# 119
# {'gas_price': 12.523382517600009, 'co2_price': 39.81276601223784, 'power_price': 94.55017771625941, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 955869475}
# Spark: 36.21402918642157
# {<Action.DO_NOTHING: 0>: 125229.97739, <Action.RUN: 1>: 125867.62748000001}
#
#
# Best action is: Action.RUN
# 120
# {'gas_price': 12.704622828575829, 'co2_price': 40.562837154196735, 'power_price': 96.0451726828906, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 966285239}
# Spark: 36.77771270011803
# {<Action.DO_NOTHING: 0>: 124943.32715, <Action.RUN: 1>: 125543.14907}
#
#
# Best action is: Action.RUN
# 121
# {'gas_price': 11.838009502009466, 'co2_price': 41.68142800290845, 'power_price': 97.06573705363807, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 976883073}
# Spark: 37.54629954872016
# {<Action.DO_NOTHING: 0>: 125191.25794, <Action.RUN: 1>: 125601.73064}
#
#
# Best action is: Action.RUN
# 122
# {'gas_price': 12.208358594219005, 'co2_price': 41.460145586105796, 'power_price': 96.04081558507077, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 987723208}
# Spark: 36.37231140474597
# {<Action.DO_NOTHING: 0>: 123497.99742, <Action.RUN: 1>: 123856.68994}
#
#
# Best action is: Action.RUN
# 123
# {'gas_price': 12.604375340089648, 'co2_price': 41.35403073537538, 'power_price': 95.88496588916013, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 998237876}
# Spark: 35.9265598136951
# {<Action.DO_NOTHING: 0>: 122510.10487000001, <Action.RUN: 1>: 122915.77581}
#
#
# Best action is: Action.RUN
# 124
# {'gas_price': 12.304726951871592, 'co2_price': 41.60381403523209, 'power_price': 94.67556593138185, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1008639535}
# Spark: 34.76702494427817
# {<Action.DO_NOTHING: 0>: 120917.3653, <Action.RUN: 1>: 121425.33608}
#
#
# Best action is: Action.RUN
# 125
# {'gas_price': 12.169701156231714, 'co2_price': 42.222884449548744, 'power_price': 99.68714995964015, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1018719230}
# Spark: 39.2945643538597
# {<Action.DO_NOTHING: 0>: 124279.81006, <Action.RUN: 1>: 124658.43307}
#
#
# Best action is: Action.RUN
# 126
# {'gas_price': 11.577838126979582, 'co2_price': 43.25693111076672, 'power_price': 105.33332635365153, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1030139797}
# Spark: 44.49855711590523
# {<Action.DO_NOTHING: 0>: 128182.39472999999, <Action.RUN: 1>: 128841.94609}
#
#
# Best action is: Action.RUN
# 127
# {'gas_price': 11.946934684561908, 'co2_price': 42.70217124336795, 'power_price': 102.88944372853904, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1043101302}
# Spark: 42.240337800609176
# {<Action.DO_NOTHING: 0>: 125637.60017, <Action.RUN: 1>: 126124.76277999999}
#
#
# Best action is: Action.RUN
# 128
# {'gas_price': 12.4035985692295, 'co2_price': 43.52621862486366, 'power_price': 107.9771619330552, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1055423725}
# Spark: 46.04734473896204
# {<Action.DO_NOTHING: 0>: 128302.59492, <Action.RUN: 1>: 129125.1111}
#
#
# Best action is: Action.RUN
# 129
# {'gas_price': 12.490228593167952, 'co2_price': 43.24923581148513, 'power_price': 115.5588756718013, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1068879981}
# Spark: 53.81941126714821
# {<Action.DO_NOTHING: 0>: 134543.15842, <Action.RUN: 1>: 135526.12029}
#
#
# Best action is: Action.RUN
# 130
# {'gas_price': 12.267438971704914, 'co2_price': 41.421809999687504, 'power_price': 116.18653468776726, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1084631653}
# Spark: 56.49728571637484
# {<Action.DO_NOTHING: 0>: 136434.51666000002, <Action.RUN: 1>: 137114.0719}
#
#
# Best action is: Action.RUN
# 131
# {'gas_price': 12.505179301696945, 'co2_price': 42.543937721747184, 'power_price': 129.3945614899849, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1101192571}
# Spark: 68.34544446654078
# {<Action.DO_NOTHING: 0>: 145969.33166, <Action.RUN: 1>: 146824.16226999997}
#
#
# Best action is: Action.RUN
# 132
# {'gas_price': 12.926492224529598, 'co2_price': 42.61226342956564, 'power_price': 135.09843522346677, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1121246217}
# Spark: 73.55967956937153
# {<Action.DO_NOTHING: 0>: 149904.78791999997, <Action.RUN: 1>: 150866.46177000002}
#
#
# Best action is: Action.RUN
# 133
# {'gas_price': 12.788054141219872, 'co2_price': 44.05073607157925, 'power_price': 141.49871710719697, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1142858054}
# Spark: 78.65992689439784
# {<Action.DO_NOTHING: 0>: 153793.94522999998, <Action.RUN: 1>: 154600.74099000002}
#
#
# Best action is: Action.RUN
# 134
# {'gas_price': 12.516492303053809, 'co2_price': 43.53121242039609, 'power_price': 142.62193799939845, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1165997317}
# Spark: 80.57423327594856
# {<Action.DO_NOTHING: 0>: 154640.87076999998, <Action.RUN: 1>: 155515.10650999998}
#
#
# Best action is: Action.RUN
# 135
# {'gas_price': 12.528716650256621, 'co2_price': 44.3729321530613, 'power_price': 145.47314917810698, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1189734697}
# Spark: 82.57150037478905
# {<Action.DO_NOTHING: 0>: 156004.65593, <Action.RUN: 1>: 156502.99994}
#
#
# Best action is: Action.RUN
# 136
# {'gas_price': 12.1910766042816, 'co2_price': 44.65597318958999, 'power_price': 148.7331847636974, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1214095446}
# Spark: 85.88613496982582
# {<Action.DO_NOTHING: 0>: 158168.2213, <Action.RUN: 1>: 159191.21255000003}
#
#
# Best action is: Action.RUN
# 137
# {'gas_price': 12.329063533978802, 'co2_price': 43.667354423949725, 'power_price': 155.93817815797996, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1239465901}
# Spark: 93.94176020005145
# {<Action.DO_NOTHING: 0>: 164196.22901999997, <Action.RUN: 1>: 165320.97313}
#
#
# Best action is: Action.RUN
# 138
# {'gas_price': 12.23417350571042, 'co2_price': 43.29203724075202, 'power_price': 153.12640884707636, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1267234385}
# Spark: 91.60019810061392
# {<Action.DO_NOTHING: 0>: 161970.76173, <Action.RUN: 1>: 162600.75924}
#
#
# Best action is: Action.RUN
# 139
# {'gas_price': 12.053931223893315, 'co2_price': 42.961758564074685, 'power_price': 150.94563329696865, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1294363865}
# Spark: 89.92994350900065
# {<Action.DO_NOTHING: 0>: 159762.53555, <Action.RUN: 1>: 160906.61016000004}
#
#
# Best action is: Action.RUN
# 140
# {'gas_price': 10.991082792941612, 'co2_price': 41.987178616659826, 'power_price': 139.53528083345122, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1321049632}
# Spark: 80.55701942384978
# {<Action.DO_NOTHING: 0>: 151057.87974, <Action.RUN: 1>: 152111.78420000002}
#
#
# Best action is: Action.RUN
# 141
# {'gas_price': 10.621538494542705, 'co2_price': 40.68914006201726, 'power_price': 142.1292226644012, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1345038059}
# Spark: 84.81854410784123
# {<Action.DO_NOTHING: 0>: 154325.33297999998, <Action.RUN: 1>: 155745.61310999998}
#
#
# Best action is: Action.RUN
# 142
# {'gas_price': 10.882103754551272, 'co2_price': 41.27611562565627, 'power_price': 137.60734785305124, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1370312525}
# Spark: 79.4491284728437
# {<Action.DO_NOTHING: 0>: 149468.00582999998, <Action.RUN: 1>: 150210.9056}
#
#
# Best action is: Action.RUN
# 143
# {'gas_price': 11.2073583623234, 'co2_price': 44.06780719121513, 'power_price': 133.46460665653734, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1394058275}
# Spark: 72.1894411029988
# {<Action.DO_NOTHING: 0>: 142550.79079, <Action.RUN: 1>: 143363.62233999997}
#
#
# Best action is: Action.RUN
# 144
# {'gas_price': 11.029350904075892, 'co2_price': 43.62917301909072, 'power_price': 132.45773217851334, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1415719913}
# Spark: 71.79920825534671
# {<Action.DO_NOTHING: 0>: 141456.65375, <Action.RUN: 1>: 142397.37595999998}
#
#
# Best action is: Action.RUN
# 145
# {'gas_price': 11.013079685355585, 'co2_price': 46.40961399545837, 'power_price': 136.21053662993143, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1437303191}
# Spark: 72.78784294911748
# {<Action.DO_NOTHING: 0>: 141885.71736, <Action.RUN: 1>: 142686.58307999998}
#
#
# Best action is: Action.RUN
# 146
# {'gas_price': 10.362799863550928, 'co2_price': 46.07684437388711, 'power_price': 123.95512581288408, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1459211273}
# Spark: 61.51548157544603
# {<Action.DO_NOTHING: 0>: 131722.23982, <Action.RUN: 1>: 131959.84102}
#
#
# Best action is: Action.RUN
# 147
# {'gas_price': 10.134656940348298, 'co2_price': 48.334611826492896, 'power_price': 122.14360318047005, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1477858573}
# Spark: 57.67433441362885
# {<Action.DO_NOTHING: 0>: 127839.23129, <Action.RUN: 1>: 128670.75453}
#
#
# Best action is: Action.RUN
# 148
# {'gas_price': 9.865872221162354, 'co2_price': 47.27745153539416, 'power_price': 124.36254146910615, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1495413203}
# Spark: 61.21921771254965
# {<Action.DO_NOTHING: 0>: 130087.09495, <Action.RUN: 1>: 131013.4352}
#
#
# Best action is: Action.RUN
# 149
# {'gas_price': 9.221349717036698, 'co2_price': 46.861815561124864, 'power_price': 128.4906201479376, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1514033641}
# Spark: 66.40745486977602
# {<Action.DO_NOTHING: 0>: 134129.66122, <Action.RUN: 1>: 134969.87671999997}
#
#
# Best action is: Action.RUN
# 150
# {'gas_price': 9.119050812518898, 'co2_price': 48.071447883109336, 'power_price': 136.73591499292505, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1534202300}
# Spark: 73.54541629729682
# {<Action.DO_NOTHING: 0>: 139367.74289, <Action.RUN: 1>: 140143.59955}
#
#
# Best action is: Action.RUN
# 151
# {'gas_price': 8.78710116039209, 'co2_price': 51.15164147673706, 'power_price': 135.92013993840877, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1556491996}
# Spark: 69.9813973012796
# {<Action.DO_NOTHING: 0>: 136044.44201, <Action.RUN: 1>: 136842.19595}
#
#
# Best action is: Action.RUN
# 152
# {'gas_price': 9.129943271074367, 'co2_price': 51.62799427213556, 'power_price': 149.04825838246103, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1577776093}
# Spark: 82.2903208392511
# {<Action.DO_NOTHING: 0>: 145790.31133, <Action.RUN: 1>: 146660.07235000003}
#
#
# Best action is: Action.RUN
# 153
# {'gas_price': 8.716986858569754, 'co2_price': 51.75005043895335, 'power_price': 146.53907758051176, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1602695484}
# Spark: 80.07204028298865
# {<Action.DO_NOTHING: 0>: 143016.45957, <Action.RUN: 1>: 144097.27678000001}
#
#
# Best action is: Action.RUN
# 154
# {'gas_price': 8.619637454961437, 'co2_price': 52.564158212728046, 'power_price': 145.23767323786902, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1627007224}
# Spark: 78.05387757017954
# {<Action.DO_NOTHING: 0>: 140933.21131, <Action.RUN: 1>: 141903.26212}
#
#
# Best action is: Action.RUN
# 155
# {'gas_price': 8.765580322499826, 'co2_price': 53.79089312749276, 'power_price': 144.65230634102312, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1650768840}
# Spark: 76.09583289103054
# {<Action.DO_NOTHING: 0>: 138712.92415999997, <Action.RUN: 1>: 139531.45564000003}
#
#
# Best action is: Action.RUN
# 156
# {'gas_price': 8.985843761780648, 'co2_price': 56.27836471055725, 'power_price': 153.8552554092682, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1673997007}
# Spark: 82.59104693693033
# {<Action.DO_NOTHING: 0>: 143091.31862, <Action.RUN: 1>: 143993.24826999998}
#
#
# Best action is: Action.RUN
# 157
# {'gas_price': 8.44675242482304, 'co2_price': 54.10415617889175, 'power_price': 161.7798055477911, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1699163272}
# Spark: 93.22889694407633
# {<Action.DO_NOTHING: 0>: 151145.64339999997, <Action.RUN: 1>: 152498.64445}
#
#
# Best action is: Action.RUN
# 158
# {'gas_price': 8.51860092669044, 'co2_price': 54.542256294192505, 'power_price': 147.97594761661372, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 1727482483}
# Spark: 78.91509039573079
# {<Action.DO_NOTHING: 0>: 138972.13428999996, <Action.RUN: 1>: 139780.52914}
#
#
# Best action is: Action.RUN
# 159
# ...
# {<Action.DO_NOTHING: 0>: 119314.68863999998, <Action.RUN: 1>: 121241.51828}
#
#
# Best action is: Action.RUN
# 246
# {'gas_price': 9.025409429940638, 'co2_price': 40.39951912030017, 'power_price': 230.35749696069178, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 4969836964}
# Spark: 174.93256841045098
# {<Action.DO_NOTHING: 0>: 119267.22555, <Action.RUN: 1>: 121419.16622}
#
#
# Best action is: Action.RUN
# 247
# {'gas_price': 9.494200519076403, 'co2_price': 39.5743250351854, 'power_price': 218.89166498181174, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 5027454833}
# Spark: 163.82313942754993
# {<Action.DO_NOTHING: 0>: 111858.28481, <Action.RUN: 1>: 114003.85905}
#
#
# Best action is: Action.RUN
# 248
# {'gas_price': 9.101782053015022, 'co2_price': 39.77280725783915, 'power_price': 223.20136916838038, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 5081918552}
# Spark: 168.32677985752622
# {<Action.DO_NOTHING: 0>: 112038.40836, <Action.RUN: 1>: 114405.62542}
#
#
# Best action is: Action.RUN
# 249
# {'gas_price': 8.940355615131812, 'co2_price': 39.376442219529366, 'power_price': 232.82947030643263, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 5137789457}
# Spark: 178.51267247177145
# {<Action.DO_NOTHING: 0>: 116042.63655000001, <Action.RUN: 1>: 118045.83408}
#
#
# Best action is: Action.RUN
# 250
# {'gas_price': 9.192660367429271, 'co2_price': 37.03925233521194, 'power_price': 236.86122969765566, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 5196731831}
# Spark: 184.62931699501442
# {<Action.DO_NOTHING: 0>: 117394.64558, <Action.RUN: 1>: 119723.16204000001}
#
#
# Best action is: Action.RUN
# 251
# {'gas_price': 8.918211023624929, 'co2_price': 35.61883188304312, 'power_price': 255.7845189963305, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 5257560563}
# Spark: 205.24747608966243
# {<Action.DO_NOTHING: 0>: 126908.58105999998, <Action.RUN: 1>: 129749.72893000001}
#
#
# Best action is: Action.RUN
# 252
# {'gas_price': 8.754731125787437, 'co2_price': 37.65333740576369, 'power_price': 249.16731508554426, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 5324520204}
# Spark: 196.75924655399314
# {<Action.DO_NOTHING: 0>: 120704.75853, <Action.RUN: 1>: 123623.20415}
#
#
# Best action is: Action.RUN
# 253
# {'gas_price': 8.421858238316599, 'co2_price': 38.092933079830054, 'power_price': 230.6613815349561, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 5389107778}
# Spark: 178.14659021680944
# {<Action.DO_NOTHING: 0>: 109891.05706, <Action.RUN: 1>: 112029.38657999999}
#
#
# Best action is: Action.RUN
# 254
# {'gas_price': 8.507253129680967, 'co2_price': 37.85620705056442, 'power_price': 236.18729931038405, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 5448358152}
# Spark: 183.82383913013865
# {<Action.DO_NOTHING: 0>: 110952.81727, <Action.RUN: 1>: 113039.25596}
#
#
# Best action is: Action.RUN
# 255
# {'gas_price': 8.770843153071683, 'co2_price': 38.21424033812428, 'power_price': 228.5647213236862, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 5509366877}
# Spark: 175.57963783249022
# {<Action.DO_NOTHING: 0>: 104748.84807, <Action.RUN: 1>: 107006.7019}
#
#
# Best action is: Action.RUN
# 256
# {'gas_price': 8.886281184437362, 'co2_price': 37.94449585832323, 'power_price': 218.98046972860956, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 5568065080}
# Spark: 166.14969268584898
# {<Action.DO_NOTHING: 0>: 98509.7713, <Action.RUN: 1>: 100789.24218}
#
#
# Best action is: Action.RUN
# 257
# {'gas_price': 9.080087607219724, 'co2_price': 36.70864727975014, 'power_price': 206.70324571533033, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 5624102137}
# Spark: 154.91451082836048
# {<Action.DO_NOTHING: 0>: 91386.02525000002, <Action.RUN: 1>: 93356.69691}
#
#
# Best action is: Action.RUN
# 258
# {'gas_price': 8.920975069466476, 'co2_price': 36.95162931370847, 'power_price': 206.80309500445856, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 5676945652}
# Spark: 154.9304906212836
# {<Action.DO_NOTHING: 0>: 89937.61025999999, <Action.RUN: 1>: 91864.96218999999}
#
#
# Best action is: Action.RUN
# 259
# {'gas_price': 8.736228371056692, 'co2_price': 36.67852037208918, 'power_price': 201.5052181898697, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 5729881116}
# Spark: 150.09046944672386
# {<Action.DO_NOTHING: 0>: 85824.13204, <Action.RUN: 1>: 87902.35676000001}
#
#
# Best action is: Action.RUN
# 260
# {'gas_price': 8.723724103621265, 'co2_price': 36.09901023667406, 'power_price': 194.7046409095764, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 5781488387}
# Spark: 143.88190656928109
# {<Action.DO_NOTHING: 0>: 81391.48753999999, <Action.RUN: 1>: 83505.54912000001}
#
#
# Best action is: Action.RUN
# 261
# {'gas_price': 8.979549351571714, 'co2_price': 35.5139245631472, 'power_price': 193.30165694043805, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 5831364997}
# Spark: 142.80818302571916
# {<Action.DO_NOTHING: 0>: 79536.24372, <Action.RUN: 1>: 81711.00761999999}
#
#
# Best action is: Action.RUN
# 262
# {'gas_price': 9.230981272287355, 'co2_price': 36.973852885641016, 'power_price': 197.84396365427284, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 5881009937}
# Spark: 145.63912949634448
# {<Action.DO_NOTHING: 0>: 79178.97637, <Action.RUN: 1>: 81414.90248}
#
#
# Best action is: Action.RUN
# 263
# {'gas_price': 8.882698659408506, 'co2_price': 36.83071243169676, 'power_price': 189.40719674846002, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 5931564871}
# Spark: 137.69378565735477
# {<Action.DO_NOTHING: 0>: 74098.57266, <Action.RUN: 1>: 76181.90664}
#
#
# Best action is: Action.RUN
# 264
# {'gas_price': 9.196854269269387, 'co2_price': 37.591396560726565, 'power_price': 204.6164909605855, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 5979879429}
# Spark: 151.82824013058956
# {<Action.DO_NOTHING: 0>: 78734.99474000001, <Action.RUN: 1>: 81021.79259}
#
#
# Best action is: Action.RUN
# 265
# {'gas_price': 9.333062873431272, 'co2_price': 37.31344636577205, 'power_price': 200.1850246816918, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 6032407860}
# Spark: 147.5385154424885
# {<Action.DO_NOTHING: 0>: 75380.72159, <Action.RUN: 1>: 77514.54731000001}
#
#
# Best action is: Action.RUN
# 266
# {'gas_price': 8.95343006439704, 'co2_price': 36.08483384145249, 'power_price': 192.60247076450767, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 6083768377}
# Spark: 141.56420685865817
# {<Action.DO_NOTHING: 0>: 71011.38368, <Action.RUN: 1>: 73176.98715}
#
#
# Best action is: Action.RUN
# 267
# {'gas_price': 8.51010790727984, 'co2_price': 36.367743794784474, 'power_price': 193.23868944092362, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 6133466341}
# Spark: 142.36083773885932
# {<Action.DO_NOTHING: 0>: 69825.53678, <Action.RUN: 1>: 71885.96426000001}
#
#
# Best action is: Action.RUN
# 268
# {'gas_price': 8.829778915347681, 'co2_price': 37.15079342946785, 'power_price': 190.60953529570602, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 6183479386}
# Spark: 138.6289629508905
# {<Action.DO_NOTHING: 0>: 66600.85088, <Action.RUN: 1>: 68979.18258000001}
#
#
# Best action is: Action.RUN
# 269
# {'gas_price': 8.226696413074391, 'co2_price': 38.7092788842691, 'power_price': 190.27036462272815, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 6232483524}
# Spark: 137.33438932538465
# {<Action.DO_NOTHING: 0>: 64785.77789, <Action.RUN: 1>: 66449.33962}
#
#
# Best action is: Action.RUN
# 270
# {'gas_price': 8.361008244145513, 'co2_price': 38.67969277771495, 'power_price': 168.4830470414321, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 6281189956}
# Spark: 115.44234601957164
# {<Action.DO_NOTHING: 0>: 54564.30408, <Action.RUN: 1>: 56322.498230000005}
#
#
# Best action is: Action.RUN
# 271
# {'gas_price': 8.430542604966401, 'co2_price': 36.61996832981359, 'power_price': 163.89524796025069, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 6323573797}
# Spark: 112.84473702547069
# {<Action.DO_NOTHING: 0>: 52168.53636999999, <Action.RUN: 1>: 53755.55956}
#
#
# Best action is: Action.RUN
# 272
# {'gas_price': 8.26720274796856, 'co2_price': 35.616753374846624, 'power_price': 168.37363606757046, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 6365267884}
# Spark: 118.48967994475527
# {<Action.DO_NOTHING: 0>: 52622.54276999999, <Action.RUN: 1>: 54516.47871}
#
#
# Best action is: Action.RUN
# 273
# {'gas_price': 8.322698920319676, 'co2_price': 35.43681393118946, 'power_price': 158.9344333609924, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 6408681877}
# Spark: 109.17492050948324
# {<Action.DO_NOTHING: 0>: 47648.55156, <Action.RUN: 1>: 49375.765569999996}
#
#
# Best action is: Action.RUN
# 274
# {'gas_price': 8.34511772935604, 'co2_price': 34.28825203287435, 'power_price': 157.48036879110504, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 6449443170}
# Spark: 108.84699902887465
# {<Action.DO_NOTHING: 0>: 45897.67078, <Action.RUN: 1>: 47602.12879000001}
#
#
# Best action is: Action.RUN
# 275
# {'gas_price': 7.840661660015165, 'co2_price': 35.526207548755735, 'power_price': 173.63562206651054, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 6490175873}
# Spark: 124.26875285773963
# {<Action.DO_NOTHING: 0>: 49519.56716, <Action.RUN: 1>: 51562.90952}
#
#
# Best action is: Action.RUN
# 276
# {'gas_price': 7.687487814589672, 'co2_price': 34.81382216661478, 'power_price': 168.67096370997865, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 6535486438}
# Spark: 120.1696537287742
# {<Action.DO_NOTHING: 0>: 46660.836859999996, <Action.RUN: 1>: 48485.60067}
#
#
# Best action is: Action.RUN
# 277
# {'gas_price': 7.995951597254096, 'co2_price': 34.92267449772716, 'power_price': 164.07334011152847, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 6579672924}
# Spark: 115.15471401654723
# {<Action.DO_NOTHING: 0>: 43441.38394, <Action.RUN: 1>: 45219.226200000005}
#
#
# Best action is: Action.RUN
# 278
# {'gas_price': 7.7102842455044245, 'co2_price': 33.82273465161714, 'power_price': 171.43097036342226, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 6622465606}
# Spark: 123.8979514663007
# {<Action.DO_NOTHING: 0>: 44481.38964, <Action.RUN: 1>: 46469.4915}
#
#
# Best action is: Action.RUN
# 279
# {'gas_price': 8.124567537496675, 'co2_price': 33.30555335145158, 'power_price': 167.20221932648326, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 6667886206}
# Spark: 119.772098437535
# {<Action.DO_NOTHING: 0>: 41588.16972, <Action.RUN: 1>: 43444.264}
#
#
# Best action is: Action.RUN
# 280
# {'gas_price': 7.879986937543746, 'co2_price': 33.10357734744093, 'power_price': 167.92086958110448, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 6712175083}
# Spark: 120.9373052961198
# {<Action.DO_NOTHING: 0>: 40164.10884, <Action.RUN: 1>: 42200.978429999996}
#
#
# Best action is: Action.RUN
# 281
# {'gas_price': 7.823639939758814, 'co2_price': 33.26899436273281, 'power_price': 169.3983197131093, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 6756877909}
# Spark: 122.30568541061766
# {<Action.DO_NOTHING: 0>: 38682.597480000004, <Action.RUN: 1>: 40692.44227000001}
#
#
# Best action is: Action.RUN
# 282
# {'gas_price': 8.231981299931148, 'co2_price': 32.48504687795842, 'power_price': 169.96017736416735, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 6802054792}
# Spark: 123.2431491862778
# {<Action.DO_NOTHING: 0>: 37197.50866000001, <Action.RUN: 1>: 39205.813760000005}
#
#
# Best action is: Action.RUN
# 283
# {'gas_price': 8.2839091965794, 'co2_price': 31.620541753967107, 'power_price': 173.47363510683368, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 6847580480}
# Spark: 127.56918415628718
# {<Action.DO_NOTHING: 0>: 36119.48399, <Action.RUN: 1>: 38400.9389}
#
#
# Best action is: Action.RUN
# 284
# {'gas_price': 8.44126904324419, 'co2_price': 31.559491427311738, 'power_price': 181.6014560271915, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 6894446646}
# Spark: 135.60069555663557
# {<Action.DO_NOTHING: 0>: 36244.97603, <Action.RUN: 1>: 38474.03578}
#
#
# Best action is: Action.RUN
# 285
# {'gas_price': 8.483721356418231, 'co2_price': 31.238324590488922, 'power_price': 187.45800088256203, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 6943739290}
# Spark: 141.73595493565486
# {<Action.DO_NOTHING: 0>: 35525.01167, <Action.RUN: 1>: 37928.24513}
#
#
# Best action is: Action.RUN
# 286
# {'gas_price': 8.811406611284234, 'co2_price': 30.852030926076772, 'power_price': 193.92889001309308, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 6994907799}
# Spark: 148.26545247573208
# {<Action.DO_NOTHING: 0>: 34661.097299999994, <Action.RUN: 1>: 37290.43297000001}
#
#
# Best action is: Action.RUN
# 287
# {'gas_price': 8.862787158566633, 'co2_price': 31.64409355233933, 'power_price': 193.40200648528426, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 7048070579}
# Spark: 146.8951257743783
# {<Action.DO_NOTHING: 0>: 32181.54096, <Action.RUN: 1>: 34713.04015}
#
#
# Best action is: Action.RUN
# 288
# {'gas_price': 8.928420292046102, 'co2_price': 31.603859515528487, 'power_price': 193.87488082070107, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 7100920366}
# Spark: 147.34260101312648
# {<Action.DO_NOTHING: 0>: 29986.878220000002, <Action.RUN: 1>: 32487.197030000003}
#
#
# Best action is: Action.RUN
# 289
# {'gas_price': 9.387404632304001, 'co2_price': 30.567836087879847, 'power_price': 200.86547770541551, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 7153988317}
# Spark: 154.91023698523168
# {<Action.DO_NOTHING: 0>: 28871.8599, <Action.RUN: 1>: 31645.03149}
#
#
# Best action is: Action.RUN
# 290
# {'gas_price': 9.542556424245328, 'co2_price': 30.88832767251384, 'power_price': 192.07752616063868, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 7209357313}
# Spark: 145.6466420638795
# {<Action.DO_NOTHING: 0>: 24779.0927, <Action.RUN: 1>: 27431.02743}
#
#
# Best action is: Action.RUN
# 291
# {'gas_price': 9.663157771934676, 'co2_price': 28.614012962586365, 'power_price': 185.70632781243103, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 7262108318}
# Spark: 141.42915707791
# {<Action.DO_NOTHING: 0>: 21665.114049999996, <Action.RUN: 1>: 24309.798520000004}
#
#
# Best action is: Action.RUN
# 292
# {'gas_price': 9.992038105732997, 'co2_price': 29.27643939561088, 'power_price': 189.68376435447223, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 7313712906}
# Spark: 144.41528685312835
# {<Action.DO_NOTHING: 0>: 19551.798380000004, <Action.RUN: 1>: 22323.34557}
#
#
# Best action is: Action.RUN
# 293
# {'gas_price': 10.638811419784407, 'co2_price': 29.5317418371836, 'power_price': 195.36429895784244, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 7366276114}
# Spark: 149.19374570087442
# {<Action.DO_NOTHING: 0>: 17384.00029, <Action.RUN: 1>: 20370.87173}
#
#
# Best action is: Action.RUN
# 294
# {'gas_price': 10.435067137353764, 'co2_price': 29.17633508574673, 'power_price': 190.65165081200172, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 7420323749}
# Spark: 145.04024858890122
# {<Action.DO_NOTHING: 0>: 14100.09629, <Action.RUN: 1>: 17176.226619999998}
#
#
# Best action is: Action.RUN
# 295
# {'gas_price': 10.397765275278443, 'co2_price': 30.00697635875108, 'power_price': 187.8550993581109, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 7473245823}
# Spark: 141.45035772408139
# {<Action.DO_NOTHING: 0>: 10928.77008, <Action.RUN: 1>: 14034.489690000002}
#
#
# Best action is: Action.RUN
# 296
# {'gas_price': 10.176594758691568, 'co2_price': 29.892806661654763, 'power_price': 183.14200841982125, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 7525205323}
# Spark: 137.0726069994749
# {<Action.DO_NOTHING: 0>: 7590.2633799999985, <Action.RUN: 1>: 10879.05329}
#
#
# Best action is: Action.RUN
# 297
# {'gas_price': 9.917465761915967, 'co2_price': 29.53710337928913, 'power_price': 174.34599432820252, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 7575970224}
# Spark: 128.89142518699742
# {<Action.DO_NOTHING: 0>: 3978.4260700000004, <Action.RUN: 1>: 7451.46486}
#
#
# Best action is: Action.RUN
# 298
# {'gas_price': 10.423956303931936, 'co2_price': 30.607679774250936, 'power_price': 173.50132715921276, 'plant_state': <PowerplantState.STAGE_2: 2>, 'balance': 7624426117}
# Spark: 126.46969108102991
# {<Action.DO_NOTHING: 0>: -504.60000000000014, <Action.RUN: 1>: 4335.19}
#
#
# Best action is: Action.RUN

# %% [markdown]
# # Conclusion
# - This problem was caused by imprecise measurement in the computation of the expected utility. Since there is only a small difference in running the plant and not running it, and there is a large variance of results, then it might happen that the expecteed value ends up being illogical
